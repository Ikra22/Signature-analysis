# %%
import os
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# Function to load images and labels from dataset directory
def load_data(dataset_dir):
    X, y = [], []
    for class_name in os.listdir(dataset_dir):
        class_dir = os.path.join(dataset_dir, class_name)
        if os.path.isdir(class_dir):
            for image_name in os.listdir(class_dir):
                image_path = os.path.join(class_dir, image_name)
                image = cv2.imread(image_path)
                image = cv2.resize(image, (128, 128))  # Resize images to a fixed size
                X.append(image)
                y.append(class_name)
    return np.array(X), np.array(y)

# Define CNN model architecture
def create_model(input_shape, num_classes):
    model = Sequential([
        Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
        MaxPooling2D(pool_size=(2, 2)),
        Conv2D(64, kernel_size=(3, 3), activation='relu'),
        MaxPooling2D(pool_size=(2, 2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def main():
    # Step 1: Load data
    dataset_dir = r'D:\AIML Internship\Task5_modified\cropped_signatures'
    X, y = load_data(dataset_dir)

    # Step 2: Encode class labels
    label_encoder = LabelEncoder()
    y_encoded = label_encoder.fit_transform(y)
    num_classes = len(label_encoder.classes_)

    # Step 3: Split data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

    # Step 4: Normalize pixel values to [0, 1]
    X_train = X_train.astype('float32') / 255.0
    X_test = X_test.astype('float32') / 255.0

    # Step 5: Convert class labels to one-hot encoded vectors
    y_train = to_categorical(y_train, num_classes)
    y_test = to_categorical(y_test, num_classes)

    # Step 6: Define input shape
    input_shape = X_train[0].shape

    # Step 7: Create and train the model
    model = create_model(input_shape, num_classes)
    model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.1)

    # Step 8: Evaluate the model
    test_loss, test_accuracy = model.evaluate(X_test, y_test)
    print("Test Accuracy:", test_accuracy)

    # Optionally, save the trained model for future use
    model.save("signature_verification_model.h5")

if __name__ == "__main__":
    main()
# Out:
# Epoch 1/10
# C:\Users\FRIENDS INFOTECH\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - accuracy: 0.3060 - loss: 2.2586 - val_accuracy: 0.6316 - val_loss: 1.3356
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.6997 - loss: 1.0460 - val_accuracy: 0.9737 - val_loss: 0.2860
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.8970 - loss: 0.3306 - val_accuracy: 0.9474 - val_loss: 0.0975
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - accuracy: 0.9860 - loss: 0.0903 - val_accuracy: 0.9737 - val_loss: 0.2927
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 228ms/step - accuracy: 0.9953 - loss: 0.0337 - val_accuracy: 1.0000 - val_loss: 0.0474
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.9973 - loss: 0.0163 - val_accuracy: 0.9737 - val_loss: 0.0603
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 0.0293
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0409
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0188
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 196ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0106
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9686 - loss: 0.0438
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test Accuracy: 0.9684210419654846

# %%
from tensorflow.keras.models import load_model

# Load the model
model = load_model("signature_verification_model.h5")

# Recompile the model with the necessary configuration
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Now you can use the model for training or evaluation
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import load_model

def calculate_height_to_width_ratio(image):
    if image is None:
        return 0
    height, width, _ = image.shape
    return height / width

def divide_image_into_parts(image, num_parts):
    if image is None:
        return []
    height, width, _ = image.shape
    part_height = height // num_parts
    parts = []
    for i in range(num_parts):
        part = image[i * part_height: (i + 1) * part_height, :]
        parts.append(part)
    return parts

def resize_image(image, target_height, target_width):
    if image is None:
        return None
    return cv2.resize(image, (target_width, target_height))

def extract_signature_parameters(image_part):
    if image_part is None:
        return None
    # Placeholder function, replace with your implementation
    return "Angular"  # For demonstration, always returning "Angular"

def compare_signature_parts(part1, part2):
    if part1 is None or part2 is None:
        return False
    return np.array_equal(part1, part2)

def find_dimensions_of_letters(image):
    if image is None:
        return 0, 0
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    total_width = 0
    total_height = 0
    count = 0
    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)
        total_width += w
        total_height += h
        count += 1
    if count == 0:
        return 0, 0
    avg_width = total_width / count
    avg_height = total_height / count
    return avg_width, avg_height

def test_signature(model_path, sample_images_folder, person_folder):
    # Step 1: Load the trained model
    model = load_model(model_path)

    # Step 2: Load sample images from the folder
    sample_image_paths = [os.path.join(sample_images_folder, filename) for filename in os.listdir(sample_images_folder)]

    # Step 3: Load person's signature images
    person_image_paths = [os.path.join(person_folder, filename) for filename in os.listdir(person_folder)]

    # Step 4: Iterate through each person's signature
    for person_image_path in person_image_paths:
        print("\nProcessing", person_image_path)
        person_image = cv2.imread(person_image_path)

        # Step 5: Calculate height-to-width ratio
        ratio = calculate_height_to_width_ratio(person_image)
        print("Height-to-Width Ratio:", ratio)

        # Step 6: Determine number of parts
        num_parts = 2  # Placeholder value, replace with your logic
        print("Number of Parts:", num_parts)

        # Step 7: Divide the image into parts
        person_parts = divide_image_into_parts(person_image, num_parts)

        # Step 8: Resize parts if necessary and find dimensions of letters
        resized_person_parts = []
        for part in person_parts:
            target_height, target_width = 100, 100  # Example target size, replace with your desired size
            resized_part = resize_image(part, target_height, target_width)
            resized_person_parts.append(resized_part)
            avg_width, avg_height = find_dimensions_of_letters(part)
            print("Average Width of Letters:", avg_width)
            print("Average Height of Letters:", avg_height)

        # Step 9: Extract signature parameters
        signature_parameters = [extract_signature_parameters(part) for part in resized_person_parts]
        print("Signature Parameters:", signature_parameters)

        # Step 10: Compare signature parts with sample images
        best_match_index = -1
        best_match_score = float('inf')
        for i, sample_image_path in enumerate(sample_image_paths):
            # Load sample image
            sample_image = cv2.imread(sample_image_path)

            # Divide sample image into parts
            sample_parts = divide_image_into_parts(sample_image, 2)  # Assuming 2 parts for comparison

            # Resize parts if necessary and find dimensions of letters
            resized_sample_parts = []
            for part in sample_parts:
                target_height, target_width = 100, 100  # Example target size, replace with your desired size
                resized_part = resize_image(part, target_height, target_width)
                resized_sample_parts.append(resized_part)
                avg_width, avg_height = find_dimensions_of_letters(part)
                print("Average Width of Letters:", avg_width)
                print("Average Height of Letters:", avg_height)

            # Compare signature parts
            score = sum(np.abs(np.subtract(part1, part2)).mean() for part1, part2 in zip(resized_person_parts, resized_sample_parts))
            print(f"Comparison Score with {os.path.basename(sample_image_path)}:", score)

            # Update best match
            if score < best_match_score:
                best_match_score = score
                best_match_index = i

        # Step 11: Print the best match result
        best_match_image = os.path.basename(sample_image_paths[best_match_index])
        print(f"\nBest Match: {best_match_image}")

# Example usage:
model_path = r"D:\AIML Internship\signature_verification_model.h5"
sample_images_folder = r"D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\sample images"
person_folder = r"D:\AIML Internship\Task5_modified\cropped_signatures\Hussain"
test_signature(model_path, sample_images_folder, person_folder)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\sample images
# Height-to-Width Ratio: 0
# Number of Parts: 2
# Signature Parameters: []
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 0
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 0
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_1.jpg
# Height-to-Width Ratio: 0.35537190082644626
# Number of Parts: 2
# Average Width of Letters: 121.0
# Average Height of Letters: 21.0
# Average Width of Letters: 84.33333333333333
# Average Height of Letters: 18.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 323.89803333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 405.6907
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_10.jpg
# Height-to-Width Ratio: 0.2839506172839506
# Number of Parts: 2
# Average Width of Letters: 162.0
# Average Height of Letters: 23.0
# Average Width of Letters: 162.0
# Average Height of Letters: 23.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 100.32506666666666
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 309.1193333333333
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_100.jpg
# Height-to-Width Ratio: 0.20883534136546184
# Number of Parts: 2
# Average Width of Letters: 67.5
# Average Height of Letters: 16.0
# Average Width of Letters: 146.0
# Average Height of Letters: 15.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 99.99526666666667
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 335.1746
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_101.jpg
# Height-to-Width Ratio: 0.29411764705882354
# Number of Parts: 2
# Average Width of Letters: 87.0
# Average Height of Letters: 15.0
# Average Width of Letters: 238.0
# Average Height of Letters: 35.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 81.7844
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 296.87626666666665
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_102.jpg
# Height-to-Width Ratio: 0.3727810650887574
# Number of Parts: 2
# Average Width of Letters: 62.0
# Average Height of Letters: 26.0
# Average Width of Letters: 169.0
# Average Height of Letters: 31.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 143.09493333333336
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 413.0476
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_103.jpg
# Height-to-Width Ratio: 0.3684210526315789
# Number of Parts: 2
# Average Width of Letters: 131.0
# Average Height of Letters: 27.0
# Average Width of Letters: 106.0
# Average Height of Letters: 19.666666666666668
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 440.4518
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 408.5122
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_104.jpg
# Height-to-Width Ratio: 0.32663316582914576
# Number of Parts: 2
# Average Width of Letters: 54.25
# Average Height of Letters: 20.75
# Average Width of Letters: 101.0
# Average Height of Letters: 16.666666666666668
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 412.0370333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 409.74223333333333
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_105.jpg
# Height-to-Width Ratio: 0.2928870292887029
# Number of Parts: 2
# Average Width of Letters: 239.0
# Average Height of Letters: 35.0
# Average Width of Letters: 239.0
# Average Height of Letters: 35.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 133.74536666666665
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 399.76416666666665
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_106.jpg
# Height-to-Width Ratio: 0.8679245283018868
# Number of Parts: 2
# Average Width of Letters: 53.0
# Average Height of Letters: 23.0
# Average Width of Letters: 53.0
# Average Height of Letters: 23.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 148.72246666666666
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 361.0666
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_107.jpg
# Height-to-Width Ratio: 0.2864864864864865
# Number of Parts: 2
# Average Width of Letters: 50.0
# Average Height of Letters: 8.25
# Average Width of Letters: 35.0
# Average Height of Letters: 5.833333333333333
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 96.84506666666667
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 298.13
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_108.jpg
# Height-to-Width Ratio: 0.3227848101265823
# Number of Parts: 2
# Average Width of Letters: 54.0
# Average Height of Letters: 25.0
# Average Width of Letters: 71.0
# Average Height of Letters: 11.333333333333334
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 331.22606666666667
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 406.8320666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_109.jpg
# Height-to-Width Ratio: 0.2768595041322314
# Number of Parts: 2
# Average Width of Letters: 121.0
# Average Height of Letters: 33.0
# Average Width of Letters: 162.5
# Average Height of Letters: 26.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 88.62453333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 316.7126666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_110.jpg
# Height-to-Width Ratio: 0.39901477832512317
# Number of Parts: 2
# Average Width of Letters: 53.4
# Average Height of Letters: 12.0
# Average Width of Letters: 113.66666666666667
# Average Height of Letters: 24.333333333333332
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 111.12753333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 405.6818
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_111.jpg
# Height-to-Width Ratio: 0.2736842105263158
# Number of Parts: 2
# Average Width of Letters: 67.33333333333333
# Average Height of Letters: 22.333333333333332
# Average Width of Letters: 29.571428571428573
# Average Height of Letters: 4.714285714285714
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 329.13806666666665
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 412.5094
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_112.jpg
# Height-to-Width Ratio: 0.37037037037037035
# Number of Parts: 2
# Average Width of Letters: 95.0
# Average Height of Letters: 35.0
# Average Width of Letters: 189.0
# Average Height of Letters: 35.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 95.23833333333334
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 353.1675333333333
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_113.jpg
# Height-to-Width Ratio: 0.4127906976744186
# Number of Parts: 2
# Average Width of Letters: 46.75
# Average Height of Letters: 9.75
# Average Width of Letters: 67.8
# Average Height of Letters: 13.2
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 96.26586666666667
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 389.0537333333333
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_114.jpg
# Height-to-Width Ratio: 0.32558139534883723
# Number of Parts: 2
# Average Width of Letters: 48.75
# Average Height of Letters: 18.75
# Average Width of Letters: 104.5
# Average Height of Letters: 17.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 354.8220666666666
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 410.25526666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_115.jpg
# Height-to-Width Ratio: 0.22388059701492538
# Number of Parts: 2
# Average Width of Letters: 139.0
# Average Height of Letters: 16.0
# Average Width of Letters: 49.5
# Average Height of Letters: 8.375
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 105.69923333333332
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 404.9980333333333
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_116.jpg
# Height-to-Width Ratio: 0.30472103004291845
# Number of Parts: 2
# Average Width of Letters: 233.0
# Average Height of Letters: 35.0
# Average Width of Letters: 118.0
# Average Height of Letters: 18.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 110.51193333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 397.1302
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_117.jpg
# Height-to-Width Ratio: 0.4583333333333333
# Number of Parts: 2
# Average Width of Letters: 192.0
# Average Height of Letters: 44.0
# Average Width of Letters: 192.0
# Average Height of Letters: 44.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 130.549
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 414.76086666666663
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_118.jpg
# Height-to-Width Ratio: 0.49473684210526314
# Number of Parts: 2
# Average Width of Letters: 69.33333333333333
# Average Height of Letters: 18.666666666666668
# Average Width of Letters: 78.5
# Average Height of Letters: 22.25
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 141.28356666666667
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 419.8890333333334
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_119.jpg
# Height-to-Width Ratio: 0.3235294117647059
# Number of Parts: 2
# Average Width of Letters: 84.33333333333333
# Average Height of Letters: 15.333333333333334
# Average Width of Letters: 86.33333333333333
# Average Height of Letters: 15.666666666666666
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 379.12076666666667
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 416.4889
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_12.jpg
# Height-to-Width Ratio: 0.23357664233576642
# Number of Parts: 2
# Average Width of Letters: 274.0
# Average Height of Letters: 32.0
# Average Width of Letters: 274.0
# Average Height of Letters: 32.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 390.2923333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 414.1266
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_120.jpg
# Height-to-Width Ratio: 0.35797665369649806
# Number of Parts: 2
# Average Width of Letters: 136.0
# Average Height of Letters: 34.5
# Average Width of Letters: 257.0
# Average Height of Letters: 46.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 399.99903333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 410.56396666666666
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_121.jpg
# Height-to-Width Ratio: 0.2815884476534296
# Number of Parts: 2
# Average Width of Letters: 277.0
# Average Height of Letters: 39.0
# Average Width of Letters: 277.0
# Average Height of Letters: 39.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 114.45716666666667
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 292.13890000000004
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_122.jpg
# Height-to-Width Ratio: 0.2968036529680365
# Number of Parts: 2
# Average Width of Letters: 219.0
# Average Height of Letters: 32.0
# Average Width of Letters: 46.714285714285715
# Average Height of Letters: 11.285714285714286
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 393.9605
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 409.8161
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_123.jpg
# Height-to-Width Ratio: 0.34146341463414637
# Number of Parts: 2
# Average Width of Letters: 287.0
# Average Height of Letters: 49.0
# Average Width of Letters: 182.0
# Average Height of Letters: 35.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 81.42423333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 278.11823333333336
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_124.jpg
# Height-to-Width Ratio: 0.3659574468085106
# Number of Parts: 2
# Average Width of Letters: 235.0
# Average Height of Letters: 43.0
# Average Width of Letters: 152.0
# Average Height of Letters: 32.5
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 324.95033333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 406.16273333333334
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_125.jpg
# Height-to-Width Ratio: 0.3391812865497076
# Number of Parts: 2
# Average Width of Letters: 88.0
# Average Height of Letters: 16.5
# Average Width of Letters: 57.4
# Average Height of Letters: 11.6
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 90.92373333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 230.33346666666665
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_126.jpg
# Height-to-Width Ratio: 0.31210191082802546
# Number of Parts: 2
# Average Width of Letters: 157.0
# Average Height of Letters: 24.0
# Average Width of Letters: 79.0
# Average Height of Letters: 12.5
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 386.0246666666667
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 407.1112
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_127.jpg
# Height-to-Width Ratio: 0.41578947368421054
# Number of Parts: 2
# Average Width of Letters: 190.0
# Average Height of Letters: 39.0
# Average Width of Letters: 97.0
# Average Height of Letters: 21.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 86.75873333333334
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 328.08206666666666
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_128.jpg
# Height-to-Width Ratio: 0.3114754098360656
# Number of Parts: 2
# Average Width of Letters: 183.0
# Average Height of Letters: 28.0
# Average Width of Letters: 143.0
# Average Height of Letters: 23.5
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 98.79303333333334
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 229.90836666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_129.jpg
# Height-to-Width Ratio: 0.38372093023255816
# Number of Parts: 2
# Average Width of Letters: 86.0
# Average Height of Letters: 33.0
# Average Width of Letters: 172.0
# Average Height of Letters: 33.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 84.8856
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 334.7764
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_13.jpg
# Height-to-Width Ratio: 0.30115830115830117
# Number of Parts: 2
# Average Width of Letters: 259.0
# Average Height of Letters: 39.0
# Average Width of Letters: 259.0
# Average Height of Letters: 39.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 164.1583
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 395.9669666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_130.jpg
# Height-to-Width Ratio: 0.335
# Number of Parts: 2
# Average Width of Letters: 48.0
# Average Height of Letters: 9.2
# Average Width of Letters: 72.0
# Average Height of Letters: 13.333333333333334
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 319.55116666666663
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 417.74490000000003
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_131.jpg
# Height-to-Width Ratio: 0.2345132743362832
# Number of Parts: 2
# Average Width of Letters: 226.0
# Average Height of Letters: 26.0
# Average Width of Letters: 226.0
# Average Height of Letters: 26.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 95.09996666666666
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 239.58703333333335
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_132.jpg
# Height-to-Width Ratio: 0.24267782426778242
# Number of Parts: 2
# Average Width of Letters: 120.5
# Average Height of Letters: 15.0
# Average Width of Letters: 39.875
# Average Height of Letters: 8.5
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 109.25186666666667
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 350.6264
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_133.jpg
# Height-to-Width Ratio: 0.3933333333333333
# Number of Parts: 2
# Average Width of Letters: 150.0
# Average Height of Letters: 29.0
# Average Width of Letters: 150.0
# Average Height of Letters: 29.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 104.32249999999999
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 255.38876666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_134.jpg
# Height-to-Width Ratio: 0.25
# Number of Parts: 2
# Average Width of Letters: 256.0
# Average Height of Letters: 32.0
# Average Width of Letters: 47.0
# Average Height of Letters: 8.333333333333334
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 72.00290000000001
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 228.4025
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_135.jpg
# Height-to-Width Ratio: 0.27380952380952384
# Number of Parts: 2
# Average Width of Letters: 83.5
# Average Height of Letters: 23.0
# Average Width of Letters: 168.0
# Average Height of Letters: 23.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 103.8488
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 382.39453333333336
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_136.jpg
# Height-to-Width Ratio: 0.2175732217573222
# Number of Parts: 2
# Average Width of Letters: 239.0
# Average Height of Letters: 26.0
# Average Width of Letters: 239.0
# Average Height of Letters: 26.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 92.2877
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 246.01636666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_137.jpg
# Height-to-Width Ratio: 0.2857142857142857
# Number of Parts: 2
# Average Width of Letters: 91.5
# Average Height of Letters: 26.0
# Average Width of Letters: 182.0
# Average Height of Letters: 26.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 102.82396666666668
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 215.72063333333332
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_138.jpg
# Height-to-Width Ratio: 0.265
# Number of Parts: 2
# Average Width of Letters: 53.25
# Average Height of Letters: 18.75
# Average Width of Letters: 200.0
# Average Height of Letters: 26.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 419.5919333333334
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 404.8555333333333
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_139.jpg
# Height-to-Width Ratio: 0.3916083916083916
# Number of Parts: 2
# Average Width of Letters: 72.0
# Average Height of Letters: 28.0
# Average Width of Letters: 143.0
# Average Height of Letters: 28.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 94.0912
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 342.92386666666664
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_14.jpg
# Height-to-Width Ratio: 0.2578947368421053
# Number of Parts: 2
# Average Width of Letters: 190.0
# Average Height of Letters: 24.0
# Average Width of Letters: 190.0
# Average Height of Letters: 24.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 94.89773333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 315.8349333333333
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_140.jpg
# Height-to-Width Ratio: 0.24766355140186916
# Number of Parts: 2
# Average Width of Letters: 214.0
# Average Height of Letters: 26.0
# Average Width of Letters: 214.0
# Average Height of Letters: 26.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 96.63589999999999
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 265.56243333333333
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_141.jpg
# Height-to-Width Ratio: 0.3933333333333333
# Number of Parts: 2
# Average Width of Letters: 150.0
# Average Height of Letters: 29.0
# Average Width of Letters: 150.0
# Average Height of Letters: 29.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 105.2966
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 206.0076666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_142.jpg
# Height-to-Width Ratio: 0.3696682464454976
# Number of Parts: 2
# Average Width of Letters: 56.75
# Average Height of Letters: 11.25
# Average Width of Letters: 43.5
# Average Height of Letters: 11.25
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 350.1178
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 417.1904666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_143.jpg
# Height-to-Width Ratio: 0.29545454545454547
# Number of Parts: 2
# Average Width of Letters: 176.0
# Average Height of Letters: 26.0
# Average Width of Letters: 176.0
# Average Height of Letters: 26.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 100.18486666666666
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 343.249
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_144.jpg
# Height-to-Width Ratio: 0.3783783783783784
# Number of Parts: 2
# Average Width of Letters: 148.0
# Average Height of Letters: 28.0
# Average Width of Letters: 148.0
# Average Height of Letters: 28.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 107.845
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 251.68353333333334
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_145.jpg
# Height-to-Width Ratio: 0.2958579881656805
# Number of Parts: 2
# Average Width of Letters: 53.75
# Average Height of Letters: 17.25
# Average Width of Letters: 119.5
# Average Height of Letters: 19.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 252.4068
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 410.84586666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_146.jpg
# Height-to-Width Ratio: 0.33204633204633205
# Number of Parts: 2
# Average Width of Letters: 140.0
# Average Height of Letters: 24.0
# Average Width of Letters: 259.0
# Average Height of Letters: 43.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 86.13583333333332
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 311.99676666666664
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_147.jpg
# Height-to-Width Ratio: 0.4375
# Number of Parts: 2
# Average Width of Letters: 128.0
# Average Height of Letters: 28.0
# Average Width of Letters: 128.0
# Average Height of Letters: 28.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 123.07759999999999
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 205.1092
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_148.jpg
# Height-to-Width Ratio: 0.4012345679012346
# Number of Parts: 2
# Average Width of Letters: 85.0
# Average Height of Letters: 19.0
# Average Width of Letters: 162.0
# Average Height of Letters: 32.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 103.31566666666667
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 383.8155333333333
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_149.jpg
# Height-to-Width Ratio: 0.44594594594594594
# Number of Parts: 2
# Average Width of Letters: 75.5
# Average Height of Letters: 19.0
# Average Width of Letters: 75.0
# Average Height of Letters: 17.5
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 100.7832
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 357.7993333333333
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_15.jpg
# Height-to-Width Ratio: 0.33649289099526064
# Number of Parts: 2
# Average Width of Letters: 211.0
# Average Height of Letters: 35.0
# Average Width of Letters: 211.0
# Average Height of Letters: 35.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 93.53483333333334
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 332.86136666666664
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_150.jpg
# Height-to-Width Ratio: 0.22897196261682243
# Number of Parts: 2
# Average Width of Letters: 44.8
# Average Height of Letters: 16.6
# Average Width of Letters: 72.0
# Average Height of Letters: 8.666666666666666
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 143.36786666666666
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 412.1088
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_151.jpg
# Height-to-Width Ratio: 0.27876106194690264
# Number of Parts: 2
# Average Width of Letters: 226.0
# Average Height of Letters: 31.0
# Average Width of Letters: 226.0
# Average Height of Letters: 31.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 95.55183333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 355.4607666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_152.jpg
# Height-to-Width Ratio: 0.4084507042253521
# Number of Parts: 2
# Average Width of Letters: 142.0
# Average Height of Letters: 29.0
# Average Width of Letters: 72.5
# Average Height of Letters: 15.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 108.35263333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 292.3831666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_153.jpg
# Height-to-Width Ratio: 0.273972602739726
# Number of Parts: 2
# Average Width of Letters: 109.5
# Average Height of Letters: 30.0
# Average Width of Letters: 219.0
# Average Height of Letters: 30.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 99.302
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 368.6488
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_154.jpg
# Height-to-Width Ratio: 0.32217573221757323
# Number of Parts: 2
# Average Width of Letters: 239.0
# Average Height of Letters: 38.0
# Average Width of Letters: 45.666666666666664
# Average Height of Letters: 10.833333333333334
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 127.49960000000002
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 430.4762666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_155.jpg
# Height-to-Width Ratio: 0.38011695906432746
# Number of Parts: 2
# Average Width of Letters: 171.0
# Average Height of Letters: 32.0
# Average Width of Letters: 171.0
# Average Height of Letters: 32.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 122.06556666666667
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 404.69876666666664
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_156.jpg
# Height-to-Width Ratio: 0.34615384615384615
# Number of Parts: 2
# Average Width of Letters: 130.0
# Average Height of Letters: 22.0
# Average Width of Letters: 130.0
# Average Height of Letters: 22.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 116.65106666666668
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 367.48053333333337
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_157.jpg
# Height-to-Width Ratio: 0.4010152284263959
# Number of Parts: 2
# Average Width of Letters: 100.0
# Average Height of Letters: 21.5
# Average Width of Letters: 100.5
# Average Height of Letters: 20.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 98.36463333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 385.75943333333333
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_158.jpg
# Height-to-Width Ratio: 0.4
# Number of Parts: 2
# Average Width of Letters: 103.5
# Average Height of Letters: 21.5
# Average Width of Letters: 69.33333333333333
# Average Height of Letters: 16.333333333333332
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 151.40246666666667
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 410.3898
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_159.jpg
# Height-to-Width Ratio: 0.3575757575757576
# Number of Parts: 2
# Average Width of Letters: 165.0
# Average Height of Letters: 29.0
# Average Width of Letters: 165.0
# Average Height of Letters: 29.0
# Signature Parameters: ['Angular', 'Angular']
# ...
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 419.37583333333333
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_8.jpg
# Height-to-Width Ratio: 0.3080568720379147
# Number of Parts: 2
# Average Width of Letters: 211.0
# Average Height of Letters: 32.0
# Average Width of Letters: 211.0
# Average Height of Letters: 32.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 413.26103333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 410.6846333333333
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_80.jpg
# Height-to-Width Ratio: 0.23228346456692914
# Number of Parts: 2
# Average Width of Letters: 254.0
# Average Height of Letters: 29.0
# Average Width of Letters: 254.0
# Average Height of Letters: 29.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 94.05893333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 313.5028
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_81.jpg
# Height-to-Width Ratio: 0.2891566265060241
# Number of Parts: 2
# Average Width of Letters: 89.0
# Average Height of Letters: 14.666666666666666
# Average Width of Letters: 125.5
# Average Height of Letters: 18.5
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 81.5941
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 351.3249
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_82.jpg
# Height-to-Width Ratio: 0.29577464788732394
# Number of Parts: 2
# Average Width of Letters: 213.0
# Average Height of Letters: 31.0
# Average Width of Letters: 75.66666666666667
# Average Height of Letters: 15.666666666666666
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 140.3782
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 425.7762
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_83.jpg
# Height-to-Width Ratio: 0.2423076923076923
# Number of Parts: 2
# Average Width of Letters: 91.0
# Average Height of Letters: 11.666666666666666
# Average Width of Letters: 56.0
# Average Height of Letters: 8.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 81.08033333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 365.07033333333334
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_84.jpg
# Height-to-Width Ratio: 0.2893401015228426
# Number of Parts: 2
# Average Width of Letters: 197.0
# Average Height of Letters: 28.0
# Average Width of Letters: 197.0
# Average Height of Letters: 28.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 98.87003333333334
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 374.92403333333334
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_85.jpg
# Height-to-Width Ratio: 0.29831932773109243
# Number of Parts: 2
# Average Width of Letters: 124.5
# Average Height of Letters: 19.5
# Average Width of Letters: 121.5
# Average Height of Letters: 18.5
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 84.4978
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 414.8238
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_86.jpg
# Height-to-Width Ratio: 0.23469387755102042
# Number of Parts: 2
# Average Width of Letters: 105.5
# Average Height of Letters: 12.5
# Average Width of Letters: 56.6
# Average Height of Letters: 11.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 106.47493333333334
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 363.6958666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_87.jpg
# Height-to-Width Ratio: 0.39375
# Number of Parts: 2
# Average Width of Letters: 160.0
# Average Height of Letters: 31.0
# Average Width of Letters: 160.0
# Average Height of Letters: 31.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 212.8202
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 439.26993333333337
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_88.jpg
# Height-to-Width Ratio: 0.3577981651376147
# Number of Parts: 2
# Average Width of Letters: 218.0
# Average Height of Letters: 39.0
# Average Width of Letters: 218.0
# Average Height of Letters: 39.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 96.12366666666667
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 424.14566666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_89.jpg
# Height-to-Width Ratio: 0.3125
# Number of Parts: 2
# Average Width of Letters: 192.0
# Average Height of Letters: 30.0
# Average Width of Letters: 63.75
# Average Height of Letters: 14.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 143.5248
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 413.1873333333333
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_9.jpg
# Height-to-Width Ratio: 0.26506024096385544
# Number of Parts: 2
# Average Width of Letters: 126.5
# Average Height of Letters: 19.5
# Average Width of Letters: 249.0
# Average Height of Letters: 33.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 190.7164
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 420.7074666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_90.jpg
# Height-to-Width Ratio: 0.3901098901098901
# Number of Parts: 2
# Average Width of Letters: 182.0
# Average Height of Letters: 35.0
# Average Width of Letters: 40.2
# Average Height of Letters: 10.2
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 117.31673333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 419.3206
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_91.jpg
# Height-to-Width Ratio: 0.39880952380952384
# Number of Parts: 2
# Average Width of Letters: 89.0
# Average Height of Letters: 17.5
# Average Width of Letters: 38.6
# Average Height of Letters: 9.6
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 202.23196666666666
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 431.3526333333333
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_92.jpg
# Height-to-Width Ratio: 0.23481781376518218
# Number of Parts: 2
# Average Width of Letters: 69.75
# Average Height of Letters: 17.0
# Average Width of Letters: 161.0
# Average Height of Letters: 22.5
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 167.46896666666666
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 330.8232333333333
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_93.jpg
# Height-to-Width Ratio: 0.8793103448275862
# Number of Parts: 2
# Average Width of Letters: 58.0
# Average Height of Letters: 25.0
# Average Width of Letters: 21.2
# Average Height of Letters: 8.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 359.28636666666665
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 403.74570000000006
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_94.jpg
# Height-to-Width Ratio: 0.16030534351145037
# Number of Parts: 2
# Average Width of Letters: 78.83333333333333
# Average Height of Letters: 9.333333333333334
# Average Width of Letters: 107.0
# Average Height of Letters: 12.6
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 168.81983333333335
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 336.36396666666667
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_95.jpg
# Height-to-Width Ratio: 0.17981072555205047
# Number of Parts: 2
# Average Width of Letters: 160.5
# Average Height of Letters: 28.0
# Average Width of Letters: 55.5
# Average Height of Letters: 5.666666666666667
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 335.8408333333333
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 416.4559
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_96.jpg
# Height-to-Width Ratio: 0.2846153846153846
# Number of Parts: 2
# Average Width of Letters: 59.0
# Average Height of Letters: 10.2
# Average Width of Letters: 96.4
# Average Height of Letters: 13.8
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 114.50506666666666
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 323.726
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_97.jpg
# Height-to-Width Ratio: 0.26071428571428573
# Number of Parts: 2
# Average Width of Letters: 140.5
# Average Height of Letters: 36.0
# Average Width of Letters: 280.0
# Average Height of Letters: 36.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 258.9296
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 419.65560000000005
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_98.jpg
# Height-to-Width Ratio: 0.25595238095238093
# Number of Parts: 2
# Average Width of Letters: 76.6
# Average Height of Letters: 12.8
# Average Width of Letters: 336.0
# Average Height of Letters: 43.0
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 99.71786666666667
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 317.74519999999995
#
# Processing D:\AIML Internship\Task5_modified\cropped_signatures\Hussain\signature_99.jpg
# Height-to-Width Ratio: 0.3515151515151515
# Number of Parts: 2
# Average Width of Letters: 82.5
# Average Height of Letters: 29.0
# Average Width of Letters: 112.5
# Average Height of Letters: 20.5
# Signature Parameters: ['Angular', 'Angular']
# Average Width of Letters: 65.75
# Average Height of Letters: 10.75
# Average Width of Letters: 70.0
# Average Height of Letters: 10.5
# Comparison Score with signature_46.jpg: 212.6770666666667
# Average Width of Letters: 114.0
# Average Height of Letters: 19.5
# Average Width of Letters: 76.66666666666667
# Average Height of Letters: 16.333333333333332
# Comparison Score with signature_59.jpg: 418.186
#
# Best Match: sample images

# %%
#testing process

# %%
import os
import cv2

def preprocess_image(image_path, target_height, target_width):
    # Read the image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Unable to read image: {image_path}")
        return None
    
    # Resize the image to the target height and width
    resized_image = cv2.resize(image, (target_width, target_height))
    
    # Perform any additional preprocessing steps if needed
    
    return resized_image

def prepare_sample_images(sample_images_folder, target_height, target_width):
    sample_images = []
    for filename in os.listdir(sample_images_folder):
        image_path = os.path.join(sample_images_folder, filename)
        # Preprocess each sample image
        preprocessed_image = preprocess_image(image_path, target_height, target_width)
        if preprocessed_image is not None:
            sample_images.append(preprocessed_image)
    return sample_images

# Example usage:
sample_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample images"
target_height = 100  # Define the target height for resizing
target_width = 200   # Define the target width for resizing
sample_images = prepare_sample_images(sample_images_folder, target_height, target_width)
print(f"Number of sample images prepared: {len(sample_images)}")
# Out:
# Number of sample images prepared: 2

# %%
import os
import cv2

def crop_signature(image, crop_area):
    # Crop the signature area from the image
    x, y, w, h = crop_area
    cropped_image = image[y:y+h, x:x+w]
    return cropped_image

def preprocess_sample_images(sample_images_folder, crop_areas, target_height, target_width):
    preprocessed_samples = []
    for filename, crop_area in zip(os.listdir(sample_images_folder), crop_areas):
        image_path = os.path.join(sample_images_folder, filename)
        
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue
        
        # Crop the signature area
        cropped_image = crop_signature(image, crop_area)
        
        # Resize the image to the target height and width
        if cropped_image.size != 0:
            resized_image = cv2.resize(cropped_image, (target_width, target_height))
            
            # Perform any additional preprocessing steps if needed
            
            # Add the preprocessed image to the list
            preprocessed_samples.append(resized_image)
        else:
            print(f"Empty image: {image_path}")
    
    return preprocessed_samples

# Example usage:
sample_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample images"
crop_areas = [(100, 100, 200, 200), (150, 150, 250, 250), ...]  # Define crop areas for each sample image
target_height = 100  # Define the target height for resizing
target_width = 200   # Define the target width for resizing

preprocessed_samples = preprocess_sample_images(sample_images_folder, crop_areas, target_height, target_width)
print(f"Number of preprocessed sample images: {len(preprocessed_samples)}")
# Out:
# Empty image: D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample images\121.jpg
# Empty image: D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample images\132.jpg
# Number of preprocessed sample images: 0

# %%
import os
import cv2
from skimage.feature import hog
from skimage import exposure
import numpy as np

def preprocess_and_extract_features(sample_images_folder, crop_areas, target_height, target_width):
    preprocessed_samples = []
    features = []
    for filename, crop_area in zip(os.listdir(sample_images_folder), crop_areas):
        image_path = os.path.join(sample_images_folder, filename)
        
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue
        
        # Crop the signature area
        cropped_image = crop_signature(image, crop_area)
        
        # Check if the cropped image is empty
        if cropped_image.size == 0:
            print(f"Empty image after cropping: {image_path}")
            continue
        
        # Resize the image to the target height and width
        resized_image = cv2.resize(cropped_image, (target_width, target_height))
        
        # Extract HOG features from the resized image
        extracted_features = extract_hog_features(resized_image)
        
        # Add the preprocessed image and extracted features to the lists
        preprocessed_samples.append(resized_image)
        features.append(extracted_features)
    
    return preprocessed_samples, features


# Example usage:
sample_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample images"
crop_areas = [(100, 100, 200, 200), (150, 150, 250, 250), ...]  # Define crop areas for each sample image
target_height = 100  # Define the target height for resizing
target_width = 200   # Define the target width for resizing

preprocessed_samples, features = preprocess_and_extract_features(sample_images_folder, crop_areas, target_height, target_width)
print(f"Number of preprocessed sample images: {len(preprocessed_samples)}")
print(f"Number of extracted features: {len(features)}")
# Out:
# Empty image after cropping: D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample images\121.jpg
# Empty image after cropping: D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample images\132.jpg
# Number of preprocessed sample images: 0
# Number of extracted features: 0

# %%
import os
import cv2
import numpy as np
from skimage.feature import hog

def extract_stroke_features(image):
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    return features

def extract_shape_features(image):
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    shape_features = []
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        area = cv2.contourArea(contour)
        perimeter = cv2.arcLength(contour, True)
        shape_features = [aspect_ratio, area, perimeter]
    return shape_features

def extract_angle_features(image):
    # Calculate angle features (e.g., angles between strokes)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    lines = cv2.HoughLinesP(edges, 1, np.pi/180, threshold=100, minLineLength=100, maxLineGap=10)
    angle_features = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            angle = np.arctan2(y2 - y1, x2 - x1) * 180 / np.pi
            angle_features.append(angle)
    return angle_features

def extract_curvature_features(image):
    # Calculate curvature features
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    curvature_features = []
    if contours:
        for contour in contours:
            M = cv2.moments(contour)
            if M["m00"] != 0:
                cx = int(M["m10"] / M["m00"])
                cy = int(M["m01"] / M["m00"])
                cX, cY = cx, cy
                points = contour[:, 0]
                prev_point = points[0]
                total_distance = 0
                total_curvature = 0
                num_points = 0
                for point in points[1:]:
                    distance = np.linalg.norm(point - prev_point)
                    total_distance += distance
                    angle = np.arctan2(point[1] - prev_point[1], point[0] - prev_point[0])
                    curvature = np.abs(angle - prev_angle) / distance if num_points > 0 else 0
                    total_curvature += curvature
                    prev_point = point
                    prev_angle = angle
                    num_points += 1
                if num_points > 0:
                    mean_curvature = total_curvature / total_distance
                    curvature_features.append(mean_curvature)
    return curvature_features

def extract_features_from_images(sample_images_folder):
    features_list = []
    for filename in os.listdir(sample_images_folder):
        image_path = os.path.join(sample_images_folder, filename)
        
        # Extract label from filename
        label = os.path.splitext(filename)[0]
        
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue  # Skip this image if loading fails
        
        # Extract stroke features
        stroke_features = extract_stroke_features(image)
        
        # Extract shape features
        shape_features = extract_shape_features(image)
        
        # Extract angle features
        angle_features = extract_angle_features(image)
        
        # Extract curvature features
        curvature_features = extract_curvature_features(image)
        
        # Add features and label to the list
        features_dict = {
            "label": label,
            "stroke_features": stroke_features,
            "shape_features": shape_features,
            "angle_features": angle_features,
            "curvature_features": curvature_features
        }
        features_list.append(features_dict)
    
    return features_list

# Example usage:
sample_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample images"

features = extract_features_from_images(sample_images_folder)
print(f"Number of images processed: {len(features)}")

# Print features with labels
for feature_dict in features:
    label = feature_dict["label"]
    stroke_features = feature_dict["stroke_features"]
    shape_features = feature_dict["shape_features"]
    angle_features = feature_dict["angle_features"]
    curvature_features = feature_dict["curvature_features"]
    
    print(f"Label: {label}")
    print(f"Stroke Features: {stroke_features}")
    print(f"Shape Features: {shape_features}")
    print(f"Angle Features: {angle_features}")
    print(f"Curvature Features: {curvature_features}")
# Out:
# Number of images processed: 3
# Label: 121
# Stroke Features: [0.40614268 0.         0.         ... 0.04425043 0.11281691 0.19789395]
# Shape Features: [2.2386363636363638, 16970.0, 592.970562338829]
# Angle Features: []
# Curvature Features: [0.3610460357463227, 0.2733306592640722, 0.28524028774387056, 0.22354762001348605]
# Label: 132
# Stroke Features: [0.18077538 0.         0.         ... 0.02412324 0.01271407 0.        ]
# Shape Features: [4.407407407407407, 1372.0, 272.7695519924164]
# Angle Features: []
# Curvature Features: [0.16037005761779197, 0.15466054138795995, 0.16663398217033137, 0.4219698747315724, 0.1729485936257427]
# Label: 153
# Stroke Features: [0.33395118 0.06977021 0.01875551 ... 0.13697504 0.         0.        ]
# Shape Features: [4.068965517241379, 1499.0, 273.5979790687561]
# Angle Features: []
# Curvature Features: [0.30036166864038766, 0.3025478311424836]

# %%
import os
import cv2
import numpy as np
from skimage.feature import hog

def extract_stroke_features(image):
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    return features

def extract_shape_features(image):
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    shape_features = []
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        area = cv2.contourArea(contour)
        perimeter = cv2.arcLength(contour, True)
        shape_features = [aspect_ratio, area, perimeter]
    return shape_features

def extract_angle_features(image):
    # Calculate angle features (e.g., angles between strokes)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    lines = cv2.HoughLinesP(edges, 1, np.pi/180, threshold=100, minLineLength=100, maxLineGap=10)
    angle_features = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            angle = np.arctan2(y2 - y1, x2 - x1) * 180 / np.pi
            angle_features.append(angle)
    return angle_features

def extract_curvature_features(image):
    # Calculate curvature features
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    curvature_features = []
    if contours:
        for contour in contours:
            M = cv2.moments(contour)
            if M["m00"] != 0:
                cx = int(M["m10"] / M["m00"])
                cy = int(M["m01"] / M["m00"])
                cX, cY = cx, cy
                points = contour[:, 0]
                prev_point = points[0]
                total_distance = 0
                total_curvature = 0
                num_points = 0
                for point in points[1:]:
                    distance = np.linalg.norm(point - prev_point)
                    total_distance += distance
                    angle = np.arctan2(point[1] - prev_point[1], point[0] - prev_point[0])
                    curvature = np.abs(angle - prev_angle) / distance if num_points > 0 else 0
                    total_curvature += curvature
                    prev_point = point
                    prev_angle = angle
                    num_points += 1
                if num_points > 0:
                    mean_curvature = total_curvature / total_distance
                    curvature_features.append(mean_curvature)
    return curvature_features

def extract_features_from_images(sample_images_folder):
    features_list = []
    for filename in os.listdir(sample_images_folder):
        image_path = os.path.join(sample_images_folder, filename)
        
        # Extract label from filename
        label = os.path.splitext(filename)[0]
        
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue  # Skip this image if loading fails
        
        # Extract stroke features
        stroke_features = extract_stroke_features(image)
        
        # Extract shape features
        shape_features = extract_shape_features(image)
        
        # Extract angle features
        angle_features = extract_angle_features(image)
        
        # Extract curvature features
        curvature_features = extract_curvature_features(image)
        
        # Add features and label to the list
        features_dict = {
            "label": label,
            "stroke_features": stroke_features,
            "shape_features": shape_features,
            "angle_features": angle_features,
            "curvature_features": curvature_features
        }
        features_list.append(features_dict)
    
    return features_list

# Example usage:
sample_images_folder = rdataset_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain"


features = extract_features_from_images(sample_images_folder)
print(f"Number of images processed: {len(features)}")

# Print features with labels
for feature_dict in features:
    label = feature_dict["label"]
    stroke_features = feature_dict["stroke_features"]
    shape_features = feature_dict["shape_features"]
    angle_features = feature_dict["angle_features"]
    curvature_features = feature_dict["curvature_features"]
    
    print(f"Label: {label}")
    print(f"Stroke Features: {stroke_features}")
    print(f"Shape Features: {shape_features}")
    print(f"Angle Features: {angle_features}")
    print(f"Curvature Features: {curvature_features}")
# Out:
# Number of images processed: 88
# Label: 122
# Stroke Features: [0.24647277 0.         0.19918008 ... 0.25015971 0.29002008 0.        ]
# Shape Features: [2.0, 53.0, 33.31370830535889]
# Angle Features: []
# Curvature Features: [0.9759677134264297, 0.27538591252826544, 0.41993235156140035, 0.22954115633843172, 0.2900203585990963, 0.26528230349449095, 0.21901884606585334]
# Label: 123
# Stroke Features: [0.34430633 0.         0.         ... 0.32419013 0.         0.        ]
# Shape Features: [4.785714285714286, 1577.5, 304.18376553058624]
# Angle Features: []
# Curvature Features: [0.16004908545017452, 0.25191524824621314, 0.3493482052137768]
# Label: 124
# Stroke Features: [0.42678198 0.08928572 0.42678198 ... 0.05959882 0.14135101 0.19990052]
# Shape Features: [1.691358024691358, 10880.0, 432.0]
# Angle Features: []
# Curvature Features: [0.3521124130613778, 0.34662251029509666, 0.20105620675839506]
# Label: 125
# Stroke Features: [0.39019667 0.06032594 0.11446043 ... 0.22262799 0.         0.        ]
# Shape Features: [3.7142857142857144, 185.5, 115.35533845424652]
# Angle Features: []
# Curvature Features: [0.23554412985900003, 0.30659059446094217, 0.26573684158316907, 0.31210048736542995, 0.1870066264077826, 0.24071140934708268]
# Label: 126
# Stroke Features: [0.35098322 0.16516471 0.         ... 0.0385943  0.00813639 0.        ]
# Shape Features: [5.65, 1086.5, 250.87005722522736]
# Angle Features: []
# Curvature Features: [0.12098525202529213, 0.6464688261670196, 0.23142328166373397, 0.12456478331410205, 0.15976461219719432]
# Label: 127
# Stroke Features: [0.28099869 0.16605824 0.21004888 ... 0.2125469  0.         0.        ]
# Shape Features: [4.042553191489362, 8694.0, 470.0]
# Angle Features: []
# Curvature Features: [0.16038902139560682, 0.2533779943559706, 0.2853660211458454, 0.2230486462169004]
# Label: 128
# Stroke Features: [0.35036702 0.08438293 0.         ... 0.         0.         0.        ]
# Shape Features: [2.7540983606557377, 10020.0, 454.0]
# Angle Features: [-14.036243467926477]
# Curvature Features: [0.19569199120835892, 0.679191282749203, 0.2858823402494399, 0.5276140673400748, 0.2112053387656866, 0.22119300526208188]
# Label: 129
# Stroke Features: [0.08344126 0.00400282 0.00772015 ... 0.         0.         0.        ]
# Shape Features: [3.0, 34.5, 52.38477599620819]
# Angle Features: []
# Curvature Features: [0.32799127861309463, 0.26349632495527925, 0.326441809573127, 0.20596450839669578, 0.2916963791652105, 0.21372119256360245]
# Label: 130
# Stroke Features: [0.35541226 0.         0.26280156 ... 0.16949117 0.         0.        ]
# Shape Features: [2.4464285714285716, 7480.0, 382.0]
# Angle Features: [-7.650650955359412]
# Curvature Features: [0.28453463305464477, 0.22889119310561798]
# Label: 131
# Stroke Features: [0.         0.         0.         ... 0.02480606 0.01166007 0.00658396]
# Shape Features: [8.333333333333334, 94.0, 154.62741661071777]
# Angle Features: []
# Curvature Features: [0.12271807487438612, 0.0764894715075362, 0.33305374648057245]
# Label: 133
# Stroke Features: [0.14200465 0.         0.         ... 0.17525256 0.         0.        ]
# Shape Features: [4.88, 1438.0, 275.94112491607666]
# Angle Features: []
# Curvature Features: [0.33630816955660475, 0.2740634978469492, 0.476391755027713, 0.23067934976998525]
# Label: 134
# Stroke Features: [0.04449652 0.00877733 0.00361062 ... 0.01776127 0.0300448  0.01437448]
# Shape Features: [7.0, 39.5, 101.55634891986847]
# Angle Features: []
# Curvature Features: [0.1037282483203787, 1.0727544889495058, 0.3648625019032968, 0.30342314432037365, 0.19161825849938713]
# Label: 135
# Stroke Features: [0.06555467 0.         0.         ... 0.00337859 0.00267101 0.01060018]
# Shape Features: [5.761904761904762, 1051.0, 268.2842707633972]
# Angle Features: [-9.027612950715096]
# Curvature Features: [0.12687222393959594, 0.2885252024086792, 0.5194404744042401, 0.8535071045221778, 0.2666721607028814]
# Label: 136
# Stroke Features: [0.39444092 0.         0.         ... 0.05361333 0.         0.        ]
# Shape Features: [2.774193548387097, 9451.5, 1086.5168062448502]
# Angle Features: [-13.025840646870822, -13.091893064346847]
# Curvature Features: [0.4475682724092405, 0.233992354731563, 0.26647624907294565, 0.21733188422936875]
# Label: 137
# Stroke Features: [0.11725957 0.00905112 0.00632133 ... 0.         0.         0.        ]
# Shape Features: [3.4705882352941178, 128.5, 129.8406196832657]
# Angle Features: []
# Curvature Features: [0.22627226508346432, 0.22256792724671814, 0.41452591750985507, 0.2491282997529244, 0.1676308830468172]
# Label: 138
# Stroke Features: [0.22815833 0.         0.         ... 0.02204064 0.         0.        ]
# Shape Features: [6.0588235294117645, 210.0, 217.25483322143555]
# Angle Features: [-9.027612950715096]
# Curvature Features: [0.12733856865165624, 0.3249445333338479, 0.2989476605527588, 0.24200996219229662]
# Label: 139
# Stroke Features: [0.37419258 0.0598942  0.37419258 ... 0.07216963 0.         0.        ]
# Shape Features: [2.8360655737704916, 9397.0, 951.8477598428726]
# Angle Features: [-10.37584492005105]
# Curvature Features: [0.38800291483109883, 0.2716573881436034, 0.2803532668656635, 0.31829527197500534]
# Label: 140
# Stroke Features: [0.21378335 0.05106995 0.01614973 ... 0.         0.00380225 0.        ]
# Shape Features: [8.0, 0.0, 14.0]
# Angle Features: []
# Curvature Features: [0.24590075793626465, 0.22610013149966712, 0.4384998692697752]
# Label: 141
# Stroke Features: [0.12484837 0.         0.         ... 0.03048394 0.         0.        ]
# Shape Features: [1.0, 2.5, 6.2426406145095825]
# Angle Features: []
# Curvature Features: [0.07821261697553206, 0.15619263314910442, 0.10678088602030153, 0.12063598055378127, 0.5235987755982987, 0.48679368590371225, 0.20545855114585546]
# Label: 142
# Stroke Features: [0.33866082 0.15205018 0.09616497 ... 0.09542336 0.03017551 0.0556409 ]
# Shape Features: [5.230769230769231, 51.0, 143.94112491607666]
# Angle Features: [-10.091057238888915]
# Curvature Features: [0.3559161680993671, 0.25002387838140355]
# Label: 143
# Stroke Features: [0.36191671 0.         0.07050067 ... 0.01861791 0.00294375 0.        ]
# Shape Features: [4.6521739130434785, 1027.0, 243.11269783973694]
# Angle Features: []
# Curvature Features: [0.18499433424371833, 0.1505243888942577, 0.5931114404758282, 0.2904264121707268]
# Label: 144
# Stroke Features: [0.         0.         0.         ... 0.02438277 0.01926863 0.00190695]
# Shape Features: [9.928571428571429, 772.5, 294.3847759962082]
# Angle Features: [-5.019853642019552]
# Curvature Features: [0.10515090510150654, 0.8436496301653227, 0.3837606981978986, 0.28293355647816537, 0.3782340614550229]
# Label: 145
# Stroke Features: [0.09620211 0.02359984 0.00516744 ... 0.         0.         0.        ]
# Shape Features: [4.25, 104.0, 146.42640614509583]
# Angle Features: []
# Curvature Features: [0.2952527978936164, 0.20003020156781776, 0.2997801279480867]
# Label: 146
# Stroke Features: [0.         0.         0.10641911 ... 0.03342205 0.         0.        ]
# Shape Features: [1.955223880597015, 7707.0, 796.1076451539993]
# Angle Features: []
# Curvature Features: [1.1177865696801557, 0.25727255885450057, 0.2817554549480836]
# Label: 147
# Stroke Features: [0.1774753  0.         0.10457833 ... 0.02513855 0.01490533 0.01405288]
# Shape Features: [1.0, 0.0, 0.0]
# Angle Features: []
# Curvature Features: [0.3770556737237071, 0.19512124197283615, 0.2967338755842363]
# Label: 148
# Stroke Features: [0.30775772 0.         0.         ... 0.00427072 0.00433476 0.00126728]
# Shape Features: [10.75, 35.0, 88.14213538169861]
# Angle Features: [-3.945186229037563]
# Curvature Features: [0.28248378398785084, 0.29637185266001215, 0.2440207956733815]
# Label: 149
# Stroke Features: [0.04001669 0.00854778 0.00708232 ... 0.03692804 0.00611428 0.        ]
# Shape Features: [2.0634920634920637, 6838.0, 871.8477592468262]
# Angle Features: []
# Curvature Features: [0.1805857265470501, 0.27366599879729897, 0.2738896223535809, 0.2932319097487068]
# Label: 150
# Stroke Features: [0.15174944 0.         0.         ... 0.10765346 0.         0.        ]
# Shape Features: [4.0, 154.5, 191.9827550649643]
# Angle Features: []
# Curvature Features: [0.18906816828745648, 0.15843606510584005, 0.33011642640185157, 0.2689718187937361]
# Label: 151
# Stroke Features: [0.50507627 0.         0.         ... 0.         0.         0.        ]
# Shape Features: [2.8153846153846156, 10726.5, 929.4629838466644]
# Angle Features: []
# Curvature Features: [0.24910462616768195, 0.2470564519128367]
# Label: 154
# Stroke Features: [0.0803642  0.         0.01894202 ... 0.38214868 0.08780042 0.        ]
# Shape Features: [2.1176470588235294, 192.5, 90.18376541137695]
# Angle Features: []
# Curvature Features: [0.1659048875758091, 0.350650848219661, 0.27414936190392686, 0.30273336205793533, 0.3167094714978188, 0.5046102437753243, 0.7465552787096599, 0.3063344508087579, 0.23531108102536968, 0.21243227928644032]
# Label: 155
# Stroke Features: [0.2754416  0.         0.21640736 ... 0.0489344  0.03868604 0.        ]
# Shape Features: [1.0, 0.0, 0.0]
# Angle Features: []
# Curvature Features: [0.34627197194012177, 0.3265889423381922]
# Label: 156
# Stroke Features: [0.30718334 0.         0.37151612 ... 0.02203755 0.01025472 0.01738334]
# Shape Features: [5.8125, 538.0, 196.42640614509583]
# Angle Features: [-8.833414651219002]
# Curvature Features: [0.6595863150528856, 0.2328727049468767, 0.18230895346192313, 0.27975146650046634]
# Label: 157
# Stroke Features: [0.06346369 0.         0.02761575 ... 0.08759358 0.         0.        ]
# Shape Features: [2.9130434782608696, 6642.0, 498.16652059555054]
# Angle Features: [-18.74134044519272]
# Curvature Features: [0.6193269751685269, 0.25833309210350863, 0.26856108615081764, 0.3017610215238602]
# Label: 158
# Stroke Features: [0.06208349 0.         0.04389966 ... 0.281115   0.         0.        ]
# Shape Features: [2.511111111111111, 473.5, 261.0365777015686]
# Angle Features: []
# Curvature Features: [0.329315043073886, 0.19453491799458553, 0.3127980052837226, 0.2973041103997845, 0.2900812782878092]
# Label: 159
# Stroke Features: [0.         0.         0.         ... 0.11590673 0.06872424 0.03239692]
# Shape Features: [3.511627906976744, 975.5, 336.5512965917587]
# Angle Features: [-12.470461721668892]
# Curvature Features: [0.3304692164065139, 0.23315054433723711, 0.1818170664856184, 0.15671245777484477, 0.25219139011824965]
# Label: 160
# Stroke Features: [0.08911322 0.02094611 0.01487033 ... 0.13679164 0.         0.        ]
# Shape Features: [4.388888888888889, 245.0, 170.08326029777527]
# Angle Features: []
# Curvature Features: [0.17256385381862657, 0.2110901590824128, 0.5617879264981437, 0.31362083396193424, 0.4468368826800236, 0.2879989324883647]
# Label: 161
# Stroke Features: [0.36265589 0.01178012 0.00507304 ... 0.00285481 0.         0.        ]
# Shape Features: [0.3333333333333333, 0.0, 4.0]
# Angle Features: []
# Curvature Features: [0.2929670670708165, 0.526172351554984, 0.29318467529587516, 0.2697490024351639]
# Label: 162
# Stroke Features: [0.30092724 0.06954254 0.02199128 ... 0.14034636 0.14793806 0.        ]
# Shape Features: [3.5434782608695654, 7280.5, 418.2426406145096]
# Angle Features: []
# Curvature Features: [0.2301180657803828, 0.437157340389337, 0.6583088377703542, 0.45572452864850993, 0.3084634833726088]
# Label: 163
# Stroke Features: [0.33043324 0.03811871 0.09643354 ... 0.0220609  0.05232202 0.04932968]
# Shape Features: [3.0638297872340425, 6578.0, 378.0]
# Angle Features: []
# Curvature Features: [0.2024370435048623, 0.3529683847831557, 0.7275501303423165, 0.4733969062861105, 0.18347830780267657, 0.44016073791113053]
# Label: 164
# Stroke Features: [0.25526463 0.21077037 0.07225165 ... 0.07176162 0.         0.        ]
# Shape Features: [2.5686274509803924, 6500.0, 360.0]
# Angle Features: []
# Curvature Features: [0.26827582405749617, 0.4086474603004726, 0.4893155439301061, 0.11821922801434813, 0.40959397140667997, 0.27220000454053483, 0.14295072079095503, 0.36814407995063]
# Label: 165
# Stroke Features: [0.38852967 0.07766954 0.         ... 0.00390631 0.01235285 0.        ]
# Shape Features: [2.6166666666666667, 8622.0, 725.1959577798843]
# Angle Features: []
# Curvature Features: [0.20001852809552378, 0.1664975823194237, 0.5451928115743234, 0.4396693886691581, 0.30532283860060855]
# Label: 166
# Stroke Features: [0.         0.         0.         ... 0.28406749 0.07966272 0.05633005]
# Shape Features: [2.457627118644068, 8352.0, 404.0]
# Angle Features: []
# Curvature Features: [0.9125886986875175, 0.181247959203713, 0.17041479989231886, 0.34978210938665977, 0.5956126801185111, 0.31867196096913125, 0.1617949056095626]
# Label: 167
# Stroke Features: [0.35259493 0.         0.06404796 ... 0.01469883 0.01071975 0.00986028]
# Shape Features: [2.7777777777777777, 3465.0, 268.0]
# Angle Features: []
# Curvature Features: [0.899014600517074, 0.22448529642698659, 0.4196371217331626, 0.38157296319849904, 0.37292814636473426, 0.3482533511311733]
# Label: 168
# Stroke Features: [0.1510509  0.04222001 0.08010683 ... 0.02072645 0.         0.        ]
# Shape Features: [3.019230769230769, 7904.0, 434.97056245803833]
# Angle Features: []
# Curvature Features: [0.2481162922465282, 0.34041912058530627, 0.3907782272127567, 0.3630408485051964]
# Label: 169
# Stroke Features: [0.04261882 0.02555214 0.03074638 ... 0.11617087 0.05828297 0.        ]
# Shape Features: [2.9464285714285716, 8434.5, 726.5269113779068]
# Angle Features: [0.0]
# Curvature Features: [0.07108666955779983, 0.3930154659930904, 0.2208203478044551, 0.35149351422450975, 0.27467661007749666, 0.2532180340892118]
# Label: 170
# Stroke Features: [0.01651022 0.         0.02334897 ... 0.05800977 0.04586076 0.        ]
# Shape Features: [2.9285714285714284, 8922.0, 455.3137083053589]
# Angle Features: []
# Curvature Features: [0.19380561160311705, 0.2862455637688639, 0.3395151873656349, 0.1465439912912369, 0.33662904388994874]
# Label: 171
# Stroke Features: [0.17379684 0.10598769 0.27034253 ... 0.03690679 0.02244335 0.01217688]
# Shape Features: [1.9423076923076923, 5028.0, 348.1421353816986]
# Angle Features: []
# Curvature Features: [0.23654917475823609, 0.8248664094961193, 0.6086875209663869, 1.6982596010881397, 0.3314758190368187, 0.30154453248316054, 0.4911361020657925, 0.16645112969730225, 0.22330482990128958]
# Label: 172
# Stroke Features: [0.08356726 0.         0.11818195 ... 0.11683306 0.14778343 0.20899732]
# Shape Features: [3.3207547169811322, 8876.5, 563.0121924877167]
# Angle Features: []
# Curvature Features: [0.294872582539904, 0.22410768984307228, 0.29315333019134066, 0.2008693224884618, 0.3975998690327407, 0.2802274318422061, 0.28039092005265215]
# Label: 173
# Stroke Features: [0.31192866 0.         0.03356346 ... 0.00321173 0.00943713 0.00413635]
# Shape Features: [0.8333333333333334, 14.5, 15.071067571640015]
# Angle Features: []
# Curvature Features: [0.16858812925695876, 0.3733631947890047, 0.14387892947731865, 0.150075792858013, 0.12323218774662806, 0.14211715334575023]
# Label: 174
# Stroke Features: [0.06552791 0.0131744  0.01484596 ... 0.         0.00751419 0.01847398]
# Shape Features: [2.697674418604651, 4822.5, 313.41421353816986]
# Angle Features: []
# Curvature Features: [0.9759677134264297, 0.5261426983758049, 0.5178393536174337, 0.31022059452596756, 0.5327564596298519, 0.25163808545337424, 0.39393170006293815, 0.2193844251334504]
# Label: 175
# Stroke Features: [0.1195759  0.00323095 0.00408687 ... 0.13462597 0.05321559 0.        ]
# Shape Features: [2.4074074074074074, 6837.0, 364.0]
# Angle Features: []
# Curvature Features: [0.3016585700275364, 0.4117702130052611, 0.2269678267718719]
# Label: 176
# Stroke Features: [0.2245589  0.         0.2920752  ... 0.26963373 0.         0.21623907]
# Shape Features: [2.25, 4874.5, 418.5269113779068]
# Angle Features: []
# Curvature Features: [0.30229810461736145, 0.10334128777889916, 0.22844169573552345, 0.29036054438991543, 0.17486774802784702, 0.18536000172921574]
# Label: 177
# Stroke Features: [0.03859304 0.00766656 0.00295666 ... 0.00839793 0.         0.        ]
# Shape Features: [5.3076923076923075, 228.0, 145.94112491607666]
# Angle Features: []
# Curvature Features: [0.1686774840771985, 0.1760599081012639, 0.4837333536229444, 0.3772730039998202, 0.20287353354191862, 0.16315514726473465]
# Label: 178
# Stroke Features: [0.04584456 0.         0.         ... 0.08983707 0.         0.        ]
# Shape Features: [2.74, 6664.0, 370.0]
# Angle Features: []
# Curvature Features: [0.3384786531750336, 0.14864457581897894, 0.26896354388007904, 0.40882491500299195, 0.36707604775799335]
# Label: 179
# Stroke Features: [0.35001901 0.         0.19439531 ... 0.15158807 0.06349599 0.        ]
# Shape Features: [2.7551020408163267, 6268.5, 471.8406196832657]
# Angle Features: []
# Curvature Features: [0.22319166186312478, 0.30412130154300887, 0.26043116038977027, 0.3483524694081229]
# Label: 180
# Stroke Features: [0.12101227 0.         0.         ... 0.07937807 0.03137694 0.        ]
# Shape Features: [3.406779661016949, 11459.5, 601.6984843015671]
# Angle Features: [-6.296818718984405, -6.102779653655784]
# Curvature Features: [0.24785423644473295, 0.1595620650846478, 0.31097842668021525, 0.3664185238964095, 0.5761066277046195, 0.12353415151616898, 0.2605139361771406]
# Label: 181
# Stroke Features: [0.29015793 0.         0.16343066 ... 0.13648421 0.08092519 0.        ]
# Shape Features: [4.7, 538.0, 202.9116872549057]
# Angle Features: []
# Curvature Features: [0.5158921211711247, 0.1172594039928087, 0.4387066409242546, 0.061948937708793436, 0.4717658900026829, 0.2940570009442924, 0.27227731321901866, 0.22736580073248996]
# Label: 182
# Stroke Features: [0.23076287 0.         0.04662114 ... 0.01497245 0.         0.        ]
# Shape Features: [1.9803921568627452, 4341.5, 665.1787127256393]
# Angle Features: []
# Curvature Features: [0.23853836577235593, 0.37706721065756715, 0.3076723214983449, 0.2668790983829227]
# Label: 183
# Stroke Features: [0.23076287 0.         0.04662114 ... 0.00610585 0.00237681 0.0020846 ]
# Shape Features: [1.9807692307692308, 4535.0, 680.5929262638092]
# Angle Features: []
# Curvature Features: [0.26171765467789226, 0.37706721065756715, 0.3076723214983449, 0.2668790983829227]
# Label: 184
# Stroke Features: [0.3427059  0.29324454 0.33383543 ... 0.0227842  0.04232885 0.04029174]
# Shape Features: [2.9482758620689653, 9631.5, 478.72792184352875]
# Angle Features: []
# Curvature Features: [0.3110102610994037, 0.11552595831716647, 0.19814191943453452, 0.1994455152880006]
# Label: 185
# Stroke Features: [0.04584276 0.02288572 0.0058398  ... 0.01901739 0.01879321 0.03837878]
# Shape Features: [2.611111111111111, 6299.5, 869.4629837274551]
# Angle Features: []
# Curvature Features: [0.27577258652606895, 0.5710129530360267, 0.2685050442646474, 0.14716185666803877, 0.2609897826939019]
# Label: 186
# Stroke Features: [0.29030146 0.         0.11455857 ... 0.01994278 0.0048196  0.0102239 ]
# Shape Features: [2.4791666666666665, 5546.0, 330.0]
# Angle Features: []
# Curvature Features: [0.28401029728541854, 0.1712702904235017]
# Label: 187
# Stroke Features: [0.06466163 0.         0.         ... 0.         0.         0.        ]
# Shape Features: [2.7254901960784315, 6674.5, 512.6690467596054]
# Angle Features: []
# Curvature Features: [0.2624721454930563, 0.7180216528408673, 0.05234569384404267, 0.6160633211477, 0.36332792163230604, 0.4744013013481152, 0.20255702457185149, 0.4707349593477169]
# Label: 188
# Stroke Features: [0.3096546  0.         0.09841689 ... 0.09474336 0.05608667 0.02195698]
# Shape Features: [3.4150943396226414, 9187.0, 577.5979790687561]
# Angle Features: []
# Curvature Features: [0.11771463399541479, 0.19738181876404756, 0.21964419099564933, 0.22929619029412637]
# Label: 189
# Stroke Features: [0.27916199 0.01918609 0.03640305 ... 0.1721535  0.02850393 0.18573859]
# Shape Features: [1.8, 22.0, 20.485281109809875]
# Angle Features: []
# Curvature Features: [0.4896588943200853, 0.19055509678953525, 0.2961961744018027, 0.21948150372219083]
# Label: 190
# Stroke Features: [0.12116595 0.         0.         ... 0.22851089 0.24305836 0.20131549]
# Shape Features: [4.116279069767442, 7392.0, 436.0]
# Angle Features: []
# Curvature Features: [0.94805944896852, 0.4312539901375873, 0.694027770302063, 0.26485007412064676, 0.22079532748488115, 0.11835032766183297, 0.19933357915787064, 0.21648076379556488]
# Label: 191
# Stroke Features: [0.20633594 0.02545817 0.1610116  ... 0.11781141 0.11642263 0.06585858]
# Shape Features: [4.444444444444445, 98.0, 85.79898953437805]
# Angle Features: []
# Curvature Features: [0.94805944896852, 0.4312539901375873, 0.21955396934247978, 0.30631983943075386, 0.20025068932828505, 0.13592211726498113, 0.42350540054275637, 0.1513194963163476, 0.187282122645392]
# Label: 192
# Stroke Features: [0.10243297 0.         0.         ... 0.01447185 0.         0.        ]
# Shape Features: [3.7551020408163267, 8784.0, 462.0]
# Angle Features: []
# Curvature Features: [0.201954200045195, 0.6141880114411227, 0.21330989765443417, 0.22656137304415924]
# Label: 193
# Stroke Features: [0.31468349 0.07456227 0.1178933  ... 0.31716688 0.         0.        ]
# Shape Features: [1.0, 0.0, 0.0]
# Angle Features: []
# Curvature Features: [0.10995574287564276, 0.6921569237351011, 0.11728061600950067, 0.2326907930966641, 0.1899930655412525, 0.2002208300424365]
# Label: 194
# Stroke Features: [0.27120988 0.         0.11314744 ... 0.20317535 0.03569427 0.        ]
# Shape Features: [1.2727272727272727, 85.0, 40.14213538169861]
# Angle Features: []
# Curvature Features: [0.3298684871203395, 0.3086551443733947, 0.1729874056952117, 0.2941728509567704, 0.16362461737446837, 0.3612691596406082, 0.5207740921309088, 0.2916077585711951, 0.5921933187393925, 0.25927050476229585]
# Label: 195
# Stroke Features: [0.35246737 0.         0.         ... 0.29019379 0.         0.        ]
# Shape Features: [2.0317460317460316, 7874.0, 378.0]
# Angle Features: []
# Curvature Features: [0.26429260555468415, 0.43136201628411225, 0.28836629032615935]
# Label: 196
# Stroke Features: [0.31127899 0.         0.0652284  ... 0.0940478  0.         0.        ]
# Shape Features: [3.38, 8010.5, 614.3259009122849]
# Angle Features: []
# Curvature Features: [0.5922098044963047, 0.11795920724203551, 0.12046290098792704, 0.350837935560254, 0.1974063070583329, 0.2703609813060423, 0.26292619648419135]
# Label: 197
# Stroke Features: [0.07593508 0.04631147 0.00398114 ... 0.22703338 0.25886295 0.12179541]
# Shape Features: [3.0, 185.5, 113.84061968326569]
# Angle Features: []
# Curvature Features: [0.34890955668405593, 0.3660839991193405, 0.3346719226669065, 0.24329763035035556, 0.26285116955367066]
# Label: 198
# Stroke Features: [0.02671961 0.01007406 0.01285917 ... 0.02962765 0.02482038 0.01755066]
# Shape Features: [2.6136363636363638, 4902.0, 314.0]
# Angle Features: []
# Curvature Features: [0.24990866201331868, 0.14412908160057133, 0.3862938777664152, 0.20835529804053565, 0.2044817429381594, 0.17342156169257647]
# Label: 199
# Stroke Features: [0.33255718 0.         0.03710135 ... 0.1121747  0.04434095 0.        ]
# Shape Features: [3.6808510638297873, 7123.0, 965.7888842821121]
# Angle Features: []
# Curvature Features: [0.28187509871444416, 0.2922289071639801, 0.5286997877766149, 0.39478044413939734, 0.24352912068989546, 0.2785834690869315, 0.19728526390073456]
# Label: 200
# Stroke Features: [0.39769343 0.26638065 0.06738957 ... 0.02635433 0.         0.00841858]
# Shape Features: [2.6792452830188678, 7179.5, 495.3553384542465]
# Angle Features: []
# Curvature Features: [0.26076478603561903, 0.1916269372742533, 0.2646941753220917]
# Label: 201
# Stroke Features: [0.28256285 0.         0.19897339 ... 0.25115082 0.25043642 0.        ]
# Shape Features: [1.0, 0.0, 0.0]
# Angle Features: []
# Curvature Features: [0.39520543107876926, 1.0630783470323464, 0.5643015400383948, 0.22328509566706975, 0.386714244984613, 0.3010495922545047, 0.26289505622213616, 0.21943614933943284]
# Label: 202
# Stroke Features: [0.26079089 0.         0.08714138 ... 0.15787263 0.         0.        ]
# Shape Features: [2.660377358490566, 7280.0, 384.0]
# Angle Features: []
# Curvature Features: [0.22884561089261143, 0.27123175747927164, 0.3041795141884641, 0.18745342753762653]
# Label: 203
# Stroke Features: [0.17429073 0.         0.         ... 0.25711121 0.07432857 0.03503882]
# Shape Features: [2.3424657534246576, 11951.0, 659.2548331022263]
# Angle Features: [-17.062857173461396]
# Curvature Features: [0.31404028787221805, 0.3409889394715578, 0.1898479036834189]
# Label: 204
# Stroke Features: [0.29237286 0.07363018 0.06985172 ... 0.05404451 0.01758971 0.04715941]
# Shape Features: [4.944444444444445, 518.0, 192.08326017856598]
# Angle Features: []
# Curvature Features: [0.7853981633974483, 0.15971114469783665, 0.4955778312113815, 0.28787009029567284, 0.19972097833526617, 0.2820726674649281]
# Label: 205
# Stroke Features: [0.229119   0.         0.         ... 0.09695483 0.03832476 0.        ]
# Shape Features: [2.0, 0.0, 2.0]
# Angle Features: []
# Curvature Features: [0.3097852185557351, 0.21386424752885308, 0.4165653409426318, 0.189803828994938, 0.2958181695343275, 0.24566828698992216]
# Label: 206
# Stroke Features: [0.10120194 0.03232777 0.04089176 ... 0.25988505 0.04109144 0.17433621]
# Shape Features: [2.0, 0.0, 2.0]
# Angle Features: []
# Curvature Features: [0.24938726686217924, 0.38729376326823456, 0.20481322447830935]
# Label: 207
# Stroke Features: [0.08788008 0.         0.20713531 ... 0.03733746 0.00977005 0.        ]
# Shape Features: [7.4, 43.0, 75.31370830535889]
# Angle Features: []
# Curvature Features: [0.15394011980442326, 0.1886847408300135, 0.1867136229397437, 0.30261487127238623]
# Label: 208
# Stroke Features: [0.32724732 0.06192967 0.04497817 ... 0.03347786 0.         0.        ]
# Shape Features: [3.6666666666666665, 301.5, 169.15432798862457]
# Angle Features: []
# Curvature Features: [0.18933864400313144, 0.3795773736994478, 0.24674996025402507, 0.528864083701674]
# Label: 209
# Stroke Features: [0.09968239 0.02786208 0.15859372 ... 0.10533002 0.16217891 0.19420922]
# Shape Features: [1.0, 0.0, 0.0]
# Angle Features: []
# Curvature Features: [0.23927951436057604, 0.29827648702260073, 0.3617146639525889, 0.3243451399280207]
# Label: 210
# Stroke Features: [0.30098192 0.         0.11359448 ... 0.22882074 0.08349171 0.03935837]
# Shape Features: [3.0, 0.0, 4.0]
# Angle Features: []
# Curvature Features: [0.19658242761365247, 0.16933511724698627, 0.3174669763156338, 0.2078529276141468, 0.08943469703953039, 0.25617066729950916]
# Label: 211
# Stroke Features: [0.20076475 0.07347428 0.02185727 ... 0.01259194 0.02840975 0.01964062]
# Shape Features: [2.025, 3120.0, 238.0]
# Angle Features: []
# Curvature Features: [0.6460231675055526, 0.4071202609387189, 0.5239079105017148, 0.21734943606254628, 0.22678530208131972, 0.21608388627768876]
# Label: 212
# Stroke Features: [0.32164591 0.08082508 0.20447307 ... 0.16216227 0.20512085 0.        ]
# Shape Features: [3.08955223880597, 13549.0, 567.798989534378]
# Angle Features: []
# Curvature Features: [0.3450566941914788, 0.3673076349050843, 0.41794951264950236, 0.2626899596516804, 0.3096914372392062, 0.3078677127499736, 0.30088002137558256]

# %%
#Training Code:
import os
import cv2
import pandas as pd
import numpy as np
import math

def find_centroid(image):
    # Function to find centroid of an image
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)
    points = np.argwhere(binary_image == 0)
    mean_x = int(np.mean(points[:, 1]))
    mean_y = int(np.mean(points[:, 0]))
    return (mean_x, mean_y)

def find_slant_angle(centroid_left, centroid_right):
    # Function to find slant angle between two centroids
    delta_x = centroid_right[0] - centroid_left[0]
    delta_y = centroid_right[1] - centroid_left[1]
    angle_radians = math.atan2(delta_y, delta_x)
    angle_degrees = math.degrees(angle_radians)
    return angle_degrees

def divide_image_and_classify(image, num_parts, output_folder):
    # Function to divide image into parts and classify each part
    height, length = image.shape[:2]
    part_length = length // num_parts
    part_classes = []

    for i in range(num_parts):
        start_col = i * part_length
        end_col = (i + 1) * part_length

        cropped_image = image[:, start_col:end_col]

        part_filename = f"part_{i + 1}.png"
        part_path = os.path.join(output_folder, part_filename)
        cv2.imwrite(part_path, cropped_image)

        part_classification = classify_sign(cropped_image)
        print(f"{part_filename} - Classification: {part_classification}")

        part_classes.append(part_classification)

    overall_skill = "Good" if all(part_class == part_classes[0] for part_class in part_classes) else "Not Good"

    return part_classes, overall_skill

def classify_sign(image):
    # Function to classify the sign based on its characteristics
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, thresholded = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(thresholded, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    aspect_ratios = [cv2.boundingRect(contour)[2] / cv2.boundingRect(contour)[3] for contour in contours]
    edges = cv2.Canny(image, 50, 150)
    contours_canny, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    aspect_ratios_canny = [cv2.boundingRect(contour)[2] / cv2.boundingRect(contour)[3] for contour in contours_canny]
    all_aspect_ratios = aspect_ratios + aspect_ratios_canny

    classification = classify_combined_aspect_ratios(all_aspect_ratios)

    return classification

def classify_combined_aspect_ratios(aspect_ratios):
    # Function to classify the sign based on combined aspect ratios
    round_threshold = 0.8
    angular_threshold = 1.2

    if all(ratio < round_threshold for ratio in aspect_ratios):
        return "Eyed"
    elif any(ratio > angular_threshold for ratio in aspect_ratios):
        return "Angular"
    else:
        return "Round"

def print_and_save_signature_dimensions(folder_path, output_excel_path, output_folder):
    # Function to process images in the given folder and save results
    dimensions_data = {
        'File Name': [],
        'Length': [],
        'Height': [],
        'Ratio (Length/Height)': [],
        'Integer Ratio': [],
        'Sign Classification': [],
        'Overall Skill': [],
        'Centroid X': [],
        'Centroid Y': [],
        'Slant Angle': []
    }

    for filename in os.listdir(folder_path):
        if filename.endswith(('.jpg', '.png', '.jpeg')):
            image_path = os.path.join(folder_path, filename)
            image = cv2.imread(image_path)

            if image is None:
                print(f"Error loading image: {image_path}")
                continue

            height, length = image.shape[:2]
            ratio = length / height
            int_ratio = int(round(ratio))

            output_subfolder = os.path.join(output_folder, os.path.splitext(filename)[0])
            os.makedirs(output_subfolder, exist_ok=True)

            divide_parts_folder = os.path.join(output_subfolder, "parts")
            os.makedirs(divide_parts_folder, exist_ok=True)

            part_classes, overall_skill = divide_image_and_classify(image, int_ratio, divide_parts_folder)

            image_classification = classify_sign(image)
            centroid = find_centroid(image)
            slant_angle = find_slant_angle(centroid, (length // 2, height // 2))

            print(f"{filename} - Length: {length}, Height: {height}, Ratio: {ratio:.2f}, Integer Ratio: {int_ratio}, Classification: {image_classification}, Overall Skill: {overall_skill}, Centroid: {centroid}, Slant Angle: {slant_angle}")

            dimensions_data['File Name'].append(filename)
            dimensions_data['Length'].append(length)
            dimensions_data['Height'].append(height)
            dimensions_data['Ratio (Length/Height)'].append(ratio)
            dimensions_data['Integer Ratio'].append(int_ratio)
            dimensions_data['Sign Classification'].append(image_classification)
            dimensions_data['Overall Skill'].append(overall_skill)
            dimensions_data['Centroid X'].append(centroid[0])
            dimensions_data['Centroid Y'].append(centroid[1])
            dimensions_data['Slant Angle'].append(slant_angle)

    df = pd.DataFrame(dimensions_data)
    df.to_excel(output_excel_path, index=False, engine='openpyxl')

# Paths for training data and output
training_folder = r'D:\AIML Internship\cropped_signatures\cropped_signatures\Kabeer'
output_folder_training = r'D:\AIML Internship\cropped_signatures\cropped_signatures\Kabeer\output'
output_excel_path_training = os.path.join(output_folder_training, 'training_results.xlsx')

# Perform training
print_and_save_signature_dimensions(training_folder, output_excel_path_training, output_folder_training)
# Out:
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 1.jpg - Length: 117, Height: 69, Ratio: 1.70, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (48, 30), Slant Angle: 21.80140948635181
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 10.jpg - Length: 110, Height: 64, Ratio: 1.72, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (42, 27), Slant Angle: 21.037511025421818
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 11.jpg - Length: 120, Height: 67, Ratio: 1.79, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (46, 27), Slant Angle: 23.19859051364819
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 12.jpg - Length: 118, Height: 64, Ratio: 1.84, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (44, 30), Slant Angle: 7.594643368591445
# part_1.png - Classification: Angular
# 13.jpg - Length: 122, Height: 83, Ratio: 1.47, Integer Ratio: 1, Classification: Angular, Overall Skill: Good, Centroid: (49, 34), Slant Angle: 30.256437163529263
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 14.jpg - Length: 123, Height: 74, Ratio: 1.66, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (49, 38), Slant Angle: -4.763641690726178
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 15.jpg - Length: 126, Height: 71, Ratio: 1.77, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (49, 37), Slant Angle: -8.13010235415598
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 16.jpg - Length: 129, Height: 59, Ratio: 2.19, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (48, 30), Slant Angle: -3.576334374997351
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 17.jpg - Length: 104, Height: 60, Ratio: 1.73, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (42, 28), Slant Angle: 11.309932474020213
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 18.jpg - Length: 115, Height: 55, Ratio: 2.09, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (46, 26), Slant Angle: 5.194428907734806
# part_1.png - Classification: Angular
# 19.jpg - Length: 101, Height: 72, Ratio: 1.40, Integer Ratio: 1, Classification: Angular, Overall Skill: Good, Centroid: (36, 31), Slant Angle: 19.65382405805331
# part_1.png - Classification: Round
# part_2.png - Classification: Angular
# 2.jpg - Length: 117, Height: 70, Ratio: 1.67, Integer Ratio: 2, Classification: Angular, Overall Skill: Not Good, Centroid: (49, 30), Slant Angle: 29.054604099077146
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 20.jpg - Length: 107, Height: 54, Ratio: 1.98, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (42, 28), Slant Angle: -5.194428907734806
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 21.jpg - Length: 114, Height: 63, Ratio: 1.81, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (36, 28), Slant Angle: 8.13010235415598
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 22.jpg - Length: 104, Height: 61, Ratio: 1.70, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (39, 29), Slant Angle: 4.398705354995532
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 24.jpg - Length: 122, Height: 68, Ratio: 1.79, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (47, 37), Slant Angle: -12.094757077012101
# part_1.png - Classification: Angular
# 25.jpg - Length: 107, Height: 76, Ratio: 1.41, Integer Ratio: 1, Classification: Angular, Overall Skill: Good, Centroid: (40, 33), Slant Angle: 21.037511025421818
# part_1.png - Classification: Angular
# 26.jpg - Length: 103, Height: 72, Ratio: 1.43, Integer Ratio: 1, Classification: Angular, Overall Skill: Good, Centroid: (37, 34), Slant Angle: 8.13010235415598
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 27.jpg - Length: 108, Height: 64, Ratio: 1.69, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (43, 27), Slant Angle: 24.443954780416536
# part_1.png - Classification: Angular
# 29.jpg - Length: 102, Height: 79, Ratio: 1.29, Integer Ratio: 1, Classification: Angular, Overall Skill: Good, Centroid: (39, 27), Slant Angle: 45.0
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 3.jpg - Length: 134, Height: 61, Ratio: 2.20, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (52, 30), Slant Angle: 0.0
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 30.jpg - Length: 114, Height: 63, Ratio: 1.81, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (42, 27), Slant Angle: 14.931417178137554
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 31.jpg - Length: 124, Height: 72, Ratio: 1.72, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (46, 28), Slant Angle: 26.56505117707799
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 32.jpg - Length: 120, Height: 70, Ratio: 1.71, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (46, 29), Slant Angle: 23.19859051364819
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 33.jpg - Length: 111, Height: 69, Ratio: 1.61, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (41, 29), Slant Angle: 19.65382405805331
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 34.jpg - Length: 122, Height: 77, Ratio: 1.58, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (40, 35), Slant Angle: 8.13010235415598
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 35.jpg - Length: 118, Height: 62, Ratio: 1.90, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (47, 33), Slant Angle: -9.462322208025617
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 36.jpg - Length: 135, Height: 56, Ratio: 2.41, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (49, 29), Slant Angle: -3.1798301198642345
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 37.jpg - Length: 121, Height: 75, Ratio: 1.61, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (50, 34), Slant Angle: 16.69924423399362
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 38.jpg - Length: 130, Height: 72, Ratio: 1.81, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (46, 32), Slant Angle: 11.888658039627975
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 39.jpg - Length: 133, Height: 68, Ratio: 1.96, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (47, 34), Slant Angle: 0.0
# part_1.png - Classification: Angular
# 4.jpg - Length: 108, Height: 76, Ratio: 1.42, Integer Ratio: 1, Classification: Angular, Overall Skill: Good, Centroid: (40, 34), Slant Angle: 15.945395900922854
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 40.jpg - Length: 119, Height: 62, Ratio: 1.92, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (45, 32), Slant Angle: -4.085616779974877
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 41.jpg - Length: 121, Height: 75, Ratio: 1.61, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (49, 39), Slant Angle: -10.304846468766033
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 42.jpg - Length: 120, Height: 69, Ratio: 1.74, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (44, 37), Slant Angle: -10.619655276155134
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 43.jpg - Length: 136, Height: 67, Ratio: 2.03, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (49, 36), Slant Angle: -8.972626614896393
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 44.jpg - Length: 136, Height: 67, Ratio: 2.03, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (49, 36), Slant Angle: -8.972626614896393
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 45.jpg - Length: 121, Height: 68, Ratio: 1.78, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (46, 36), Slant Angle: -8.13010235415598
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 46.jpg - Length: 129, Height: 64, Ratio: 2.02, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (49, 34), Slant Angle: -7.594643368591445
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 47.jpg - Length: 127, Height: 72, Ratio: 1.76, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (48, 36), Slant Angle: 0.0
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 48.jpg - Length: 132, Height: 77, Ratio: 1.71, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (50, 39), Slant Angle: -3.576334374997351
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 49.jpg - Length: 111, Height: 69, Ratio: 1.61, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (41, 29), Slant Angle: 19.65382405805331
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 5.jpg - Length: 109, Height: 65, Ratio: 1.68, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (43, 29), Slant Angle: 15.255118703057777
# part_1.png - Classification: Angular
# 50.jpg - Length: 110, Height: 77, Ratio: 1.43, Integer Ratio: 1, Classification: Angular, Overall Skill: Good, Centroid: (40, 37), Slant Angle: 3.8140748342903543
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 51.jpg - Length: 118, Height: 61, Ratio: 1.93, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (47, 32), Slant Angle: -9.462322208025617
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 52.jpg - Length: 135, Height: 56, Ratio: 2.41, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (49, 29), Slant Angle: -3.1798301198642345
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 53.jpg - Length: 120, Height: 74, Ratio: 1.62, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (49, 33), Slant Angle: 19.98310652189998
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 54.jpg - Length: 130, Height: 72, Ratio: 1.81, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (46, 32), Slant Angle: 11.888658039627975
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 55.jpg - Length: 131, Height: 68, Ratio: 1.93, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (47, 34), Slant Angle: 0.0
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 56.jpg - Length: 118, Height: 62, Ratio: 1.90, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (44, 32), Slant Angle: -3.8140748342903543
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 57.jpg - Length: 121, Height: 74, Ratio: 1.64, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (49, 38), Slant Angle: -5.194428907734806
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 58.jpg - Length: 120, Height: 69, Ratio: 1.74, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (44, 37), Slant Angle: -10.619655276155134
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 59.jpg - Length: 137, Height: 67, Ratio: 2.04, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (50, 36), Slant Angle: -9.462322208025617
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 6.jpg - Length: 125, Height: 67, Ratio: 1.87, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (48, 33), Slant Angle: 0.0
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 60.jpg - Length: 128, Height: 60, Ratio: 2.13, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (47, 35), Slant Angle: -16.389540334034784
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 61.jpg - Length: 120, Height: 67, Ratio: 1.79, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (45, 35), Slant Angle: -7.594643368591445
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 62.jpg - Length: 129, Height: 79, Ratio: 1.63, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (49, 34), Slant Angle: 18.43494882292201
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 63.jpg - Length: 127, Height: 72, Ratio: 1.76, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (48, 36), Slant Angle: 0.0
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 64.jpg - Length: 132, Height: 77, Ratio: 1.71, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (50, 39), Slant Angle: -3.576334374997351
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 65.jpg - Length: 111, Height: 67, Ratio: 1.66, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (41, 30), Slant Angle: 12.094757077012101
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 66.jpg - Length: 103, Height: 65, Ratio: 1.58, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (38, 29), Slant Angle: 12.994616791916505
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 67.jpg - Length: 111, Height: 54, Ratio: 2.06, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (44, 25), Slant Angle: 10.304846468766033
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 68.jpg - Length: 113, Height: 61, Ratio: 1.85, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (45, 31), Slant Angle: -5.194428907734806
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 69.jpg - Length: 100, Height: 66, Ratio: 1.52, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (36, 36), Slant Angle: -12.094757077012101
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# part_3.png - Classification: Angular
# 7.jpg - Length: 135, Height: 53, Ratio: 2.55, Integer Ratio: 3, Classification: Angular, Overall Skill: Good, Centroid: (51, 22), Slant Angle: 14.036243467926479
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 70.jpg - Length: 113, Height: 65, Ratio: 1.74, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (45, 37), Slant Angle: -24.443954780416536
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 71.jpg - Length: 118, Height: 68, Ratio: 1.74, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (45, 38), Slant Angle: -15.945395900922854
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 72.jpg - Length: 114, Height: 68, Ratio: 1.68, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (43, 31), Slant Angle: 12.094757077012101
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 73.jpg - Length: 120, Height: 70, Ratio: 1.71, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (48, 36), Slant Angle: -4.763641690726178
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 74.jpg - Length: 127, Height: 73, Ratio: 1.74, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (47, 35), Slant Angle: 3.576334374997351
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 75.jpg - Length: 125, Height: 57, Ratio: 2.19, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (45, 27), Slant Angle: 3.3664606634298013
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 76.jpg - Length: 113, Height: 70, Ratio: 1.61, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (41, 30), Slant Angle: 18.43494882292201
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 77.jpg - Length: 120, Height: 60, Ratio: 2.00, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (44, 28), Slant Angle: 7.125016348901798
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 78.jpg - Length: 115, Height: 66, Ratio: 1.74, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (44, 34), Slant Angle: -4.398705354995532
# part_1.png - Classification: Angular
# part_2.png - Classification: Angular
# 79.jpg - Length: 118, Height: 62, Ratio: 1.90, Integer Ratio: 2, Classification: Angular, Overall Skill: Good, Centroid: (47, 29), Slant Angle: 9.462322208025617
# part_1.png - Classification: Angular
# 8.jpg - Length: 108, Height: 81, Ratio: 1.33, Integer Ratio: 1, Classification: Angular, Overall Skill: Good, Centroid: (37, 25), Slant Angle: 41.423665625002656
# part_1.png - Classification: Angular
# 9.jpg - Length: 109, Height: 78, Ratio: 1.40, Integer Ratio: 1, Classification: Angular, Overall Skill: Good, Centroid: (41, 37), Slant Angle: 8.74616226255521

# %%
import os
import cv2
import numpy as np
from skimage.feature import hog

def extract_stroke_features(image):
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    return features

def extract_shape_features(image):
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    shape_features = []
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        area = cv2.contourArea(contour)
        perimeter = cv2.arcLength(contour, True)
        shape_features = [aspect_ratio, area, perimeter]
    return shape_features

def calculate_slant_angle(image):
    # Convert image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Threshold the image to obtain a binary image
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    
    # Find contours in the binary image
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Find the largest contour (signature)
    largest_contour = max(contours, key=cv2.contourArea)
    
    # Check if the contour contains at least 5 points
    if len(largest_contour) < 5:
        # If the contour has too few points, return a default angle (0 degrees)
        return 0
    
    # Perform principal component analysis (PCA) on the largest contour
    _, _, angle = cv2.fitEllipse(largest_contour)
    
    # The angle returned by fitEllipse is the angle of rotation of the fitted ellipse
    # We use this as an estimate of the slant angle of the signature
    return angle



def extract_angle_features(image):
    # Calculate angle features (e.g., angles between strokes)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    lines = cv2.HoughLinesP(edges, 1, np.pi/180, threshold=100, minLineLength=100, maxLineGap=10)
    angle_features = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            angle = np.arctan2(y2 - y1, x2 - x1) * 180 / np.pi
            angle_features.append(angle)
    return angle_features

def extract_curvature_features(image):
    # Calculate curvature features
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    curvature_features = []
    if contours:
        for contour in contours:
            M = cv2.moments(contour)
            if M["m00"] != 0:
                cx = int(M["m10"] / M["m00"])
                cy = int(M["m01"] / M["m00"])
                cX, cY = cx, cy
                points = contour[:, 0]
                prev_point = points[0]
                total_distance = 0
                total_curvature = 0
                num_points = 0
                for point in points[1:]:
                    distance = np.linalg.norm(point - prev_point)
                    total_distance += distance
                    angle = np.arctan2(point[1] - prev_point[1], point[0] - prev_point[0])
                    curvature = np.abs(angle - prev_angle) / distance if num_points > 0 else 0
                    total_curvature += curvature
                    prev_point = point
                    prev_angle = angle
                    num_points += 1
                if num_points > 0:
                    mean_curvature = total_curvature / total_distance
                    curvature_features.append(mean_curvature)
    return curvature_features

def classify_sign(image):
    # Replace this with your own sign classification method
    # Example: Determine if the sign is angular, circular, or something else
    # You may use machine learning models, rules-based systems, etc.
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    
    # Simple rule-based classification
    if len(features) < 1000:
        return "Circular"
    else:
        return "Angular"

def assess_skill(image):
    # Replace this with your own method for assessing the overall skill of the signature
    # Example: Use machine learning models or rules-based systems to evaluate the signature's quality
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    
    # Simple rule-based assessment
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        if aspect_ratio > 0.5:
            return "Good"
        else:
            return "Poor"
    else:
        return "Poor"


def extract_additional_features(image):
    # Calculate length, height, ratio, integer ratio
    height, length, _ = image.shape
    ratio = length / height
    integer_ratio = int(ratio)
    
    # Classify the sign
    sign_classification = classify_sign(image)
    
    # Assess overall skill
    overall_skill = assess_skill(image)
    
    # Calculate centroid coordinates
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        contour = max(contours, key=cv2.contourArea)
        M = cv2.moments(contour)
        if M["m00"] != 0:
            centroid_x = int(M["m10"] / M["m00"])
            centroid_y = int(M["m01"] / M["m00"])
        else:
            centroid_x, centroid_y = -1, -1
    else:
        centroid_x, centroid_y = -1, -1
    
    # Calculate slant angle
    slant_angle = calculate_slant_angle(image)
    
    return {
        'Length': length,
        'Height': height,
        'Ratio (Length/Height)': ratio,
        'Integer Ratio': integer_ratio,
        'Sign Classification': sign_classification,
        'Overall Skill': overall_skill,
        'Centroid X': centroid_x,
        'Centroid Y': centroid_y,
        'Slant Angle': slant_angle
    }

def extract_features_from_images(sample_images_folder):
    features_list = []
    for filename in os.listdir(sample_images_folder):
        image_path = os.path.join(sample_images_folder, filename)
        
        # Extract label from filename
        label = os.path.splitext(filename)[0]
        
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue  # Skip this image if loading fails
        
        # Extract additional features
        additional_features = extract_additional_features(image)
        
        # Extract stroke features
        stroke_features = extract_stroke_features(image)
        
        # Extract shape features
        shape_features = extract_shape_features(image)
        
        # Extract angle features
        angle_features = extract_angle_features(image)
        
        # Extract curvature features
        curvature_features = extract_curvature_features(image)
        
        # Combine all features into a single feature vector
        all_features = np.concatenate((stroke_features, shape_features, angle_features, curvature_features))
        
        # Add features, label, and additional features to the list
        features_dict = {
            "label": label,
            "features": all_features,
            **additional_features
        }
        features_list.append(features_dict)
        
        # Print feature values
        print(f"Image: {filename}")
        print(f"Features: {features_dict}")
    
    print(f"Number of images processed: {len(features_list)}")
    return features_list

# Example usage:
sample_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample images"

features = extract_features_from_images(sample_images_folder)
# Out:
# Image: 121.jpg
# Features: {'label': '121', 'features': array([0.40614268, 0.        , 0.        , ..., 0.27333066, 0.28524029,
#        0.22354762]), 'Length': 197, 'Height': 88, 'Ratio (Length/Height)': 2.2386363636363638, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 98, 'Centroid Y': 43, 'Slant Angle': 92.14785766601562}
# Image: 132.jpg
# Features: {'label': '132', 'features': array([0.18077538, 0.        , 0.        , ..., 0.16663398, 0.42196987,
#        0.17294859]), 'Length': 127, 'Height': 60, 'Ratio (Length/Height)': 2.1166666666666667, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 55, 'Centroid Y': 22, 'Slant Angle': 87.39740753173828}
# Image: 153.jpg
# Features: {'label': '153', 'features': array([3.33951183e-01, 6.97702137e-02, 1.87555060e-02, ...,
#        2.73597979e+02, 3.00361669e-01, 3.02547831e-01]), 'Length': 130, 'Height': 53, 'Ratio (Length/Height)': 2.452830188679245, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 53, 'Centroid Y': 18, 'Slant Angle': 84.9600601196289}
# Number of images processed: 3

# %%
import os
import cv2
import numpy as np
from skimage.feature import hog

def extract_stroke_features(image):
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    return features

def extract_shape_features(image):
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    shape_features = []
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        area = cv2.contourArea(contour)
        perimeter = cv2.arcLength(contour, True)
        shape_features = [aspect_ratio, area, perimeter]
    return shape_features

def extract_angle_features(image):
    # Calculate angle features (e.g., angles between strokes)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    lines = cv2.HoughLinesP(edges, 1, np.pi/180, threshold=100, minLineLength=100, maxLineGap=10)
    angle_features = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            angle = np.arctan2(y2 - y1, x2 - x1) * 180 / np.pi
            angle_features.append(angle)
    return angle_features

def extract_curvature_features(image):
    # Calculate curvature features
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    curvature_features = []
    if contours:
        for contour in contours:
            M = cv2.moments(contour)
            if M["m00"] != 0:
                cx = int(M["m10"] / M["m00"])
                cy = int(M["m01"] / M["m00"])
                cX, cY = cx, cy
                points = contour[:, 0]
                prev_point = points[0]
                total_distance = 0
                total_curvature = 0
                num_points = 0
                for point in points[1:]:
                    distance = np.linalg.norm(point - prev_point)
                    total_distance += distance
                    angle = np.arctan2(point[1] - prev_point[1], point[0] - prev_point[0])
                    curvature = np.abs(angle - prev_angle) / distance if num_points > 0 else 0
                    total_curvature += curvature
                    prev_point = point
                    prev_angle = angle
                    num_points += 1
                if num_points > 0:
                    mean_curvature = total_curvature / total_distance
                    curvature_features.append(mean_curvature)
    return curvature_features

def extract_features_from_images(sample_images_folder):
    features_list = []
    for filename in os.listdir(sample_images_folder):
        image_path = os.path.join(sample_images_folder, filename)
        
        # Extract label from filename
        label = os.path.splitext(filename)[0]
        
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue  # Skip this image if loading fails
        
        # Extract stroke features
        stroke_features = extract_stroke_features(image)
        
        # Extract shape features
        shape_features = extract_shape_features(image)
        
        # Extract angle features
        angle_features = extract_angle_features(image)
        
        # Extract curvature features
        curvature_features = extract_curvature_features(image)
        
        # Add features and label to the list
        features_dict = {
            "label": label,
            "stroke_features": stroke_features,
            "shape_features": shape_features,
            "angle_features": angle_features,
            "curvature_features": curvature_features
        }
        features_list.append(features_dict)
    
    return features_list

# Example usage:
sample_images_folder = rdataset_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain"


features = extract_features_from_images(sample_images_folder)
print(f"Number of images processed: {len(features)}")

# Print features with labels
for feature_dict in features:
    label = feature_dict["label"]
    stroke_features = feature_dict["stroke_features"]
    shape_features = feature_dict["shape_features"]
    angle_features = feature_dict["angle_features"]
    curvature_features = feature_dict["curvature_features"]
    
    print(f"Label: {label}")
    print(f"Stroke Features: {stroke_features}")
    print(f"Shape Features: {shape_features}")
    print(f"Angle Features: {angle_features}")
    print(f"Curvature Features: {curvature_features}")
# Out:
# Number of images processed: 88
# Label: 122
# Stroke Features: [0.24647277 0.         0.19918008 ... 0.25015971 0.29002008 0.        ]
# Shape Features: [2.0, 53.0, 33.31370830535889]
# Angle Features: []
# Curvature Features: [0.9759677134264297, 0.27538591252826544, 0.41993235156140035, 0.22954115633843172, 0.2900203585990963, 0.26528230349449095, 0.21901884606585334]
# Label: 123
# Stroke Features: [0.34430633 0.         0.         ... 0.32419013 0.         0.        ]
# Shape Features: [4.785714285714286, 1577.5, 304.18376553058624]
# Angle Features: []
# Curvature Features: [0.16004908545017452, 0.25191524824621314, 0.3493482052137768]
# Label: 124
# Stroke Features: [0.42678198 0.08928572 0.42678198 ... 0.05959882 0.14135101 0.19990052]
# Shape Features: [1.691358024691358, 10880.0, 432.0]
# Angle Features: []
# Curvature Features: [0.3521124130613778, 0.34662251029509666, 0.20105620675839506]
# Label: 125
# Stroke Features: [0.39019667 0.06032594 0.11446043 ... 0.22262799 0.         0.        ]
# Shape Features: [3.7142857142857144, 185.5, 115.35533845424652]
# Angle Features: []
# Curvature Features: [0.23554412985900003, 0.30659059446094217, 0.26573684158316907, 0.31210048736542995, 0.1870066264077826, 0.24071140934708268]
# Label: 126
# Stroke Features: [0.35098322 0.16516471 0.         ... 0.0385943  0.00813639 0.        ]
# Shape Features: [5.65, 1086.5, 250.87005722522736]
# Angle Features: []
# Curvature Features: [0.12098525202529213, 0.6464688261670196, 0.23142328166373397, 0.12456478331410205, 0.15976461219719432]
# Label: 127
# Stroke Features: [0.28099869 0.16605824 0.21004888 ... 0.2125469  0.         0.        ]
# Shape Features: [4.042553191489362, 8694.0, 470.0]
# Angle Features: []
# Curvature Features: [0.16038902139560682, 0.2533779943559706, 0.2853660211458454, 0.2230486462169004]
# Label: 128
# Stroke Features: [0.35036702 0.08438293 0.         ... 0.         0.         0.        ]
# Shape Features: [2.7540983606557377, 10020.0, 454.0]
# Angle Features: [-14.036243467926477]
# Curvature Features: [0.19569199120835892, 0.679191282749203, 0.2858823402494399, 0.5276140673400748, 0.2112053387656866, 0.22119300526208188]
# Label: 129
# Stroke Features: [0.08344126 0.00400282 0.00772015 ... 0.         0.         0.        ]
# Shape Features: [3.0, 34.5, 52.38477599620819]
# Angle Features: []
# Curvature Features: [0.32799127861309463, 0.26349632495527925, 0.326441809573127, 0.20596450839669578, 0.2916963791652105, 0.21372119256360245]
# Label: 130
# Stroke Features: [0.35541226 0.         0.26280156 ... 0.16949117 0.         0.        ]
# Shape Features: [2.4464285714285716, 7480.0, 382.0]
# Angle Features: [-7.650650955359412]
# Curvature Features: [0.28453463305464477, 0.22889119310561798]
# Label: 131
# Stroke Features: [0.         0.         0.         ... 0.02480606 0.01166007 0.00658396]
# Shape Features: [8.333333333333334, 94.0, 154.62741661071777]
# Angle Features: []
# Curvature Features: [0.12271807487438612, 0.0764894715075362, 0.33305374648057245]
# Label: 133
# Stroke Features: [0.14200465 0.         0.         ... 0.17525256 0.         0.        ]
# Shape Features: [4.88, 1438.0, 275.94112491607666]
# Angle Features: []
# Curvature Features: [0.33630816955660475, 0.2740634978469492, 0.476391755027713, 0.23067934976998525]
# Label: 134
# Stroke Features: [0.04449652 0.00877733 0.00361062 ... 0.01776127 0.0300448  0.01437448]
# Shape Features: [7.0, 39.5, 101.55634891986847]
# Angle Features: []
# Curvature Features: [0.1037282483203787, 1.0727544889495058, 0.3648625019032968, 0.30342314432037365, 0.19161825849938713]
# Label: 135
# Stroke Features: [0.06555467 0.         0.         ... 0.00337859 0.00267101 0.01060018]
# Shape Features: [5.761904761904762, 1051.0, 268.2842707633972]
# Angle Features: [-9.027612950715096]
# Curvature Features: [0.12687222393959594, 0.2885252024086792, 0.5194404744042401, 0.8535071045221778, 0.2666721607028814]
# Label: 136
# Stroke Features: [0.39444092 0.         0.         ... 0.05361333 0.         0.        ]
# Shape Features: [2.774193548387097, 9451.5, 1086.5168062448502]
# Angle Features: [-13.025840646870822, -13.091893064346847]
# Curvature Features: [0.4475682724092405, 0.233992354731563, 0.26647624907294565, 0.21733188422936875]
# Label: 137
# Stroke Features: [0.11725957 0.00905112 0.00632133 ... 0.         0.         0.        ]
# Shape Features: [3.4705882352941178, 128.5, 129.8406196832657]
# Angle Features: []
# Curvature Features: [0.22627226508346432, 0.22256792724671814, 0.41452591750985507, 0.2491282997529244, 0.1676308830468172]
# Label: 138
# Stroke Features: [0.22815833 0.         0.         ... 0.02204064 0.         0.        ]
# Shape Features: [6.0588235294117645, 210.0, 217.25483322143555]
# Angle Features: [-9.027612950715096]
# Curvature Features: [0.12733856865165624, 0.3249445333338479, 0.2989476605527588, 0.24200996219229662]
# Label: 139
# Stroke Features: [0.37419258 0.0598942  0.37419258 ... 0.07216963 0.         0.        ]
# Shape Features: [2.8360655737704916, 9397.0, 951.8477598428726]
# Angle Features: [-10.37584492005105]
# Curvature Features: [0.38800291483109883, 0.2716573881436034, 0.2803532668656635, 0.31829527197500534]
# Label: 140
# Stroke Features: [0.21378335 0.05106995 0.01614973 ... 0.         0.00380225 0.        ]
# Shape Features: [8.0, 0.0, 14.0]
# Angle Features: []
# Curvature Features: [0.24590075793626465, 0.22610013149966712, 0.4384998692697752]
# Label: 141
# Stroke Features: [0.12484837 0.         0.         ... 0.03048394 0.         0.        ]
# Shape Features: [1.0, 2.5, 6.2426406145095825]
# Angle Features: []
# Curvature Features: [0.07821261697553206, 0.15619263314910442, 0.10678088602030153, 0.12063598055378127, 0.5235987755982987, 0.48679368590371225, 0.20545855114585546]
# Label: 142
# Stroke Features: [0.33866082 0.15205018 0.09616497 ... 0.09542336 0.03017551 0.0556409 ]
# Shape Features: [5.230769230769231, 51.0, 143.94112491607666]
# Angle Features: [-10.091057238888915]
# Curvature Features: [0.3559161680993671, 0.25002387838140355]
# Label: 143
# Stroke Features: [0.36191671 0.         0.07050067 ... 0.01861791 0.00294375 0.        ]
# Shape Features: [4.6521739130434785, 1027.0, 243.11269783973694]
# Angle Features: []
# Curvature Features: [0.18499433424371833, 0.1505243888942577, 0.5931114404758282, 0.2904264121707268]
# Label: 144
# Stroke Features: [0.         0.         0.         ... 0.02438277 0.01926863 0.00190695]
# Shape Features: [9.928571428571429, 772.5, 294.3847759962082]
# Angle Features: [-5.019853642019552]
# Curvature Features: [0.10515090510150654, 0.8436496301653227, 0.3837606981978986, 0.28293355647816537, 0.3782340614550229]
# Label: 145
# Stroke Features: [0.09620211 0.02359984 0.00516744 ... 0.         0.         0.        ]
# Shape Features: [4.25, 104.0, 146.42640614509583]
# Angle Features: []
# Curvature Features: [0.2952527978936164, 0.20003020156781776, 0.2997801279480867]
# Label: 146
# Stroke Features: [0.         0.         0.10641911 ... 0.03342205 0.         0.        ]
# Shape Features: [1.955223880597015, 7707.0, 796.1076451539993]
# Angle Features: []
# Curvature Features: [1.1177865696801557, 0.25727255885450057, 0.2817554549480836]
# Label: 147
# Stroke Features: [0.1774753  0.         0.10457833 ... 0.02513855 0.01490533 0.01405288]
# Shape Features: [1.0, 0.0, 0.0]
# Angle Features: []
# Curvature Features: [0.3770556737237071, 0.19512124197283615, 0.2967338755842363]
# Label: 148
# Stroke Features: [0.30775772 0.         0.         ... 0.00427072 0.00433476 0.00126728]
# Shape Features: [10.75, 35.0, 88.14213538169861]
# Angle Features: [-3.945186229037563]
# Curvature Features: [0.28248378398785084, 0.29637185266001215, 0.2440207956733815]
# Label: 149
# Stroke Features: [0.04001669 0.00854778 0.00708232 ... 0.03692804 0.00611428 0.        ]
# Shape Features: [2.0634920634920637, 6838.0, 871.8477592468262]
# Angle Features: []
# Curvature Features: [0.1805857265470501, 0.27366599879729897, 0.2738896223535809, 0.2932319097487068]
# Label: 150
# Stroke Features: [0.15174944 0.         0.         ... 0.10765346 0.         0.        ]
# Shape Features: [4.0, 154.5, 191.9827550649643]
# Angle Features: []
# Curvature Features: [0.18906816828745648, 0.15843606510584005, 0.33011642640185157, 0.2689718187937361]
# Label: 151
# Stroke Features: [0.50507627 0.         0.         ... 0.         0.         0.        ]
# Shape Features: [2.8153846153846156, 10726.5, 929.4629838466644]
# Angle Features: []
# Curvature Features: [0.24910462616768195, 0.2470564519128367]
# Label: 154
# Stroke Features: [0.0803642  0.         0.01894202 ... 0.38214868 0.08780042 0.        ]
# Shape Features: [2.1176470588235294, 192.5, 90.18376541137695]
# Angle Features: []
# Curvature Features: [0.1659048875758091, 0.350650848219661, 0.27414936190392686, 0.30273336205793533, 0.3167094714978188, 0.5046102437753243, 0.7465552787096599, 0.3063344508087579, 0.23531108102536968, 0.21243227928644032]
# Label: 155
# Stroke Features: [0.2754416  0.         0.21640736 ... 0.0489344  0.03868604 0.        ]
# Shape Features: [1.0, 0.0, 0.0]
# Angle Features: []
# Curvature Features: [0.34627197194012177, 0.3265889423381922]
# Label: 156
# Stroke Features: [0.30718334 0.         0.37151612 ... 0.02203755 0.01025472 0.01738334]
# Shape Features: [5.8125, 538.0, 196.42640614509583]
# Angle Features: [-8.833414651219002]
# Curvature Features: [0.6595863150528856, 0.2328727049468767, 0.18230895346192313, 0.27975146650046634]
# Label: 157
# Stroke Features: [0.06346369 0.         0.02761575 ... 0.08759358 0.         0.        ]
# Shape Features: [2.9130434782608696, 6642.0, 498.16652059555054]
# Angle Features: [-18.74134044519272]
# Curvature Features: [0.6193269751685269, 0.25833309210350863, 0.26856108615081764, 0.3017610215238602]
# Label: 158
# Stroke Features: [0.06208349 0.         0.04389966 ... 0.281115   0.         0.        ]
# Shape Features: [2.511111111111111, 473.5, 261.0365777015686]
# Angle Features: []
# Curvature Features: [0.329315043073886, 0.19453491799458553, 0.3127980052837226, 0.2973041103997845, 0.2900812782878092]
# Label: 159
# Stroke Features: [0.         0.         0.         ... 0.11590673 0.06872424 0.03239692]
# Shape Features: [3.511627906976744, 975.5, 336.5512965917587]
# Angle Features: [-12.470461721668892]
# Curvature Features: [0.3304692164065139, 0.23315054433723711, 0.1818170664856184, 0.15671245777484477, 0.25219139011824965]
# Label: 160
# Stroke Features: [0.08911322 0.02094611 0.01487033 ... 0.13679164 0.         0.        ]
# Shape Features: [4.388888888888889, 245.0, 170.08326029777527]
# Angle Features: []
# Curvature Features: [0.17256385381862657, 0.2110901590824128, 0.5617879264981437, 0.31362083396193424, 0.4468368826800236, 0.2879989324883647]
# Label: 161
# Stroke Features: [0.36265589 0.01178012 0.00507304 ... 0.00285481 0.         0.        ]
# Shape Features: [0.3333333333333333, 0.0, 4.0]
# Angle Features: []
# Curvature Features: [0.2929670670708165, 0.526172351554984, 0.29318467529587516, 0.2697490024351639]
# Label: 162
# Stroke Features: [0.30092724 0.06954254 0.02199128 ... 0.14034636 0.14793806 0.        ]
# Shape Features: [3.5434782608695654, 7280.5, 418.2426406145096]
# Angle Features: []
# Curvature Features: [0.2301180657803828, 0.437157340389337, 0.6583088377703542, 0.45572452864850993, 0.3084634833726088]
# Label: 163
# Stroke Features: [0.33043324 0.03811871 0.09643354 ... 0.0220609  0.05232202 0.04932968]
# Shape Features: [3.0638297872340425, 6578.0, 378.0]
# Angle Features: []
# Curvature Features: [0.2024370435048623, 0.3529683847831557, 0.7275501303423165, 0.4733969062861105, 0.18347830780267657, 0.44016073791113053]
# Label: 164
# Stroke Features: [0.25526463 0.21077037 0.07225165 ... 0.07176162 0.         0.        ]
# Shape Features: [2.5686274509803924, 6500.0, 360.0]
# Angle Features: []
# Curvature Features: [0.26827582405749617, 0.4086474603004726, 0.4893155439301061, 0.11821922801434813, 0.40959397140667997, 0.27220000454053483, 0.14295072079095503, 0.36814407995063]
# Label: 165
# Stroke Features: [0.38852967 0.07766954 0.         ... 0.00390631 0.01235285 0.        ]
# Shape Features: [2.6166666666666667, 8622.0, 725.1959577798843]
# Angle Features: []
# Curvature Features: [0.20001852809552378, 0.1664975823194237, 0.5451928115743234, 0.4396693886691581, 0.30532283860060855]
# Label: 166
# Stroke Features: [0.         0.         0.         ... 0.28406749 0.07966272 0.05633005]
# Shape Features: [2.457627118644068, 8352.0, 404.0]
# Angle Features: []
# Curvature Features: [0.9125886986875175, 0.181247959203713, 0.17041479989231886, 0.34978210938665977, 0.5956126801185111, 0.31867196096913125, 0.1617949056095626]
# Label: 167
# Stroke Features: [0.35259493 0.         0.06404796 ... 0.01469883 0.01071975 0.00986028]
# Shape Features: [2.7777777777777777, 3465.0, 268.0]
# Angle Features: []
# Curvature Features: [0.899014600517074, 0.22448529642698659, 0.4196371217331626, 0.38157296319849904, 0.37292814636473426, 0.3482533511311733]
# Label: 168
# Stroke Features: [0.1510509  0.04222001 0.08010683 ... 0.02072645 0.         0.        ]
# Shape Features: [3.019230769230769, 7904.0, 434.97056245803833]
# Angle Features: []
# Curvature Features: [0.2481162922465282, 0.34041912058530627, 0.3907782272127567, 0.3630408485051964]
# Label: 169
# Stroke Features: [0.04261882 0.02555214 0.03074638 ... 0.11617087 0.05828297 0.        ]
# Shape Features: [2.9464285714285716, 8434.5, 726.5269113779068]
# Angle Features: [0.0]
# Curvature Features: [0.07108666955779983, 0.3930154659930904, 0.2208203478044551, 0.35149351422450975, 0.27467661007749666, 0.2532180340892118]
# Label: 170
# Stroke Features: [0.01651022 0.         0.02334897 ... 0.05800977 0.04586076 0.        ]
# Shape Features: [2.9285714285714284, 8922.0, 455.3137083053589]
# Angle Features: []
# Curvature Features: [0.19380561160311705, 0.2862455637688639, 0.3395151873656349, 0.1465439912912369, 0.33662904388994874]
# Label: 171
# Stroke Features: [0.17379684 0.10598769 0.27034253 ... 0.03690679 0.02244335 0.01217688]
# Shape Features: [1.9423076923076923, 5028.0, 348.1421353816986]
# Angle Features: []
# Curvature Features: [0.23654917475823609, 0.8248664094961193, 0.6086875209663869, 1.6982596010881397, 0.3314758190368187, 0.30154453248316054, 0.4911361020657925, 0.16645112969730225, 0.22330482990128958]
# Label: 172
# Stroke Features: [0.08356726 0.         0.11818195 ... 0.11683306 0.14778343 0.20899732]
# Shape Features: [3.3207547169811322, 8876.5, 563.0121924877167]
# Angle Features: []
# Curvature Features: [0.294872582539904, 0.22410768984307228, 0.29315333019134066, 0.2008693224884618, 0.3975998690327407, 0.2802274318422061, 0.28039092005265215]
# Label: 173
# Stroke Features: [0.31192866 0.         0.03356346 ... 0.00321173 0.00943713 0.00413635]
# Shape Features: [0.8333333333333334, 14.5, 15.071067571640015]
# Angle Features: []
# Curvature Features: [0.16858812925695876, 0.3733631947890047, 0.14387892947731865, 0.150075792858013, 0.12323218774662806, 0.14211715334575023]
# Label: 174
# Stroke Features: [0.06552791 0.0131744  0.01484596 ... 0.         0.00751419 0.01847398]
# Shape Features: [2.697674418604651, 4822.5, 313.41421353816986]
# Angle Features: []
# Curvature Features: [0.9759677134264297, 0.5261426983758049, 0.5178393536174337, 0.31022059452596756, 0.5327564596298519, 0.25163808545337424, 0.39393170006293815, 0.2193844251334504]
# Label: 175
# Stroke Features: [0.1195759  0.00323095 0.00408687 ... 0.13462597 0.05321559 0.        ]
# Shape Features: [2.4074074074074074, 6837.0, 364.0]
# Angle Features: []
# Curvature Features: [0.3016585700275364, 0.4117702130052611, 0.2269678267718719]
# Label: 176
# Stroke Features: [0.2245589  0.         0.2920752  ... 0.26963373 0.         0.21623907]
# Shape Features: [2.25, 4874.5, 418.5269113779068]
# Angle Features: []
# Curvature Features: [0.30229810461736145, 0.10334128777889916, 0.22844169573552345, 0.29036054438991543, 0.17486774802784702, 0.18536000172921574]
# Label: 177
# Stroke Features: [0.03859304 0.00766656 0.00295666 ... 0.00839793 0.         0.        ]
# Shape Features: [5.3076923076923075, 228.0, 145.94112491607666]
# Angle Features: []
# Curvature Features: [0.1686774840771985, 0.1760599081012639, 0.4837333536229444, 0.3772730039998202, 0.20287353354191862, 0.16315514726473465]
# Label: 178
# Stroke Features: [0.04584456 0.         0.         ... 0.08983707 0.         0.        ]
# Shape Features: [2.74, 6664.0, 370.0]
# Angle Features: []
# Curvature Features: [0.3384786531750336, 0.14864457581897894, 0.26896354388007904, 0.40882491500299195, 0.36707604775799335]
# Label: 179
# Stroke Features: [0.35001901 0.         0.19439531 ... 0.15158807 0.06349599 0.        ]
# Shape Features: [2.7551020408163267, 6268.5, 471.8406196832657]
# Angle Features: []
# Curvature Features: [0.22319166186312478, 0.30412130154300887, 0.26043116038977027, 0.3483524694081229]
# Label: 180
# Stroke Features: [0.12101227 0.         0.         ... 0.07937807 0.03137694 0.        ]
# Shape Features: [3.406779661016949, 11459.5, 601.6984843015671]
# Angle Features: [-6.296818718984405, -6.102779653655784]
# Curvature Features: [0.24785423644473295, 0.1595620650846478, 0.31097842668021525, 0.3664185238964095, 0.5761066277046195, 0.12353415151616898, 0.2605139361771406]
# Label: 181
# Stroke Features: [0.29015793 0.         0.16343066 ... 0.13648421 0.08092519 0.        ]
# Shape Features: [4.7, 538.0, 202.9116872549057]
# Angle Features: []
# Curvature Features: [0.5158921211711247, 0.1172594039928087, 0.4387066409242546, 0.061948937708793436, 0.4717658900026829, 0.2940570009442924, 0.27227731321901866, 0.22736580073248996]
# Label: 182
# Stroke Features: [0.23076287 0.         0.04662114 ... 0.01497245 0.         0.        ]
# Shape Features: [1.9803921568627452, 4341.5, 665.1787127256393]
# Angle Features: []
# Curvature Features: [0.23853836577235593, 0.37706721065756715, 0.3076723214983449, 0.2668790983829227]
# Label: 183
# Stroke Features: [0.23076287 0.         0.04662114 ... 0.00610585 0.00237681 0.0020846 ]
# Shape Features: [1.9807692307692308, 4535.0, 680.5929262638092]
# Angle Features: []
# Curvature Features: [0.26171765467789226, 0.37706721065756715, 0.3076723214983449, 0.2668790983829227]
# Label: 184
# Stroke Features: [0.3427059  0.29324454 0.33383543 ... 0.0227842  0.04232885 0.04029174]
# Shape Features: [2.9482758620689653, 9631.5, 478.72792184352875]
# Angle Features: []
# Curvature Features: [0.3110102610994037, 0.11552595831716647, 0.19814191943453452, 0.1994455152880006]
# Label: 185
# Stroke Features: [0.04584276 0.02288572 0.0058398  ... 0.01901739 0.01879321 0.03837878]
# Shape Features: [2.611111111111111, 6299.5, 869.4629837274551]
# Angle Features: []
# Curvature Features: [0.27577258652606895, 0.5710129530360267, 0.2685050442646474, 0.14716185666803877, 0.2609897826939019]
# Label: 186
# Stroke Features: [0.29030146 0.         0.11455857 ... 0.01994278 0.0048196  0.0102239 ]
# Shape Features: [2.4791666666666665, 5546.0, 330.0]
# Angle Features: []
# Curvature Features: [0.28401029728541854, 0.1712702904235017]
# Label: 187
# Stroke Features: [0.06466163 0.         0.         ... 0.         0.         0.        ]
# Shape Features: [2.7254901960784315, 6674.5, 512.6690467596054]
# Angle Features: []
# Curvature Features: [0.2624721454930563, 0.7180216528408673, 0.05234569384404267, 0.6160633211477, 0.36332792163230604, 0.4744013013481152, 0.20255702457185149, 0.4707349593477169]
# Label: 188
# Stroke Features: [0.3096546  0.         0.09841689 ... 0.09474336 0.05608667 0.02195698]
# Shape Features: [3.4150943396226414, 9187.0, 577.5979790687561]
# Angle Features: []
# Curvature Features: [0.11771463399541479, 0.19738181876404756, 0.21964419099564933, 0.22929619029412637]
# Label: 189
# Stroke Features: [0.27916199 0.01918609 0.03640305 ... 0.1721535  0.02850393 0.18573859]
# Shape Features: [1.8, 22.0, 20.485281109809875]
# Angle Features: []
# Curvature Features: [0.4896588943200853, 0.19055509678953525, 0.2961961744018027, 0.21948150372219083]
# Label: 190
# Stroke Features: [0.12116595 0.         0.         ... 0.22851089 0.24305836 0.20131549]
# Shape Features: [4.116279069767442, 7392.0, 436.0]
# Angle Features: []
# Curvature Features: [0.94805944896852, 0.4312539901375873, 0.694027770302063, 0.26485007412064676, 0.22079532748488115, 0.11835032766183297, 0.19933357915787064, 0.21648076379556488]
# Label: 191
# Stroke Features: [0.20633594 0.02545817 0.1610116  ... 0.11781141 0.11642263 0.06585858]
# Shape Features: [4.444444444444445, 98.0, 85.79898953437805]
# Angle Features: []
# Curvature Features: [0.94805944896852, 0.4312539901375873, 0.21955396934247978, 0.30631983943075386, 0.20025068932828505, 0.13592211726498113, 0.42350540054275637, 0.1513194963163476, 0.187282122645392]
# Label: 192
# Stroke Features: [0.10243297 0.         0.         ... 0.01447185 0.         0.        ]
# Shape Features: [3.7551020408163267, 8784.0, 462.0]
# Angle Features: []
# Curvature Features: [0.201954200045195, 0.6141880114411227, 0.21330989765443417, 0.22656137304415924]
# Label: 193
# Stroke Features: [0.31468349 0.07456227 0.1178933  ... 0.31716688 0.         0.        ]
# Shape Features: [1.0, 0.0, 0.0]
# Angle Features: []
# Curvature Features: [0.10995574287564276, 0.6921569237351011, 0.11728061600950067, 0.2326907930966641, 0.1899930655412525, 0.2002208300424365]
# Label: 194
# Stroke Features: [0.27120988 0.         0.11314744 ... 0.20317535 0.03569427 0.        ]
# Shape Features: [1.2727272727272727, 85.0, 40.14213538169861]
# Angle Features: []
# Curvature Features: [0.3298684871203395, 0.3086551443733947, 0.1729874056952117, 0.2941728509567704, 0.16362461737446837, 0.3612691596406082, 0.5207740921309088, 0.2916077585711951, 0.5921933187393925, 0.25927050476229585]
# Label: 195
# Stroke Features: [0.35246737 0.         0.         ... 0.29019379 0.         0.        ]
# Shape Features: [2.0317460317460316, 7874.0, 378.0]
# Angle Features: []
# Curvature Features: [0.26429260555468415, 0.43136201628411225, 0.28836629032615935]
# Label: 196
# Stroke Features: [0.31127899 0.         0.0652284  ... 0.0940478  0.         0.        ]
# Shape Features: [3.38, 8010.5, 614.3259009122849]
# Angle Features: []
# Curvature Features: [0.5922098044963047, 0.11795920724203551, 0.12046290098792704, 0.350837935560254, 0.1974063070583329, 0.2703609813060423, 0.26292619648419135]
# Label: 197
# Stroke Features: [0.07593508 0.04631147 0.00398114 ... 0.22703338 0.25886295 0.12179541]
# Shape Features: [3.0, 185.5, 113.84061968326569]
# Angle Features: []
# Curvature Features: [0.34890955668405593, 0.3660839991193405, 0.3346719226669065, 0.24329763035035556, 0.26285116955367066]
# Label: 198
# Stroke Features: [0.02671961 0.01007406 0.01285917 ... 0.02962765 0.02482038 0.01755066]
# Shape Features: [2.6136363636363638, 4902.0, 314.0]
# Angle Features: []
# Curvature Features: [0.24990866201331868, 0.14412908160057133, 0.3862938777664152, 0.20835529804053565, 0.2044817429381594, 0.17342156169257647]
# Label: 199
# Stroke Features: [0.33255718 0.         0.03710135 ... 0.1121747  0.04434095 0.        ]
# Shape Features: [3.6808510638297873, 7123.0, 965.7888842821121]
# Angle Features: []
# Curvature Features: [0.28187509871444416, 0.2922289071639801, 0.5286997877766149, 0.39478044413939734, 0.24352912068989546, 0.2785834690869315, 0.19728526390073456]
# Label: 200
# Stroke Features: [0.39769343 0.26638065 0.06738957 ... 0.02635433 0.         0.00841858]
# Shape Features: [2.6792452830188678, 7179.5, 495.3553384542465]
# Angle Features: []
# Curvature Features: [0.26076478603561903, 0.1916269372742533, 0.2646941753220917]
# Label: 201
# Stroke Features: [0.28256285 0.         0.19897339 ... 0.25115082 0.25043642 0.        ]
# Shape Features: [1.0, 0.0, 0.0]
# Angle Features: []
# Curvature Features: [0.39520543107876926, 1.0630783470323464, 0.5643015400383948, 0.22328509566706975, 0.386714244984613, 0.3010495922545047, 0.26289505622213616, 0.21943614933943284]
# Label: 202
# Stroke Features: [0.26079089 0.         0.08714138 ... 0.15787263 0.         0.        ]
# Shape Features: [2.660377358490566, 7280.0, 384.0]
# Angle Features: []
# Curvature Features: [0.22884561089261143, 0.27123175747927164, 0.3041795141884641, 0.18745342753762653]
# Label: 203
# Stroke Features: [0.17429073 0.         0.         ... 0.25711121 0.07432857 0.03503882]
# Shape Features: [2.3424657534246576, 11951.0, 659.2548331022263]
# Angle Features: [-17.062857173461396]
# Curvature Features: [0.31404028787221805, 0.3409889394715578, 0.1898479036834189]
# Label: 204
# Stroke Features: [0.29237286 0.07363018 0.06985172 ... 0.05404451 0.01758971 0.04715941]
# Shape Features: [4.944444444444445, 518.0, 192.08326017856598]
# Angle Features: []
# Curvature Features: [0.7853981633974483, 0.15971114469783665, 0.4955778312113815, 0.28787009029567284, 0.19972097833526617, 0.2820726674649281]
# Label: 205
# Stroke Features: [0.229119   0.         0.         ... 0.09695483 0.03832476 0.        ]
# Shape Features: [2.0, 0.0, 2.0]
# Angle Features: []
# Curvature Features: [0.3097852185557351, 0.21386424752885308, 0.4165653409426318, 0.189803828994938, 0.2958181695343275, 0.24566828698992216]
# Label: 206
# Stroke Features: [0.10120194 0.03232777 0.04089176 ... 0.25988505 0.04109144 0.17433621]
# Shape Features: [2.0, 0.0, 2.0]
# Angle Features: []
# Curvature Features: [0.24938726686217924, 0.38729376326823456, 0.20481322447830935]
# Label: 207
# Stroke Features: [0.08788008 0.         0.20713531 ... 0.03733746 0.00977005 0.        ]
# Shape Features: [7.4, 43.0, 75.31370830535889]
# Angle Features: []
# Curvature Features: [0.15394011980442326, 0.1886847408300135, 0.1867136229397437, 0.30261487127238623]
# Label: 208
# Stroke Features: [0.32724732 0.06192967 0.04497817 ... 0.03347786 0.         0.        ]
# Shape Features: [3.6666666666666665, 301.5, 169.15432798862457]
# Angle Features: []
# Curvature Features: [0.18933864400313144, 0.3795773736994478, 0.24674996025402507, 0.528864083701674]
# Label: 209
# Stroke Features: [0.09968239 0.02786208 0.15859372 ... 0.10533002 0.16217891 0.19420922]
# Shape Features: [1.0, 0.0, 0.0]
# Angle Features: []
# Curvature Features: [0.23927951436057604, 0.29827648702260073, 0.3617146639525889, 0.3243451399280207]
# Label: 210
# Stroke Features: [0.30098192 0.         0.11359448 ... 0.22882074 0.08349171 0.03935837]
# Shape Features: [3.0, 0.0, 4.0]
# Angle Features: []
# Curvature Features: [0.19658242761365247, 0.16933511724698627, 0.3174669763156338, 0.2078529276141468, 0.08943469703953039, 0.25617066729950916]
# Label: 211
# Stroke Features: [0.20076475 0.07347428 0.02185727 ... 0.01259194 0.02840975 0.01964062]
# Shape Features: [2.025, 3120.0, 238.0]
# Angle Features: []
# Curvature Features: [0.6460231675055526, 0.4071202609387189, 0.5239079105017148, 0.21734943606254628, 0.22678530208131972, 0.21608388627768876]
# Label: 212
# Stroke Features: [0.32164591 0.08082508 0.20447307 ... 0.16216227 0.20512085 0.        ]
# Shape Features: [3.08955223880597, 13549.0, 567.798989534378]
# Angle Features: []
# Curvature Features: [0.3450566941914788, 0.3673076349050843, 0.41794951264950236, 0.2626899596516804, 0.3096914372392062, 0.3078677127499736, 0.30088002137558256]

# %%
import os
import numpy as np

def extract_features_from_images(images_folder):
    features_list = []
    for filename in os.listdir(images_folder):
        image_path = os.path.join(images_folder, filename)
        # Read the image and extract features (replace this with your feature extraction method)
        features = np.random.rand(10)  # Dummy features for demonstration
        features_list.append((filename, features))
    return features_list

def compare_with_dataset(sample_features, dataset_features, threshold=0.5):
    matched_images = []
    for sample_filename, sample_feature in sample_features:
        for dataset_filename, dataset_feature in dataset_features:
            # Calculate distance between sample and dataset features (replace this with your distance metric)
            distance = np.linalg.norm(sample_feature - dataset_feature)
            # If the distance is below the threshold, consider it a match
            if distance < threshold:
                matched_images.append(dataset_filename)
                break  # Break out of the inner loop since we found a match for the current sample image
    return matched_images

# Paths to sample images and dataset images folders
sample_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample images"
dataset_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain"

# Extract features from sample images and dataset images
sample_features = extract_features_from_images(sample_images_folder)
dataset_features = extract_features_from_images(dataset_images_folder)

# Set a threshold for considering a match (adjust as needed)
threshold = 0.5

# Compare sample features with dataset features
matched_images = compare_with_dataset(sample_features, dataset_features, threshold)

# Print matched image names or numbers
print("Matched images from the dataset:")
for image_name in matched_images:
    print(image_name)

# Optionally, you can also visualize the matched images
# Out:
# Matched images from the dataset:

# %%
import os
import numpy as np

def extract_features_from_images(images_folder):
    features_list = []
    for filename in os.listdir(images_folder):
        image_path = os.path.join(images_folder, filename)
        # Read the image and extract features (replace this with your feature extraction method)
        features = np.random.rand(10)  # Dummy features for demonstration
        features_list.append((filename, features))
    return features_list

def compare_with_dataset(sample_features, dataset_features, threshold=0.5):
    matched_images = []
    for sample_filename, sample_feature in sample_features:
        for dataset_filename, dataset_feature in dataset_features:
            # Calculate distance between sample and dataset features (replace this with your distance metric)
            distance = np.linalg.norm(sample_feature - dataset_feature)
            print(f"Distance between {sample_filename} and {dataset_filename}: {distance}")
            # If the distance is below the threshold, consider it a match
            if distance < threshold:
                matched_images.append((sample_filename, dataset_filename))
                break  # Break out of the inner loop since we found a match for the current sample image
    return matched_images

# Paths to sample images and dataset images folders
sample_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample images"
dataset_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain"

# Extract features from sample images and dataset images
sample_features = extract_features_from_images(sample_images_folder)
dataset_features = extract_features_from_images(dataset_images_folder)

# Set a threshold for considering a match (adjust as needed)
threshold = 0.1  # Lower the threshold to increase the chances of finding matches

# Compare sample features with dataset features
matched_images = compare_with_dataset(sample_features, dataset_features, threshold)

# Print matched image names or numbers along with the corresponding sample image names
if matched_images:
    print("Matched images from the dataset:")
    for sample_image, dataset_image in matched_images:
        print(f"Sample Image: {sample_image}, Matched Dataset Image: {dataset_image}")
else:
    print("No matching images found in the dataset.")
# Out:
# Distance between 121.jpg and 122.jpg: 1.2447070170436367
# Distance between 121.jpg and 123.jpg: 1.1098740516933254
# Distance between 121.jpg and 124.jpg: 1.5207528448708652
# Distance between 121.jpg and 125.jpg: 0.837242409107747
# Distance between 121.jpg and 126.jpg: 1.5775923034156643
# Distance between 121.jpg and 127.jpg: 1.3094638597271862
# Distance between 121.jpg and 128.jpg: 1.2573828141559111
# Distance between 121.jpg and 129.jpg: 1.2234025719136403
# Distance between 121.jpg and 130.jpg: 1.3792095028204023
# Distance between 121.jpg and 131.jpg: 1.311863722467605
# Distance between 121.jpg and 133.jpg: 1.055495286605202
# Distance between 121.jpg and 134.jpg: 1.819160154526251
# Distance between 121.jpg and 135.jpg: 1.7233962629836368
# Distance between 121.jpg and 136.jpg: 1.6264445339430624
# Distance between 121.jpg and 137.jpg: 1.319501697354919
# Distance between 121.jpg and 138.jpg: 1.397341046320521
# Distance between 121.jpg and 139.jpg: 1.3980375792699746
# Distance between 121.jpg and 140.jpg: 1.8307817692672959
# Distance between 121.jpg and 141.jpg: 1.58196081603596
# Distance between 121.jpg and 142.jpg: 1.6509692273839087
# Distance between 121.jpg and 143.jpg: 1.3359538665225887
# Distance between 121.jpg and 144.jpg: 1.534328664086801
# Distance between 121.jpg and 145.jpg: 1.389020958675658
# Distance between 121.jpg and 146.jpg: 1.59944390314264
# Distance between 121.jpg and 147.jpg: 1.4149030011093062
# Distance between 121.jpg and 148.jpg: 1.0786153015215356
# Distance between 121.jpg and 149.jpg: 1.0751709802279656
# Distance between 121.jpg and 150.jpg: 0.9984364330381557
# Distance between 121.jpg and 151.jpg: 1.764439161081076
# Distance between 121.jpg and 153.jpg: 1.284365005657157
# Distance between 121.jpg and 154.jpg: 1.1569176242324237
# Distance between 121.jpg and 155.jpg: 1.6295583074628335
# Distance between 121.jpg and 156.jpg: 1.3285067710063496
# Distance between 121.jpg and 157.jpg: 1.2739587201262916
# Distance between 121.jpg and 158.jpg: 1.508728357958109
# Distance between 121.jpg and 159.jpg: 1.2956486888618002
# Distance between 121.jpg and 160.jpg: 1.2655337439019887
# Distance between 121.jpg and 161.jpg: 1.440956974982649
# Distance between 121.jpg and 162.jpg: 1.540588217872657
# Distance between 121.jpg and 163.jpg: 1.5263976994095931
# Distance between 121.jpg and 164.jpg: 1.4069041941906077
# Distance between 121.jpg and 165.jpg: 1.5520619324085985
# Distance between 121.jpg and 166.jpg: 1.2421240530738247
# Distance between 121.jpg and 167.jpg: 1.1828603899642114
# Distance between 121.jpg and 168.jpg: 1.0417065178830822
# Distance between 121.jpg and 169.jpg: 1.2272069524413234
# Distance between 121.jpg and 170.jpg: 1.60998442363558
# Distance between 121.jpg and 171.jpg: 1.6256269743465854
# Distance between 121.jpg and 172.jpg: 1.6459900557875213
# Distance between 121.jpg and 173.jpg: 1.6484508125363242
# Distance between 121.jpg and 174.jpg: 1.5967178390954158
# Distance between 121.jpg and 175.jpg: 1.3580431546748628
# Distance between 121.jpg and 176.jpg: 1.411697297541375
# Distance between 121.jpg and 177.jpg: 1.4309752564975697
# Distance between 121.jpg and 178.jpg: 1.3100774145985403
# Distance between 121.jpg and 179.jpg: 1.2013092045130442
# Distance between 121.jpg and 180.jpg: 1.7284904078123313
# Distance between 121.jpg and 181.jpg: 1.4293648003971864
# Distance between 121.jpg and 182.jpg: 1.4714709907667798
# Distance between 121.jpg and 183.jpg: 1.603192346253329
# Distance between 121.jpg and 184.jpg: 1.3779643960918464
# Distance between 121.jpg and 185.jpg: 0.7449161966496995
# Distance between 121.jpg and 186.jpg: 1.1555771803251542
# Distance between 121.jpg and 187.jpg: 1.3997292030004669
# Distance between 121.jpg and 188.jpg: 1.2040379141242556
# Distance between 121.jpg and 189.jpg: 1.5301898984936102
# Distance between 121.jpg and 190.jpg: 1.2163832581460488
# Distance between 121.jpg and 191.jpg: 1.61669054299137
# Distance between 121.jpg and 192.jpg: 1.5265322647026895
# Distance between 121.jpg and 193.jpg: 1.5134733012139248
# Distance between 121.jpg and 194.jpg: 1.4813131266154551
# Distance between 121.jpg and 195.jpg: 1.6550557921044917
# Distance between 121.jpg and 196.jpg: 1.385660294580014
# Distance between 121.jpg and 197.jpg: 1.3300602271606097
# Distance between 121.jpg and 198.jpg: 1.3630035991116554
# Distance between 121.jpg and 199.jpg: 1.0930006117633695
# Distance between 121.jpg and 200.jpg: 1.0695764569566417
# Distance between 121.jpg and 201.jpg: 1.4339722155130699
# Distance between 121.jpg and 202.jpg: 1.6605787862427517
# Distance between 121.jpg and 203.jpg: 0.8250587314691032
# Distance between 121.jpg and 204.jpg: 1.3121044793037733
# Distance between 121.jpg and 205.jpg: 1.4646968852109048
# Distance between 121.jpg and 206.jpg: 0.9279594635818876
# Distance between 121.jpg and 207.jpg: 1.1505707621312904
# Distance between 121.jpg and 208.jpg: 1.2521716151142923
# Distance between 121.jpg and 209.jpg: 1.7443282266230034
# Distance between 121.jpg and 210.jpg: 1.5534367084953773
# Distance between 121.jpg and 211.jpg: 1.4192182960491149
# Distance between 121.jpg and 212.jpg: 1.3595935935190369
# Distance between 132.jpg and 122.jpg: 1.5291313863517764
# Distance between 132.jpg and 123.jpg: 1.1944522454720061
# Distance between 132.jpg and 124.jpg: 1.5014641801128314
# Distance between 132.jpg and 125.jpg: 1.0458744095129624
# Distance between 132.jpg and 126.jpg: 1.1444715003349721
# Distance between 132.jpg and 127.jpg: 1.3749557093034477
# Distance between 132.jpg and 128.jpg: 1.4483020880503603
# Distance between 132.jpg and 129.jpg: 1.4028114787541621
# Distance between 132.jpg and 130.jpg: 1.1701261240832206
# Distance between 132.jpg and 131.jpg: 1.5915485863723242
# Distance between 132.jpg and 133.jpg: 1.4772417255703778
# Distance between 132.jpg and 134.jpg: 1.5354595306180245
# Distance between 132.jpg and 135.jpg: 1.5685207717958112
# Distance between 132.jpg and 136.jpg: 1.7574446042042031
# Distance between 132.jpg and 137.jpg: 1.4097973047052237
# Distance between 132.jpg and 138.jpg: 1.4474922410293045
# Distance between 132.jpg and 139.jpg: 1.452981851774788
# Distance between 132.jpg and 140.jpg: 1.6384809166024725
# Distance between 132.jpg and 141.jpg: 1.8585507655777773
# Distance between 132.jpg and 142.jpg: 1.4227734970258779
# Distance between 132.jpg and 143.jpg: 1.3255511499253068
# Distance between 132.jpg and 144.jpg: 1.204798896442936
# Distance between 132.jpg and 145.jpg: 1.6335106782587463
# Distance between 132.jpg and 146.jpg: 1.1529495987927187
# Distance between 132.jpg and 147.jpg: 1.6384629062836424
# Distance between 132.jpg and 148.jpg: 1.0265906511691774
# Distance between 132.jpg and 149.jpg: 1.4042543692224418
# Distance between 132.jpg and 150.jpg: 1.3298412162505988
# Distance between 132.jpg and 151.jpg: 1.4402653244668755
# Distance between 132.jpg and 153.jpg: 1.621512877580785
# Distance between 132.jpg and 154.jpg: 1.6337286693234374
# Distance between 132.jpg and 155.jpg: 1.5237937727343351
# Distance between 132.jpg and 156.jpg: 0.7711475684356458
# Distance between 132.jpg and 157.jpg: 1.1665368569206844
# Distance between 132.jpg and 158.jpg: 1.535610678015431
# Distance between 132.jpg and 159.jpg: 1.0889440968306199
# Distance between 132.jpg and 160.jpg: 1.1884249976270191
# Distance between 132.jpg and 161.jpg: 1.450357519091261
# Distance between 132.jpg and 162.jpg: 1.4312209644375558
# Distance between 132.jpg and 163.jpg: 1.3419515236946964
# Distance between 132.jpg and 164.jpg: 1.3486562693077024
# Distance between 132.jpg and 165.jpg: 0.9766183313378876
# Distance between 132.jpg and 166.jpg: 1.5197401895285245
# Distance between 132.jpg and 167.jpg: 1.524614991319489
# Distance between 132.jpg and 168.jpg: 1.4054384445740786
# Distance between 132.jpg and 169.jpg: 0.919928750349718
# Distance between 132.jpg and 170.jpg: 1.6249520197468563
# Distance between 132.jpg and 171.jpg: 0.7487669969956313
# Distance between 132.jpg and 172.jpg: 1.5414668245966698
# Distance between 132.jpg and 173.jpg: 1.3711675123890505
# Distance between 132.jpg and 174.jpg: 1.5244968825080532
# Distance between 132.jpg and 175.jpg: 1.1144401895358522
# Distance between 132.jpg and 176.jpg: 1.7209778028552782
# Distance between 132.jpg and 177.jpg: 0.989535474734304
# Distance between 132.jpg and 178.jpg: 1.0337503543211006
# Distance between 132.jpg and 179.jpg: 1.3701029711276715
# Distance between 132.jpg and 180.jpg: 1.4174273048770654
# Distance between 132.jpg and 181.jpg: 1.4586350689277798
# Distance between 132.jpg and 182.jpg: 1.5010986056920517
# Distance between 132.jpg and 183.jpg: 1.6472815780545453
# Distance between 132.jpg and 184.jpg: 1.4003649888432654
# Distance between 132.jpg and 185.jpg: 1.2944808077395584
# Distance between 132.jpg and 186.jpg: 1.1230661976368228
# Distance between 132.jpg and 187.jpg: 1.5489936987149402
# Distance between 132.jpg and 188.jpg: 1.4513888297847826
# Distance between 132.jpg and 189.jpg: 1.4621159985377945
# Distance between 132.jpg and 190.jpg: 1.0182045600913208
# Distance between 132.jpg and 191.jpg: 1.438516996010958
# Distance between 132.jpg and 192.jpg: 1.2420902032885237
# Distance between 132.jpg and 193.jpg: 1.2095782802457948
# Distance between 132.jpg and 194.jpg: 1.0387050357380867
# Distance between 132.jpg and 195.jpg: 1.3469930148859
# Distance between 132.jpg and 196.jpg: 1.522802268185498
# Distance between 132.jpg and 197.jpg: 1.3417336670738411
# Distance between 132.jpg and 198.jpg: 1.1096835966016587
# Distance between 132.jpg and 199.jpg: 1.515801123566259
# Distance between 132.jpg and 200.jpg: 1.4039988487775958
# Distance between 132.jpg and 201.jpg: 1.4493772821209754
# Distance between 132.jpg and 202.jpg: 1.7531360637907327
# Distance between 132.jpg and 203.jpg: 1.1370005187745171
# Distance between 132.jpg and 204.jpg: 1.0954417081123657
# Distance between 132.jpg and 205.jpg: 1.1343863715945663
# Distance between 132.jpg and 206.jpg: 1.161613416219583
# Distance between 132.jpg and 207.jpg: 1.3222459288537134
# Distance between 132.jpg and 208.jpg: 1.7861601390348745
# Distance between 132.jpg and 209.jpg: 1.5015398059071563
# Distance between 132.jpg and 210.jpg: 1.0222097999115853
# Distance between 132.jpg and 211.jpg: 0.9153705223744812
# Distance between 132.jpg and 212.jpg: 1.1003655514989492
# Distance between 153.jpg and 122.jpg: 1.3520066370952737
# Distance between 153.jpg and 123.jpg: 1.1005200708325222
# Distance between 153.jpg and 124.jpg: 1.2827542752424814
# Distance between 153.jpg and 125.jpg: 1.0634219402648943
# Distance between 153.jpg and 126.jpg: 0.8895661517217482
# Distance between 153.jpg and 127.jpg: 1.2045953461974381
# Distance between 153.jpg and 128.jpg: 1.4054603778415091
# Distance between 153.jpg and 129.jpg: 1.3407328022113227
# Distance between 153.jpg and 130.jpg: 0.8536426553732306
# Distance between 153.jpg and 131.jpg: 0.9582143028509751
# Distance between 153.jpg and 133.jpg: 1.2464269684968803
# Distance between 153.jpg and 134.jpg: 1.1274851452365258
# Distance between 153.jpg and 135.jpg: 1.2403426720291728
# Distance between 153.jpg and 136.jpg: 1.1389626137512303
# Distance between 153.jpg and 137.jpg: 1.406168428603168
# Distance between 153.jpg and 138.jpg: 1.1004113207879318
# Distance between 153.jpg and 139.jpg: 1.2389621365906829
# Distance between 153.jpg and 140.jpg: 1.145365340529285
# Distance between 153.jpg and 141.jpg: 1.4061548865955271
# Distance between 153.jpg and 142.jpg: 1.1498982123219077
# Distance between 153.jpg and 143.jpg: 1.0571344938328724
# Distance between 153.jpg and 144.jpg: 1.0014947137136474
# Distance between 153.jpg and 145.jpg: 1.2130211372408517
# Distance between 153.jpg and 146.jpg: 1.1936134464473434
# Distance between 153.jpg and 147.jpg: 1.1715855101205157
# Distance between 153.jpg and 148.jpg: 1.1816929950947435
# Distance between 153.jpg and 149.jpg: 1.5048835706073347
# Distance between 153.jpg and 150.jpg: 1.3969555270661762
# Distance between 153.jpg and 151.jpg: 1.1248181786271292
# Distance between 153.jpg and 153.jpg: 1.3297221127408687
# Distance between 153.jpg and 154.jpg: 1.3609349057623903
# Distance between 153.jpg and 155.jpg: 1.1928921018393843
# Distance between 153.jpg and 156.jpg: 0.8142944785313565
# Distance between 153.jpg and 157.jpg: 0.8996584431471955
# Distance between 153.jpg and 158.jpg: 1.2386979663710556
# Distance between 153.jpg and 159.jpg: 1.0254614186966802
# Distance between 153.jpg and 160.jpg: 0.9632371030160078
# Distance between 153.jpg and 161.jpg: 1.5855964898796153
# Distance between 153.jpg and 162.jpg: 0.8026544863899682
# Distance between 153.jpg and 163.jpg: 0.8706812395713287
# Distance between 153.jpg and 164.jpg: 0.8909419908588478
# Distance between 153.jpg and 165.jpg: 0.8178486874778125
# Distance between 153.jpg and 166.jpg: 1.5378299886847335
# Distance between 153.jpg and 167.jpg: 1.2996400630087537
# Distance between 153.jpg and 168.jpg: 1.0656372814481727
# Distance between 153.jpg and 169.jpg: 0.964326124080507
# Distance between 153.jpg and 170.jpg: 0.8380780152887257
# Distance between 153.jpg and 171.jpg: 1.2317112141696898
# Distance between 153.jpg and 172.jpg: 0.9856200563648717
# Distance between 153.jpg and 173.jpg: 0.7896044181905814
# Distance between 153.jpg and 174.jpg: 1.2073607282284535
# Distance between 153.jpg and 175.jpg: 0.496187778479338
# Distance between 153.jpg and 176.jpg: 1.369788149409919
# Distance between 153.jpg and 177.jpg: 0.5019787592408028
# Distance between 153.jpg and 178.jpg: 0.5968769953586249
# Distance between 153.jpg and 179.jpg: 1.123737676881188
# Distance between 153.jpg and 180.jpg: 1.0891262447594545
# Distance between 153.jpg and 181.jpg: 1.1940172258706545
# Distance between 153.jpg and 182.jpg: 1.1043858810326548
# Distance between 153.jpg and 183.jpg: 1.2958936005989798
# Distance between 153.jpg and 184.jpg: 1.0886276641926462
# Distance between 153.jpg and 185.jpg: 1.3434684000731294
# Distance between 153.jpg and 186.jpg: 1.127749234658544
# Distance between 153.jpg and 187.jpg: 1.1975556316273837
# Distance between 153.jpg and 188.jpg: 1.2270650301718287
# Distance between 153.jpg and 189.jpg: 1.344847351177309
# Distance between 153.jpg and 190.jpg: 0.990337098418719
# Distance between 153.jpg and 191.jpg: 0.6873898785337061
# Distance between 153.jpg and 192.jpg: 1.122415349436613
# Distance between 153.jpg and 193.jpg: 1.0306263566828957
# Distance between 153.jpg and 194.jpg: 1.1462010722873353
# Distance between 153.jpg and 195.jpg: 1.0476749822411051
# Distance between 153.jpg and 196.jpg: 1.4316855050227577
# Distance between 153.jpg and 197.jpg: 1.0394334974462835
# Distance between 153.jpg and 198.jpg: 1.027395693811855
# Distance between 153.jpg and 199.jpg: 1.4289809941043432
# Distance between 153.jpg and 200.jpg: 1.1967319031031138
# Distance between 153.jpg and 201.jpg: 1.2630234836185852
# Distance between 153.jpg and 202.jpg: 1.6204037597352083
# Distance between 153.jpg and 203.jpg: 1.5002976713567544
# Distance between 153.jpg and 204.jpg: 1.2304165908307594
# Distance between 153.jpg and 205.jpg: 1.1423789277546081
# Distance between 153.jpg and 206.jpg: 1.3564445045328184
# Distance between 153.jpg and 207.jpg: 1.6603138862118487
# Distance between 153.jpg and 208.jpg: 1.5407393698733387
# Distance between 153.jpg and 209.jpg: 1.0625562308293803
# Distance between 153.jpg and 210.jpg: 1.4939892151237832
# Distance between 153.jpg and 211.jpg: 1.1034909071913295
# Distance between 153.jpg and 212.jpg: 1.0960847587361502
# No matching images found in the dataset.

# %%
import os
import numpy as np

def extract_features_from_images(images_folder):
    features_list = []
    for filename in os.listdir(images_folder):
        image_path = os.path.join(images_folder, filename)
        # Read the image and extract features (replace this with your feature extraction method)
        features = np.random.rand(10)  # Dummy features for demonstration
        features_list.append((filename, features))
    return features_list

def compare_with_dataset(sample_features, dataset_features, threshold=0.5):
    matched_images = []
    for sample_filename, sample_feature in sample_features:
        matched_dataset_index = None
        for dataset_index, (dataset_filename, dataset_feature) in enumerate(dataset_features):
            # Calculate distance between sample and dataset features (replace this with your distance metric)
            distance = np.linalg.norm(sample_feature - dataset_feature)
            # If the distance is below the threshold, consider it a match
            if distance < threshold:
                matched_dataset_index = dataset_index
                print(f"Matched sample image: {sample_filename}, matched dataset image index: {matched_dataset_index}")
                break  # Break out of the inner loop since we found a match for the current sample image
        matched_images.append((sample_filename, matched_dataset_index))
    return matched_images

# Paths to sample images and dataset images folders
sample_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample images"
dataset_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain"

# Extract features from sample images and dataset images
sample_features = extract_features_from_images(sample_images_folder)
dataset_features = extract_features_from_images(dataset_images_folder)

# Set a threshold for considering a match (adjust as needed)
threshold = 0.1  # Lower the threshold to increase the chances of finding matches

# Compare sample features with dataset features
matched_images = compare_with_dataset(sample_features, dataset_features, threshold)

# Print matched image names or numbers along with the corresponding sample image names
if matched_images:
    print("Matched images from the dataset:")
    for sample_image, matched_dataset_index in matched_images:
        if matched_dataset_index is not None:
            print(f"Sample Image: {sample_image}, Matched Dataset Image Index: {matched_dataset_index}")
else:
    print("No matching images found in the dataset.")
# Out:
# Matched images from the dataset:

# %%
import os
import cv2
import numpy as np
from skimage.feature import hog

def extract_stroke_features(image):
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    return features

def extract_shape_features(image):
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    shape_features = []
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        area = cv2.contourArea(contour)
        perimeter = cv2.arcLength(contour, True)
        shape_features = [aspect_ratio, area, perimeter]
    return shape_features

def calculate_slant_angle(image):
    # Convert image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Threshold the image to obtain a binary image
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    
    # Find contours in the binary image
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Find the largest contour (signature)
    largest_contour = max(contours, key=cv2.contourArea)
    
    # Check if the contour contains at least 5 points
    if len(largest_contour) < 5:
        # If the contour has too few points, return a default angle (0 degrees)
        return 0
    
    # Perform principal component analysis (PCA) on the largest contour
    _, _, angle = cv2.fitEllipse(largest_contour)
    
    # The angle returned by fitEllipse is the angle of rotation of the fitted ellipse
    # We use this as an estimate of the slant angle of the signature
    return angle


def extract_angle_features(image):
    # Calculate angle features (e.g., angles between strokes)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    lines = cv2.HoughLinesP(edges, 1, np.pi/180, threshold=100, minLineLength=100, maxLineGap=10)
    angle_features = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            angle = np.arctan2(y2 - y1, x2 - x1) * 180 / np.pi
            angle_features.append(angle)
    return angle_features

def extract_curvature_features(image):
    # Calculate curvature features
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    curvature_features = []
    if contours:
        for contour in contours:
            M = cv2.moments(contour)
            if M["m00"] != 0:
                cx = int(M["m10"] / M["m00"])
                cy = int(M["m01"] / M["m00"])
                cX, cY = cx, cy
                points = contour[:, 0]
                prev_point = points[0]
                total_distance = 0
                total_curvature = 0
                num_points = 0
                for point in points[1:]:
                    distance = np.linalg.norm(point - prev_point)
                    total_distance += distance
                    angle = np.arctan2(point[1] - prev_point[1], point[0] - prev_point[0])
                    curvature = np.abs(angle - prev_angle) / distance if num_points > 0 else 0
                    total_curvature += curvature
                    prev_point = point
                    prev_angle = angle
                    num_points += 1
                if num_points > 0:
                    mean_curvature = total_curvature / total_distance
                    curvature_features.append(mean_curvature)
    return curvature_features

def classify_sign(image):
    # Replace this with your own sign classification method
    # Example: Determine if the sign is angular, circular, or something else
    # You may use machine learning models, rules-based systems, etc.
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    
    # Simple rule-based classification
    if len(features) < 1000:
        return "Circular"
    else:
        return "Angular"

def assess_skill(image):
    # Replace this with your own method for assessing the overall skill of the signature
    # Example: Use machine learning models or rules-based systems to evaluate the signature's quality
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    
    # Simple rule-based assessment
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        if aspect_ratio > 0.5:
            return "Good"
        else:
            return "Poor"
    else:
        return "Poor"


def extract_additional_features(image):
    # Calculate length, height, ratio, integer ratio
    height, length, _ = image.shape
    ratio = length / height
    integer_ratio = int(ratio)
    
    # Classify the sign
    sign_classification = classify_sign(image)
    
    # Assess overall skill
    overall_skill = assess_skill(image)
    
    # Calculate centroid coordinates
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        contour = max(contours, key=cv2.contourArea)
        M = cv2.moments(contour)
        if M["m00"] != 0:
            centroid_x = int(M["m10"] / M["m00"])
            centroid_y = int(M["m01"] / M["m00"])
        else:
            centroid_x, centroid_y = -1, -1
    else:
        centroid_x, centroid_y = -1, -1
    
    # Calculate slant angle
    slant_angle = calculate_slant_angle(image)
    
    return {
        'Length': length,
        'Height': height,
        'Ratio (Length/Height)': ratio,
        'Integer Ratio': integer_ratio,
        'Sign Classification': sign_classification,
        'Overall Skill': overall_skill,
        'Centroid X': centroid_x,
        'Centroid Y': centroid_y,
        'Slant Angle': slant_angle
    }

def extract_features_from_images(sample_images_folder):
    features_list = []
    for filename in os.listdir(sample_images_folder):
        image_path = os.path.join(sample_images_folder, filename)
        
        # Extract label from filename
        label = os.path.splitext(filename)[0]
        
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue  # Skip this image if loading fails
        
        # Extract additional features
        additional_features = extract_additional_features(image)
        
        # Extract stroke features
        stroke_features = extract_stroke_features(image)
        
        # Extract shape features
        shape_features = extract_shape_features(image)
        
        # Extract angle features
        angle_features = extract_angle_features(image)
        
        # Extract curvature features
        curvature_features = extract_curvature_features(image)
        
        # Combine all features into a single feature vector
        all_features = np.concatenate((stroke_features, shape_features, angle_features, curvature_features))
        
        # Add features, label, and additional features to the list
        features_dict = {
            "label": label,
            "features": all_features,
            **additional_features
        }
        features_list.append(features_dict)
        
        # Print feature values
        print(f"Image: {filename}")
        print(f"Features: {features_dict}")
    
    print(f"Number of images processed: {len(features_list)}")
    return features_list

# Example usage:
sample_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\kabeer sample image"

features = extract_features_from_images(sample_images_folder)
# Out:
# Image: 1.jpg
# Features: {'label': '1', 'features': array([0.04132208, 0.        , 0.0233753 , ..., 0.32553102, 0.81145465,
#        0.36577128]), 'Length': 117, 'Height': 69, 'Ratio (Length/Height)': 1.6956521739130435, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 58, 'Centroid Y': 34, 'Slant Angle': 0}
# Image: 56.jpg
# Features: {'label': '56', 'features': array([0.02936837, 0.00273624, 0.0034611 , ..., 0.18845876, 0.35122746,
#        0.35669672]), 'Length': 118, 'Height': 62, 'Ratio (Length/Height)': 1.903225806451613, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 79, 'Centroid Y': 15, 'Slant Angle': 89.0597915649414}
# Number of images processed: 2

# %%
import os
import numpy as np

def extract_features_from_images(images_folder):
    features_list = []
    for filename in os.listdir(images_folder):
        image_path = os.path.join(images_folder, filename)
        # Read the image and extract features (replace this with your feature extraction method)
        features = np.random.rand(10)  # Dummy features for demonstration
        features_list.append((filename, features))
    return features_list

def compare_with_dataset(sample_features, dataset_features, threshold=0.5):
    matched_images = []
    for sample_filename, sample_feature in sample_features:
        matched_dataset_filenames = []  # List to store matched dataset filenames for the current sample image
        for dataset_filename, dataset_feature in dataset_features:
            # Calculate distance between sample and dataset features (replace this with your distance metric)
            distance = np.linalg.norm(sample_feature - dataset_feature)
            # If the distance is below the threshold, consider it a match
            if distance < threshold:
                matched_dataset_filenames.append(dataset_filename)
        matched_images.append((sample_filename, matched_dataset_filenames))  # Append tuple of sample image and matched dataset filenames
    return matched_images

# Paths to sample images and dataset images folders
sample_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample images"
dataset_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain"

# Extract features from sample images and dataset images
sample_features = extract_features_from_images(sample_images_folder)
dataset_features = extract_features_from_images(dataset_images_folder)

# Set a threshold for considering a match (adjust as needed)
threshold = 0.1  # Lower the threshold to increase the chances of finding matches

# Compare sample features with dataset features
matched_images = compare_with_dataset(sample_features, dataset_features, threshold)

# Print matched image names or numbers along with the corresponding sample image names
if matched_images:
    print("Matched images from the dataset:")
    for sample_image, matched_dataset_filenames in matched_images:
        if matched_dataset_filenames:
            print(f"Sample Image: {sample_image}, Matched Dataset Images: {', '.join(matched_dataset_filenames)}")
else:
    print("No matching images found in the dataset.")
# Out:
# Matched images from the dataset:

# %%
import os
import cv2
import numpy as np
from skimage.feature import hog

def extract_stroke_features(image):
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    return features

def extract_shape_features(image):
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    shape_features = []
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        area = cv2.contourArea(contour)
        perimeter = cv2.arcLength(contour, True)
        shape_features = [aspect_ratio, area, perimeter]
    return shape_features

def calculate_slant_angle(image):
    # Convert image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Threshold the image to obtain a binary image
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    
    # Find contours in the binary image
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Find the largest contour (signature)
    largest_contour = max(contours, key=cv2.contourArea)
    
    # Check if the contour contains at least 5 points
    if len(largest_contour) < 5:
        # If the contour has too few points, return a default angle (0 degrees)
        return 0
    
    # Perform principal component analysis (PCA) on the largest contour
    _, _, angle = cv2.fitEllipse(largest_contour)
    
    # The angle returned by fitEllipse is the angle of rotation of the fitted ellipse
    # We use this as an estimate of the slant angle of the signature
    return angle


def extract_angle_features(image):
    # Calculate angle features (e.g., angles between strokes)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    lines = cv2.HoughLinesP(edges, 1, np.pi/180, threshold=100, minLineLength=100, maxLineGap=10)
    angle_features = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            angle = np.arctan2(y2 - y1, x2 - x1) * 180 / np.pi
            angle_features.append(angle)
    return angle_features

def extract_curvature_features(image):
    # Calculate curvature features
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    curvature_features = []
    if contours:
        for contour in contours:
            M = cv2.moments(contour)
            if M["m00"] != 0:
                cx = int(M["m10"] / M["m00"])
                cy = int(M["m01"] / M["m00"])
                cX, cY = cx, cy
                points = contour[:, 0]
                prev_point = points[0]
                total_distance = 0
                total_curvature = 0
                num_points = 0
                for point in points[1:]:
                    distance = np.linalg.norm(point - prev_point)
                    total_distance += distance
                    angle = np.arctan2(point[1] - prev_point[1], point[0] - prev_point[0])
                    curvature = np.abs(angle - prev_angle) / distance if num_points > 0 else 0
                    total_curvature += curvature
                    prev_point = point
                    prev_angle = angle
                    num_points += 1
                if num_points > 0:
                    mean_curvature = total_curvature / total_distance
                    curvature_features.append(mean_curvature)
    return curvature_features

def classify_sign(image):
    # Replace this with your own sign classification method
    # Example: Determine if the sign is angular, circular, or something else
    # You may use machine learning models, rules-based systems, etc.
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    
    # Simple rule-based classification
    if len(features) < 1000:
        return "Circular"
    else:
        return "Angular"

def assess_skill(image):
    # Replace this with your own method for assessing the overall skill of the signature
    # Example: Use machine learning models or rules-based systems to evaluate the signature's quality
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    
    # Simple rule-based assessment
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        if aspect_ratio > 0.5:
            return "Good"
        else:
            return "Poor"
    else:
        return "Poor"


def extract_additional_features(image):
    # Calculate length, height, ratio, integer ratio
    height, length, _ = image.shape
    ratio = length / height
    integer_ratio = int(ratio)
    
    # Classify the sign
    sign_classification = classify_sign(image)
    
    # Assess overall skill
    overall_skill = assess_skill(image)
    
    # Calculate centroid coordinates
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        contour = max(contours, key=cv2.contourArea)
        M = cv2.moments(contour)
        if M["m00"] != 0:
            centroid_x = int(M["m10"] / M["m00"])
            centroid_y = int(M["m01"] / M["m00"])
        else:
            centroid_x, centroid_y = -1, -1
    else:
        centroid_x, centroid_y = -1, -1
    
    # Calculate slant angle
    slant_angle = calculate_slant_angle(image)
    
    return {
        'Length': length,
        'Height': height,
        'Ratio (Length/Height)': ratio,
        'Integer Ratio': integer_ratio,
        'Sign Classification': sign_classification,
        'Overall Skill': overall_skill,
        'Centroid X': centroid_x,
        'Centroid Y': centroid_y,
        'Slant Angle': slant_angle
    }

def extract_features_from_images(sample_images_folder):
    features_list = []
    for filename in os.listdir(sample_images_folder):
        image_path = os.path.join(sample_images_folder, filename)
        
        # Extract label from filename
        label = os.path.splitext(filename)[0]
        
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue  # Skip this image if loading fails
        
        # Extract additional features
        additional_features = extract_additional_features(image)
        
        # Extract stroke features
        stroke_features = extract_stroke_features(image)
        
        # Extract shape features
        shape_features = extract_shape_features(image)
        
        # Extract angle features
        angle_features = extract_angle_features(image)
        
        # Extract curvature features
        curvature_features = extract_curvature_features(image)
        
        # Combine all features into a single feature vector
        all_features = np.concatenate((stroke_features, shape_features, angle_features, curvature_features))
        
        # Add features, label, and additional features to the list
        features_dict = {
            "label": label,
            "features": all_features,
            **additional_features
        }
        features_list.append(features_dict)
        
        # Print feature values
        print(f"Image: {filename}")
        print(f"Features: {features_dict}")
    
    print(f"Number of images processed: {len(features_list)}")
    return features_list

# Example usage:
sample_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain"

features = extract_features_from_images(sample_images_folder)
# Out:
# Image: 122.jpg
# Features: {'label': '122', 'features': array([0.24647277, 0.        , 0.19918008, ..., 0.29002036, 0.2652823 ,
#        0.21901885]), 'Length': 169, 'Height': 56, 'Ratio (Length/Height)': 3.017857142857143, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 85, 'Centroid Y': 27, 'Slant Angle': 91.28682708740234}
# Image: 123.jpg
# Features: {'label': '123', 'features': array([0.34430633, 0.        , 0.        , ..., 0.16004909, 0.25191525,
#        0.34934821]), 'Length': 134, 'Height': 64, 'Ratio (Length/Height)': 2.09375, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 92, 'Centroid Y': 19, 'Slant Angle': 75.56608581542969}
# Image: 124.jpg
# Features: {'label': '124', 'features': array([0.42678198, 0.08928572, 0.42678198, ..., 0.35211241, 0.34662251,
#        0.20105621]), 'Length': 137, 'Height': 81, 'Ratio (Length/Height)': 1.691358024691358, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 68, 'Centroid Y': 40, 'Slant Angle': 0}
# Image: 125.jpg
# Features: {'label': '125', 'features': array([0.39019667, 0.06032594, 0.11446043, ..., 0.31210049, 0.18700663,
#        0.24071141]), 'Length': 179, 'Height': 74, 'Ratio (Length/Height)': 2.418918918918919, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 89, 'Centroid Y': 34, 'Slant Angle': 91.18515014648438}
# Image: 126.jpg
# Features: {'label': '126', 'features': array([0.35098322, 0.16516471, 0.        , ..., 0.23142328, 0.12456478,
#        0.15976461]), 'Length': 115, 'Height': 58, 'Ratio (Length/Height)': 1.9827586206896552, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 51, 'Centroid Y': 21, 'Slant Angle': 79.34481811523438}
# Image: 127.jpg
# Features: {'label': '127', 'features': array([0.28099869, 0.16605824, 0.21004888, ..., 0.25337799, 0.28536602,
#        0.22304865]), 'Length': 190, 'Height': 47, 'Ratio (Length/Height)': 4.042553191489362, 'Integer Ratio': 4, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 94, 'Centroid Y': 23, 'Slant Angle': 0}
# Image: 128.jpg
# Features: {'label': '128', 'features': array([0.35036702, 0.08438293, 0.        , ..., 0.52761407, 0.21120534,
#        0.22119301]), 'Length': 168, 'Height': 61, 'Ratio (Length/Height)': 2.7540983606557377, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 83, 'Centroid Y': 30, 'Slant Angle': 0}
# Image: 129.jpg
# Features: {'label': '129', 'features': array([0.08344126, 0.00400282, 0.00772015, ..., 0.20596451, 0.29169638,
#        0.21372119]), 'Length': 141, 'Height': 60, 'Ratio (Length/Height)': 2.35, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 61, 'Centroid Y': 18, 'Slant Angle': 79.2044677734375}
# Image: 130.jpg
# Features: {'label': '130', 'features': array([ 0.35541226,  0.        ,  0.26280156, ..., -7.65065096,
#         0.28453463,  0.22889119]), 'Length': 137, 'Height': 56, 'Ratio (Length/Height)': 2.4464285714285716, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 68, 'Centroid Y': 27, 'Slant Angle': 0}
# Image: 131.jpg
# Features: {'label': '131', 'features': array([0.        , 0.        , 0.        , ..., 0.12271807, 0.07648947,
#        0.33305375]), 'Length': 120, 'Height': 52, 'Ratio (Length/Height)': 2.3076923076923075, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 77, 'Centroid Y': 16, 'Slant Angle': 90.23107147216797}
# Image: 133.jpg
# Features: {'label': '133', 'features': array([0.14200465, 0.        , 0.        , ..., 0.2740635 , 0.47639176,
#        0.23067935]), 'Length': 122, 'Height': 67, 'Ratio (Length/Height)': 1.8208955223880596, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 58, 'Centroid Y': 24, 'Slant Angle': 80.00345611572266}
# Image: 134.jpg
# Features: {'label': '134', 'features': array([0.04449652, 0.00877733, 0.00361062, ..., 0.3648625 , 0.30342314,
#        0.19161826]), 'Length': 107, 'Height': 47, 'Ratio (Length/Height)': 2.276595744680851, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 54, 'Centroid Y': 20, 'Slant Angle': 98.31202697753906}
# Image: 135.jpg
# Features: {'label': '135', 'features': array([0.06555467, 0.        , 0.        , ..., 0.51944047, 0.8535071 ,
#        0.26667216]), 'Length': 135, 'Height': 55, 'Ratio (Length/Height)': 2.4545454545454546, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 87, 'Centroid Y': 20, 'Slant Angle': 84.49777221679688}
# Image: 136.jpg
# Features: {'label': '136', 'features': array([0.39444092, 0.        , 0.        , ..., 0.23399235, 0.26647625,
#        0.21733188]), 'Length': 172, 'Height': 62, 'Ratio (Length/Height)': 2.774193548387097, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 86, 'Centroid Y': 29, 'Slant Angle': 88.65807342529297}
# Image: 137.jpg
# Features: {'label': '137', 'features': array([0.11725957, 0.00905112, 0.00632133, ..., 0.41452592, 0.2491283 ,
#        0.16763088]), 'Length': 138, 'Height': 66, 'Ratio (Length/Height)': 2.090909090909091, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 62, 'Centroid Y': 22, 'Slant Angle': 76.85358428955078}
# Image: 138.jpg
# Features: {'label': '138', 'features': array([0.22815833, 0.        , 0.        , ..., 0.32494453, 0.29894766,
#        0.24200996]), 'Length': 143, 'Height': 65, 'Ratio (Length/Height)': 2.2, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 70, 'Centroid Y': 29, 'Slant Angle': 90.78755950927734}
# Image: 139.jpg
# Features: {'label': '139', 'features': array([0.37419258, 0.0598942 , 0.37419258, ..., 0.27165739, 0.28035327,
#        0.31829527]), 'Length': 173, 'Height': 61, 'Ratio (Length/Height)': 2.8360655737704916, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 85, 'Centroid Y': 29, 'Slant Angle': 89.4727554321289}
# Image: 140.jpg
# Features: {'label': '140', 'features': array([0.21378335, 0.05106995, 0.01614973, ..., 0.24590076, 0.22610013,
#        0.43849987]), 'Length': 151, 'Height': 46, 'Ratio (Length/Height)': 3.282608695652174, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 75, 'Centroid Y': 21, 'Slant Angle': 90.56396484375}
# Image: 141.jpg
# Features: {'label': '141', 'features': array([0.12484837, 0.        , 0.        , ..., 0.52359878, 0.48679369,
#        0.20545855]), 'Length': 159, 'Height': 57, 'Ratio (Length/Height)': 2.789473684210526, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 79, 'Centroid Y': 25, 'Slant Angle': 83.55333709716797}
# Image: 142.jpg
# Features: {'label': '142', 'features': array([  0.33866082,   0.15205018,   0.09616497, ..., -10.09105724,
#          0.35591617,   0.25002388]), 'Length': 172, 'Height': 61, 'Ratio (Length/Height)': 2.819672131147541, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 87, 'Centroid Y': 28, 'Slant Angle': 90.07624816894531}
# Image: 143.jpg
# Features: {'label': '143', 'features': array([0.36191671, 0.        , 0.07050067, ..., 0.15052439, 0.59311144,
#        0.29042641]), 'Length': 116, 'Height': 60, 'Ratio (Length/Height)': 1.9333333333333333, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 51, 'Centroid Y': 22, 'Slant Angle': 86.89753723144531}
# Image: 144.jpg
# Features: {'label': '144', 'features': array([0.        , 0.        , 0.        , ..., 0.3837607 , 0.28293356,
#        0.37823406]), 'Length': 165, 'Height': 50, 'Ratio (Length/Height)': 3.3, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 75, 'Centroid Y': 20, 'Slant Angle': 90.5782470703125}
# Image: 145.jpg
# Features: {'label': '145', 'features': array([0.09620211, 0.02359984, 0.00516744, ..., 0.2952528 , 0.2000302 ,
#        0.29978013]), 'Length': 118, 'Height': 66, 'Ratio (Length/Height)': 1.7878787878787878, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 56, 'Centroid Y': 22, 'Slant Angle': 77.58428955078125}
# Image: 146.jpg
# Features: {'label': '146', 'features': array([0.        , 0.        , 0.10641911, ..., 1.11778657, 0.25727256,
#        0.28175545]), 'Length': 131, 'Height': 67, 'Ratio (Length/Height)': 1.955223880597015, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 63, 'Centroid Y': 31, 'Slant Angle': 89.26143646240234}
# Image: 147.jpg
# Features: {'label': '147', 'features': array([0.1774753 , 0.        , 0.10457833, ..., 0.37705567, 0.19512124,
#        0.29673388]), 'Length': 120, 'Height': 60, 'Ratio (Length/Height)': 2.0, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 60, 'Centroid Y': 27, 'Slant Angle': 95.03276824951172}
# Image: 148.jpg
# Features: {'label': '148', 'features': array([0.30775772, 0.        , 0.        , ..., 0.28248378, 0.29637185,
#        0.2440208 ]), 'Length': 176, 'Height': 53, 'Ratio (Length/Height)': 3.3207547169811322, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 82, 'Centroid Y': 21, 'Slant Angle': 99.52277374267578}
# Image: 149.jpg
# Features: {'label': '149', 'features': array([0.04001669, 0.00854778, 0.00708232, ..., 0.273666  , 0.27388962,
#        0.29323191]), 'Length': 130, 'Height': 63, 'Ratio (Length/Height)': 2.0634920634920637, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 64, 'Centroid Y': 29, 'Slant Angle': 85.67007446289062}
# Image: 150.jpg
# Features: {'label': '150', 'features': array([0.15174944, 0.        , 0.        , ..., 0.15843607, 0.33011643,
#        0.26897182]), 'Length': 165, 'Height': 63, 'Ratio (Length/Height)': 2.619047619047619, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 73, 'Centroid Y': 19, 'Slant Angle': 83.88218688964844}
# Image: 151.jpg
# Features: {'label': '151', 'features': array([5.05076272e-01, 0.00000000e+00, 0.00000000e+00, ...,
#        9.29462984e+02, 2.49104626e-01, 2.47056452e-01]), 'Length': 183, 'Height': 65, 'Ratio (Length/Height)': 2.8153846153846156, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 92, 'Centroid Y': 31, 'Slant Angle': 0.0}
# Image: 154.jpg
# Features: {'label': '154', 'features': array([0.0803642 , 0.        , 0.01894202, ..., 0.30633445, 0.23531108,
#        0.21243228]), 'Length': 162, 'Height': 48, 'Ratio (Length/Height)': 3.375, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 111, 'Centroid Y': 31, 'Slant Angle': 91.95911407470703}
# Image: 155.jpg
# Features: {'label': '155', 'features': array([0.2754416 , 0.        , 0.21640736, ..., 0.        , 0.34627197,
#        0.32658894]), 'Length': 166, 'Height': 63, 'Ratio (Length/Height)': 2.634920634920635, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 83, 'Centroid Y': 30, 'Slant Angle': 87.71559143066406}
# Image: 156.jpg
# Features: {'label': '156', 'features': array([0.30718334, 0.        , 0.37151612, ..., 0.2328727 , 0.18230895,
#        0.27975147]), 'Length': 279, 'Height': 41, 'Ratio (Length/Height)': 6.804878048780488, 'Integer Ratio': 6, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 147, 'Centroid Y': 18, 'Slant Angle': 91.01760864257812}
# Image: 157.jpg
# Features: {'label': '157', 'features': array([0.06346369, 0.        , 0.02761575, ..., 0.25833309, 0.26856109,
#        0.30176102]), 'Length': 223, 'Height': 69, 'Ratio (Length/Height)': 3.2318840579710146, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 70, 'Centroid Y': 22, 'Slant Angle': 89.31143188476562}
# Image: 158.jpg
# Features: {'label': '158', 'features': array([0.06208349, 0.        , 0.04389966, ..., 0.31279801, 0.29730411,
#        0.29008128]), 'Length': 229, 'Height': 89, 'Ratio (Length/Height)': 2.5730337078651684, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 88, 'Centroid Y': 23, 'Slant Angle': 101.22886657714844}
# Image: 159.jpg
# Features: {'label': '159', 'features': array([0.        , 0.        , 0.        , ..., 0.18181707, 0.15671246,
#        0.25219139]), 'Length': 265, 'Height': 75, 'Ratio (Length/Height)': 3.533333333333333, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 138, 'Centroid Y': 35, 'Slant Angle': 89.0843505859375}
# Image: 160.jpg
# Features: {'label': '160', 'features': array([0.08911322, 0.02094611, 0.01487033, ..., 0.31362083, 0.44683688,
#        0.28799893]), 'Length': 173, 'Height': 52, 'Ratio (Length/Height)': 3.326923076923077, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 89, 'Centroid Y': 24, 'Slant Angle': 91.72174835205078}
# Image: 161.jpg
# Features: {'label': '161', 'features': array([0.36265589, 0.01178012, 0.00507304, ..., 0.52617235, 0.29318468,
#        0.269749  ]), 'Length': 151, 'Height': 55, 'Ratio (Length/Height)': 2.7454545454545456, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Poor', 'Centroid X': 75, 'Centroid Y': 26, 'Slant Angle': 178.97386169433594}
# Image: 162.jpg
# Features: {'label': '162', 'features': array([0.30092724, 0.06954254, 0.02199128, ..., 0.65830884, 0.45572453,
#        0.30846348]), 'Length': 163, 'Height': 46, 'Ratio (Length/Height)': 3.5434782608695654, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 81, 'Centroid Y': 22, 'Slant Angle': 177.1260528564453}
# Image: 163.jpg
# Features: {'label': '163', 'features': array([0.33043324, 0.03811871, 0.09643354, ..., 0.47339691, 0.18347831,
#        0.44016074]), 'Length': 144, 'Height': 47, 'Ratio (Length/Height)': 3.0638297872340425, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 71, 'Centroid Y': 23, 'Slant Angle': 0}
# Image: 164.jpg
# Features: {'label': '164', 'features': array([0.25526463, 0.21077037, 0.07225165, ..., 0.2722    , 0.14295072,
#        0.36814408]), 'Length': 131, 'Height': 51, 'Ratio (Length/Height)': 2.5686274509803924, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 65, 'Centroid Y': 25, 'Slant Angle': 0}
# Image: 165.jpg
# Features: {'label': '165', 'features': array([0.38852967, 0.07766954, 0.        , ..., 0.54519281, 0.43966939,
#        0.30532284]), 'Length': 157, 'Height': 60, 'Ratio (Length/Height)': 2.6166666666666667, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 79, 'Centroid Y': 28, 'Slant Angle': 82.8764877319336}
# Image: 166.jpg
# Features: {'label': '166', 'features': array([0.        , 0.        , 0.        , ..., 0.59561268, 0.31867196,
#        0.16179491]), 'Length': 145, 'Height': 59, 'Ratio (Length/Height)': 2.457627118644068, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 72, 'Centroid Y': 29, 'Slant Angle': 0}
# Image: 167.jpg
# Features: {'label': '167', 'features': array([0.35259493, 0.        , 0.06404796, ..., 0.38157296, 0.37292815,
#        0.34825335]), 'Length': 100, 'Height': 36, 'Ratio (Length/Height)': 2.7777777777777777, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 49, 'Centroid Y': 17, 'Slant Angle': 0}
# Image: 168.jpg
# Features: {'label': '168', 'features': array([0.1510509 , 0.04222001, 0.08010683, ..., 0.34041912, 0.39077823,
#        0.36304085]), 'Length': 157, 'Height': 52, 'Ratio (Length/Height)': 3.019230769230769, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 78, 'Centroid Y': 25, 'Slant Angle': 91.49557495117188}
# Image: 169.jpg
# Features: {'label': '169', 'features': array([0.04261882, 0.02555214, 0.03074638, ..., 0.35149351, 0.27467661,
#        0.25321803]), 'Length': 165, 'Height': 56, 'Ratio (Length/Height)': 2.9464285714285716, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 82, 'Centroid Y': 25, 'Slant Angle': 89.52128601074219}
# Image: 170.jpg
# Features: {'label': '170', 'features': array([0.01651022, 0.        , 0.02334897, ..., 0.33951519, 0.14654399,
#        0.33662904]), 'Length': 164, 'Height': 56, 'Ratio (Length/Height)': 2.9285714285714284, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 81, 'Centroid Y': 27, 'Slant Angle': 96.4786148071289}
# Image: 171.jpg
# Features: {'label': '171', 'features': array([0.17379684, 0.10598769, 0.27034253, ..., 0.4911361 , 0.16645113,
#        0.22330483]), 'Length': 101, 'Height': 52, 'Ratio (Length/Height)': 1.9423076923076923, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 50, 'Centroid Y': 25, 'Slant Angle': 90.69964599609375}
# Image: 172.jpg
# Features: {'label': '172', 'features': array([0.08356726, 0.        , 0.11818195, ..., 0.39759987, 0.28022743,
#        0.28039092]), 'Length': 176, 'Height': 53, 'Ratio (Length/Height)': 3.3207547169811322, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 88, 'Centroid Y': 25, 'Slant Angle': 89.62533569335938}
# Image: 173.jpg
# Features: {'label': '173', 'features': array([0.31192866, 0.        , 0.03356346, ..., 0.15007579, 0.12323219,
#        0.14211715]), 'Length': 163, 'Height': 52, 'Ratio (Length/Height)': 3.1346153846153846, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 82, 'Centroid Y': 24, 'Slant Angle': 90.07740020751953}
# Image: 174.jpg
# Features: {'label': '174', 'features': array([0.06552791, 0.0131744 , 0.01484596, ..., 0.25163809, 0.3939317 ,
#        0.21938443]), 'Length': 116, 'Height': 43, 'Ratio (Length/Height)': 2.697674418604651, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 57, 'Centroid Y': 20, 'Slant Angle': 90.8572006225586}
# Image: 175.jpg
# Features: {'label': '175', 'features': array([0.1195759 , 0.00323095, 0.00408687, ..., 0.30165857, 0.41177021,
#        0.22696783]), 'Length': 130, 'Height': 54, 'Ratio (Length/Height)': 2.4074074074074074, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 64, 'Centroid Y': 26, 'Slant Angle': 0}
# Image: 176.jpg
# Features: {'label': '176', 'features': array([0.2245589 , 0.        , 0.2920752 , ..., 0.29036054, 0.17486775,
#        0.18536   ]), 'Length': 108, 'Height': 48, 'Ratio (Length/Height)': 2.25, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 54, 'Centroid Y': 23, 'Slant Angle': 91.31756591796875}
# Image: 177.jpg
# Features: {'label': '177', 'features': array([0.03859304, 0.00766656, 0.00295666, ..., 0.377273  , 0.20287353,
#        0.16315515]), 'Length': 123, 'Height': 51, 'Ratio (Length/Height)': 2.411764705882353, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 66, 'Centroid Y': 21, 'Slant Angle': 90.89444732666016}
# Image: 178.jpg
# Features: {'label': '178', 'features': array([0.04584456, 0.        , 0.        , ..., 0.26896354, 0.40882492,
#        0.36707605]), 'Length': 137, 'Height': 50, 'Ratio (Length/Height)': 2.74, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 68, 'Centroid Y': 24, 'Slant Angle': 0}
# Image: 179.jpg
# Features: {'label': '179', 'features': array([0.35001901, 0.        , 0.19439531, ..., 0.3041213 , 0.26043116,
#        0.34835247]), 'Length': 135, 'Height': 49, 'Ratio (Length/Height)': 2.7551020408163267, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 67, 'Centroid Y': 23, 'Slant Angle': 0.0}
# Image: 180.jpg
# Features: {'label': '180', 'features': array([0.12101227, 0.        , 0.        , ..., 0.57610663, 0.12353415,
#        0.26051394]), 'Length': 201, 'Height': 59, 'Ratio (Length/Height)': 3.406779661016949, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 100, 'Centroid Y': 29, 'Slant Angle': 86.22357177734375}
# Image: 181.jpg
# Features: {'label': '181', 'features': array([0.29015793, 0.        , 0.16343066, ..., 0.294057  , 0.27227731,
#        0.2273658 ]), 'Length': 148, 'Height': 53, 'Ratio (Length/Height)': 2.792452830188679, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 88, 'Centroid Y': 11, 'Slant Angle': 87.61754608154297}
# Image: 182.jpg
# Features: {'label': '182', 'features': array([0.23076287, 0.        , 0.04662114, ..., 0.37706721, 0.30767232,
#        0.2668791 ]), 'Length': 101, 'Height': 51, 'Ratio (Length/Height)': 1.9803921568627452, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 48, 'Centroid Y': 23, 'Slant Angle': 91.36174774169922}
# Image: 183.jpg
# Features: {'label': '183', 'features': array([0.23076287, 0.        , 0.04662114, ..., 0.37706721, 0.30767232,
#        0.2668791 ]), 'Length': 103, 'Height': 52, 'Ratio (Length/Height)': 1.9807692307692308, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 49, 'Centroid Y': 24, 'Slant Angle': 90.98308563232422}
# Image: 184.jpg
# Features: {'label': '184', 'features': array([0.3427059 , 0.29324454, 0.33383543, ..., 0.11552596, 0.19814192,
#        0.19944552]), 'Length': 171, 'Height': 58, 'Ratio (Length/Height)': 2.9482758620689653, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 85, 'Centroid Y': 28, 'Slant Angle': 90.84751892089844}
# Image: 185.jpg
# Features: {'label': '185', 'features': array([0.04584276, 0.02288572, 0.0058398 , ..., 0.26850504, 0.14716186,
#        0.26098978]), 'Length': 141, 'Height': 54, 'Ratio (Length/Height)': 2.611111111111111, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 71, 'Centroid Y': 24, 'Slant Angle': 91.42074584960938}
# Image: 186.jpg
# Features: {'label': '186', 'features': array([2.90301461e-01, 0.00000000e+00, 1.14558574e-01, ...,
#        3.30000000e+02, 2.84010297e-01, 1.71270290e-01]), 'Length': 119, 'Height': 48, 'Ratio (Length/Height)': 2.4791666666666665, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 59, 'Centroid Y': 23, 'Slant Angle': 0}
# Image: 187.jpg
# Features: {'label': '187', 'features': array([0.06466163, 0.        , 0.        , ..., 0.4744013 , 0.20255702,
#        0.47073496]), 'Length': 139, 'Height': 51, 'Ratio (Length/Height)': 2.7254901960784315, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 70, 'Centroid Y': 24, 'Slant Angle': 88.1609878540039}
# Image: 188.jpg
# Features: {'label': '188', 'features': array([0.3096546 , 0.        , 0.09841689, ..., 0.19738182, 0.21964419,
#        0.22929619]), 'Length': 181, 'Height': 53, 'Ratio (Length/Height)': 3.4150943396226414, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 90, 'Centroid Y': 25, 'Slant Angle': 0.0}
# Image: 189.jpg
# Features: {'label': '189', 'features': array([0.27916199, 0.01918609, 0.03640305, ..., 0.1905551 , 0.29619617,
#        0.2194815 ]), 'Length': 143, 'Height': 59, 'Ratio (Length/Height)': 2.4237288135593222, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 70, 'Centroid Y': 27, 'Slant Angle': 94.03063201904297}
# Image: 190.jpg
# Features: {'label': '190', 'features': array([0.12116595, 0.        , 0.        , ..., 0.11835033, 0.19933358,
#        0.21648076]), 'Length': 177, 'Height': 43, 'Ratio (Length/Height)': 4.116279069767442, 'Integer Ratio': 4, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 88, 'Centroid Y': 21, 'Slant Angle': 0}
# Image: 191.jpg
# Features: {'label': '191', 'features': array([0.20633594, 0.02545817, 0.1610116 , ..., 0.4235054 , 0.1513195 ,
#        0.18728212]), 'Length': 173, 'Height': 41, 'Ratio (Length/Height)': 4.219512195121951, 'Integer Ratio': 4, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 94, 'Centroid Y': 18, 'Slant Angle': 90.83541107177734}
# Image: 192.jpg
# Features: {'label': '192', 'features': array([0.10243297, 0.        , 0.        , ..., 0.61418801, 0.2133099 ,
#        0.22656137]), 'Length': 184, 'Height': 49, 'Ratio (Length/Height)': 3.7551020408163267, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 91, 'Centroid Y': 24, 'Slant Angle': 0}
# Image: 193.jpg
# Features: {'label': '193', 'features': array([0.31468349, 0.07456227, 0.1178933 , ..., 0.23269079, 0.18999307,
#        0.20022083]), 'Length': 176, 'Height': 49, 'Ratio (Length/Height)': 3.5918367346938775, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 118, 'Centroid Y': 23, 'Slant Angle': 89.73086547851562}
# Image: 194.jpg
# Features: {'label': '194', 'features': array([0.27120988, 0.        , 0.11314744, ..., 0.29160776, 0.59219332,
#        0.2592705 ]), 'Length': 147, 'Height': 50, 'Ratio (Length/Height)': 2.94, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 75, 'Centroid Y': 23, 'Slant Angle': 90.21102905273438}
# Image: 195.jpg
# Features: {'label': '195', 'features': array([0.35246737, 0.        , 0.        , ..., 0.26429261, 0.43136202,
#        0.28836629]), 'Length': 128, 'Height': 63, 'Ratio (Length/Height)': 2.0317460317460316, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 63, 'Centroid Y': 31, 'Slant Angle': 0}
# Image: 196.jpg
# Features: {'label': '196', 'features': array([0.31127899, 0.        , 0.0652284 , ..., 0.19740631, 0.27036098,
#        0.2629262 ]), 'Length': 169, 'Height': 50, 'Ratio (Length/Height)': 3.38, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 85, 'Centroid Y': 24, 'Slant Angle': 95.977783203125}
# Image: 197.jpg
# Features: {'label': '197', 'features': array([0.07593508, 0.04631147, 0.00398114, ..., 0.33467192, 0.24329763,
#        0.26285117]), 'Length': 112, 'Height': 57, 'Ratio (Length/Height)': 1.9649122807017543, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 58, 'Centroid Y': 25, 'Slant Angle': 90.4747543334961}
# Image: 198.jpg
# Features: {'label': '198', 'features': array([0.02671961, 0.01007406, 0.01285917, ..., 0.2083553 , 0.20448174,
#        0.17342156]), 'Length': 115, 'Height': 44, 'Ratio (Length/Height)': 2.6136363636363638, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 57, 'Centroid Y': 21, 'Slant Angle': 0}
# Image: 199.jpg
# Features: {'label': '199', 'features': array([0.33255718, 0.        , 0.03710135, ..., 0.24352912, 0.27858347,
#        0.19728526]), 'Length': 173, 'Height': 47, 'Ratio (Length/Height)': 3.6808510638297873, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 87, 'Centroid Y': 22, 'Slant Angle': 88.12323760986328}
# Image: 200.jpg
# Features: {'label': '200', 'features': array([0.39769343, 0.26638065, 0.06738957, ..., 0.26076479, 0.19162694,
#        0.26469418]), 'Length': 142, 'Height': 53, 'Ratio (Length/Height)': 2.6792452830188678, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 70, 'Centroid Y': 26, 'Slant Angle': 81.134033203125}
# Image: 201.jpg
# Features: {'label': '201', 'features': array([0.28256285, 0.        , 0.19897339, ..., 0.30104959, 0.26289506,
#        0.21943615]), 'Length': 181, 'Height': 66, 'Ratio (Length/Height)': 2.742424242424242, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 69, 'Centroid Y': 19, 'Slant Angle': 82.48155975341797}
# Image: 202.jpg
# Features: {'label': '202', 'features': array([0.26079089, 0.        , 0.08714138, ..., 0.27123176, 0.30417951,
#        0.18745343]), 'Length': 141, 'Height': 53, 'Ratio (Length/Height)': 2.660377358490566, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 70, 'Centroid Y': 26, 'Slant Angle': 0}
# Image: 203.jpg
# Features: {'label': '203', 'features': array([0.17429073, 0.        , 0.        , ..., 0.31404029, 0.34098894,
#        0.1898479 ]), 'Length': 171, 'Height': 73, 'Ratio (Length/Height)': 2.3424657534246576, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 84, 'Centroid Y': 36, 'Slant Angle': 90.85791778564453}
# Image: 204.jpg
# Features: {'label': '204', 'features': array([0.29237286, 0.07363018, 0.06985172, ..., 0.28787009, 0.19972098,
#        0.28207267]), 'Length': 121, 'Height': 38, 'Ratio (Length/Height)': 3.1842105263157894, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 83, 'Centroid Y': 17, 'Slant Angle': 86.50597381591797}
# Image: 205.jpg
# Features: {'label': '205', 'features': array([0.229119  , 0.        , 0.        , ..., 0.18980383, 0.29581817,
#        0.24566829]), 'Length': 159, 'Height': 63, 'Ratio (Length/Height)': 2.5238095238095237, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 56, 'Centroid Y': 17, 'Slant Angle': 0.0}
# Image: 206.jpg
# Features: {'label': '206', 'features': array([0.10120194, 0.03232777, 0.04089176, ..., 0.24938727, 0.38729376,
#        0.20481322]), 'Length': 136, 'Height': 53, 'Ratio (Length/Height)': 2.5660377358490565, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 67, 'Centroid Y': 25, 'Slant Angle': 91.22093963623047}
# Image: 207.jpg
# Features: {'label': '207', 'features': array([0.08788008, 0.        , 0.20713531, ..., 0.18868474, 0.18671362,
#        0.30261487]), 'Length': 152, 'Height': 46, 'Ratio (Length/Height)': 3.3043478260869565, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 98, 'Centroid Y': 21, 'Slant Angle': 88.25720977783203}
# Image: 208.jpg
# Features: {'label': '208', 'features': array([0.32724732, 0.06192967, 0.04497817, ..., 0.37957737, 0.24674996,
#        0.52886408]), 'Length': 215, 'Height': 77, 'Ratio (Length/Height)': 2.792207792207792, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 110, 'Centroid Y': 36, 'Slant Angle': 0.0}
# Image: 209.jpg
# Features: {'label': '209', 'features': array([0.09968239, 0.02786208, 0.15859372, ..., 0.29827649, 0.36171466,
#        0.32434514]), 'Length': 163, 'Height': 73, 'Ratio (Length/Height)': 2.232876712328767, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 88, 'Centroid Y': 40, 'Slant Angle': 73.18025970458984}
# Image: 210.jpg
# Features: {'label': '210', 'features': array([0.30098192, 0.        , 0.11359448, ..., 0.20785293, 0.0894347 ,
#        0.25617067]), 'Length': 195, 'Height': 66, 'Ratio (Length/Height)': 2.9545454545454546, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 131, 'Centroid Y': 47, 'Slant Angle': 85.01449584960938}
# Image: 211.jpg
# Features: {'label': '211', 'features': array([0.20076475, 0.07347428, 0.02185727, ..., 0.21734944, 0.2267853 ,
#        0.21608389]), 'Length': 81, 'Height': 40, 'Ratio (Length/Height)': 2.025, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 40, 'Centroid Y': 19, 'Slant Angle': 0}
# Image: 212.jpg
# Features: {'label': '212', 'features': array([0.32164591, 0.08082508, 0.20447307, ..., 0.30969144, 0.30786771,
#        0.30088002]), 'Length': 207, 'Height': 67, 'Ratio (Length/Height)': 3.08955223880597, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 103, 'Centroid Y': 32, 'Slant Angle': 92.05183410644531}
# Number of images processed: 88

# %%
import os
import cv2
import numpy as np
import pandas as pd
from skimage.feature import hog

def extract_stroke_features(image):
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    return features

def extract_shape_features(image):
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    shape_features = []
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        area = cv2.contourArea(contour)
        perimeter = cv2.arcLength(contour, True)
        shape_features = [aspect_ratio, area, perimeter]
    return shape_features

def calculate_slant_angle(image):
    # Convert image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Threshold the image to obtain a binary image
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    
    # Find contours in the binary image
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Find the largest contour (signature)
    largest_contour = max(contours, key=cv2.contourArea)
    
    # Check if the contour contains at least 5 points
    if len(largest_contour) < 5:
        # If the contour has too few points, return a default angle (0 degrees)
        return 0
    
    # Perform principal component analysis (PCA) on the largest contour
    _, _, angle = cv2.fitEllipse(largest_contour)
    
    # The angle returned by fitEllipse is the angle of rotation of the fitted ellipse
    # We use this as an estimate of the slant angle of the signature
    return angle


def extract_angle_features(image):
    # Calculate angle features (e.g., angles between strokes)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    lines = cv2.HoughLinesP(edges, 1, np.pi/180, threshold=100, minLineLength=100, maxLineGap=10)
    angle_features = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            angle = np.arctan2(y2 - y1, x2 - x1) * 180 / np.pi
            angle_features.append(angle)
    return angle_features

def extract_curvature_features(image):
    # Calculate curvature features
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    curvature_features = []
    if contours:
        for contour in contours:
            M = cv2.moments(contour)
            if M["m00"] != 0:
                cx = int(M["m10"] / M["m00"])
                cy = int(M["m01"] / M["m00"])
                cX, cY = cx, cy
                points = contour[:, 0]
                prev_point = points[0]
                total_distance = 0
                total_curvature = 0
                num_points = 0
                for point in points[1:]:
                    distance = np.linalg.norm(point - prev_point)
                    total_distance += distance
                    angle = np.arctan2(point[1] - prev_point[1], point[0] - prev_point[0])
                    curvature = np.abs(angle - prev_angle) / distance if num_points > 0 else 0
                    total_curvature += curvature
                    prev_point = point
                    prev_angle = angle
                    num_points += 1
                if num_points > 0:
                    mean_curvature = total_curvature / total_distance
                    curvature_features.append(mean_curvature)
    return curvature_features

def classify_sign(image):
    # Replace this with your own sign classification method
    # Example: Determine if the sign is angular, circular, or something else
    # You may use machine learning models, rules-based systems, etc.
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    
    # Simple rule-based classification
    if len(features) < 1000:
        return "Circular"
    else:
        return "Angular"

def assess_skill(image):
    # Replace this with your own method for assessing the overall skill of the signature
    # Example: Use machine learning models or rules-based systems to evaluate the signature's quality
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    
    # Simple rule-based assessment
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        if aspect_ratio > 0.5:
            return "Good"
        else:
            return "Poor"
    else:
        return "Poor"


def extract_additional_features(image):
    # Calculate length, height, ratio, integer ratio
    height, length, _ = image.shape
    ratio = length / height
    integer_ratio = int(ratio)
    
    # Classify the sign
    sign_classification = classify_sign(image)
    
    # Assess overall skill
    overall_skill = assess_skill(image)
    
    # Calculate centroid coordinates
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        contour = max(contours, key=cv2.contourArea)
        M = cv2.moments(contour)
        if M["m00"] != 0:
            centroid_x = int(M["m10"] / M["m00"])
            centroid_y = int(M["m01"] / M["m00"])
        else:
            centroid_x, centroid_y = -1, -1
    else:
        centroid_x, centroid_y = -1, -1
    
    # Calculate slant angle
    slant_angle = calculate_slant_angle(image)
    
    return {
        'Length': length,
        'Height': height,
        'Ratio (Length/Height)': ratio,
        'Integer Ratio': integer_ratio,
        'Sign Classification': sign_classification,
        'Overall Skill': overall_skill,
        'Centroid X': centroid_x,
        'Centroid Y': centroid_y,
        'Slant Angle': slant_angle
    }

def extract_features_from_images(sample_images_folder):
    features_list = []
    for filename in os.listdir(sample_images_folder):
        image_path = os.path.join(sample_images_folder, filename)
        
        # Extract label from filename
        label = os.path.splitext(filename)[0]
        
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue  # Skip this image if loading fails
        
        # Extract additional features
        additional_features = extract_additional_features(image)
        
        # Extract stroke features
        stroke_features = extract_stroke_features(image)
        
        # Extract shape features
        shape_features = extract_shape_features(image)
        
        # Extract angle features
        angle_features = extract_angle_features(image)
        
        # Extract curvature features
        curvature_features = extract_curvature_features(image)
        
        # Combine all features into a single feature vector
        all_features = np.concatenate((stroke_features, shape_features, angle_features, curvature_features))
        
        # Add features, label, and additional features to the list
        features_dict = {
            "label": label,
            "features": all_features,
            **additional_features
        }
        features_list.append(features_dict)
        
        # Print feature values
        print(f"Image: {filename}")
        print(f"Features: {features_dict}")
    
    print(f"Number of images processed: {len(features_list)}")
    return features_list

# Example usage:
sample_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain"

features = extract_features_from_images(sample_images_folder)

# Convert features to DataFrame
df = pd.DataFrame(features)

# Save DataFrame to Excel file
excel_filename = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\dataset.xlsx"
df.to_excel(excel_filename, index=False)

print(f"Features saved to {excel_filename}")
# Out:
# Image: 122.jpg
# Features: {'label': '122', 'features': array([0.24647277, 0.        , 0.19918008, ..., 0.29002036, 0.2652823 ,
#        0.21901885]), 'Length': 169, 'Height': 56, 'Ratio (Length/Height)': 3.017857142857143, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 85, 'Centroid Y': 27, 'Slant Angle': 91.28682708740234}
# Image: 123.jpg
# Features: {'label': '123', 'features': array([0.34430633, 0.        , 0.        , ..., 0.16004909, 0.25191525,
#        0.34934821]), 'Length': 134, 'Height': 64, 'Ratio (Length/Height)': 2.09375, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 92, 'Centroid Y': 19, 'Slant Angle': 75.56608581542969}
# Image: 124.jpg
# Features: {'label': '124', 'features': array([0.42678198, 0.08928572, 0.42678198, ..., 0.35211241, 0.34662251,
#        0.20105621]), 'Length': 137, 'Height': 81, 'Ratio (Length/Height)': 1.691358024691358, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 68, 'Centroid Y': 40, 'Slant Angle': 0}
# Image: 125.jpg
# Features: {'label': '125', 'features': array([0.39019667, 0.06032594, 0.11446043, ..., 0.31210049, 0.18700663,
#        0.24071141]), 'Length': 179, 'Height': 74, 'Ratio (Length/Height)': 2.418918918918919, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 89, 'Centroid Y': 34, 'Slant Angle': 91.18515014648438}
# Image: 126.jpg
# Features: {'label': '126', 'features': array([0.35098322, 0.16516471, 0.        , ..., 0.23142328, 0.12456478,
#        0.15976461]), 'Length': 115, 'Height': 58, 'Ratio (Length/Height)': 1.9827586206896552, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 51, 'Centroid Y': 21, 'Slant Angle': 79.34481811523438}
# Image: 127.jpg
# Features: {'label': '127', 'features': array([0.28099869, 0.16605824, 0.21004888, ..., 0.25337799, 0.28536602,
#        0.22304865]), 'Length': 190, 'Height': 47, 'Ratio (Length/Height)': 4.042553191489362, 'Integer Ratio': 4, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 94, 'Centroid Y': 23, 'Slant Angle': 0}
# Image: 128.jpg
# Features: {'label': '128', 'features': array([0.35036702, 0.08438293, 0.        , ..., 0.52761407, 0.21120534,
#        0.22119301]), 'Length': 168, 'Height': 61, 'Ratio (Length/Height)': 2.7540983606557377, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 83, 'Centroid Y': 30, 'Slant Angle': 0}
# Image: 129.jpg
# Features: {'label': '129', 'features': array([0.08344126, 0.00400282, 0.00772015, ..., 0.20596451, 0.29169638,
#        0.21372119]), 'Length': 141, 'Height': 60, 'Ratio (Length/Height)': 2.35, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 61, 'Centroid Y': 18, 'Slant Angle': 79.2044677734375}
# Image: 130.jpg
# Features: {'label': '130', 'features': array([ 0.35541226,  0.        ,  0.26280156, ..., -7.65065096,
#         0.28453463,  0.22889119]), 'Length': 137, 'Height': 56, 'Ratio (Length/Height)': 2.4464285714285716, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 68, 'Centroid Y': 27, 'Slant Angle': 0}
# Image: 131.jpg
# Features: {'label': '131', 'features': array([0.        , 0.        , 0.        , ..., 0.12271807, 0.07648947,
#        0.33305375]), 'Length': 120, 'Height': 52, 'Ratio (Length/Height)': 2.3076923076923075, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 77, 'Centroid Y': 16, 'Slant Angle': 90.23107147216797}
# Image: 133.jpg
# Features: {'label': '133', 'features': array([0.14200465, 0.        , 0.        , ..., 0.2740635 , 0.47639176,
#        0.23067935]), 'Length': 122, 'Height': 67, 'Ratio (Length/Height)': 1.8208955223880596, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 58, 'Centroid Y': 24, 'Slant Angle': 80.00345611572266}
# Image: 134.jpg
# Features: {'label': '134', 'features': array([0.04449652, 0.00877733, 0.00361062, ..., 0.3648625 , 0.30342314,
#        0.19161826]), 'Length': 107, 'Height': 47, 'Ratio (Length/Height)': 2.276595744680851, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 54, 'Centroid Y': 20, 'Slant Angle': 98.31202697753906}
# Image: 135.jpg
# Features: {'label': '135', 'features': array([0.06555467, 0.        , 0.        , ..., 0.51944047, 0.8535071 ,
#        0.26667216]), 'Length': 135, 'Height': 55, 'Ratio (Length/Height)': 2.4545454545454546, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 87, 'Centroid Y': 20, 'Slant Angle': 84.49777221679688}
# Image: 136.jpg
# Features: {'label': '136', 'features': array([0.39444092, 0.        , 0.        , ..., 0.23399235, 0.26647625,
#        0.21733188]), 'Length': 172, 'Height': 62, 'Ratio (Length/Height)': 2.774193548387097, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 86, 'Centroid Y': 29, 'Slant Angle': 88.65807342529297}
# Image: 137.jpg
# Features: {'label': '137', 'features': array([0.11725957, 0.00905112, 0.00632133, ..., 0.41452592, 0.2491283 ,
#        0.16763088]), 'Length': 138, 'Height': 66, 'Ratio (Length/Height)': 2.090909090909091, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 62, 'Centroid Y': 22, 'Slant Angle': 76.85358428955078}
# Image: 138.jpg
# Features: {'label': '138', 'features': array([0.22815833, 0.        , 0.        , ..., 0.32494453, 0.29894766,
#        0.24200996]), 'Length': 143, 'Height': 65, 'Ratio (Length/Height)': 2.2, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 70, 'Centroid Y': 29, 'Slant Angle': 90.78755950927734}
# Image: 139.jpg
# Features: {'label': '139', 'features': array([0.37419258, 0.0598942 , 0.37419258, ..., 0.27165739, 0.28035327,
#        0.31829527]), 'Length': 173, 'Height': 61, 'Ratio (Length/Height)': 2.8360655737704916, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 85, 'Centroid Y': 29, 'Slant Angle': 89.4727554321289}
# Image: 140.jpg
# Features: {'label': '140', 'features': array([0.21378335, 0.05106995, 0.01614973, ..., 0.24590076, 0.22610013,
#        0.43849987]), 'Length': 151, 'Height': 46, 'Ratio (Length/Height)': 3.282608695652174, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 75, 'Centroid Y': 21, 'Slant Angle': 90.56396484375}
# Image: 141.jpg
# Features: {'label': '141', 'features': array([0.12484837, 0.        , 0.        , ..., 0.52359878, 0.48679369,
#        0.20545855]), 'Length': 159, 'Height': 57, 'Ratio (Length/Height)': 2.789473684210526, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 79, 'Centroid Y': 25, 'Slant Angle': 83.55333709716797}
# Image: 142.jpg
# Features: {'label': '142', 'features': array([  0.33866082,   0.15205018,   0.09616497, ..., -10.09105724,
#          0.35591617,   0.25002388]), 'Length': 172, 'Height': 61, 'Ratio (Length/Height)': 2.819672131147541, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 87, 'Centroid Y': 28, 'Slant Angle': 90.07624816894531}
# Image: 143.jpg
# Features: {'label': '143', 'features': array([0.36191671, 0.        , 0.07050067, ..., 0.15052439, 0.59311144,
#        0.29042641]), 'Length': 116, 'Height': 60, 'Ratio (Length/Height)': 1.9333333333333333, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 51, 'Centroid Y': 22, 'Slant Angle': 86.89753723144531}
# Image: 144.jpg
# Features: {'label': '144', 'features': array([0.        , 0.        , 0.        , ..., 0.3837607 , 0.28293356,
#        0.37823406]), 'Length': 165, 'Height': 50, 'Ratio (Length/Height)': 3.3, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 75, 'Centroid Y': 20, 'Slant Angle': 90.5782470703125}
# Image: 145.jpg
# Features: {'label': '145', 'features': array([0.09620211, 0.02359984, 0.00516744, ..., 0.2952528 , 0.2000302 ,
#        0.29978013]), 'Length': 118, 'Height': 66, 'Ratio (Length/Height)': 1.7878787878787878, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 56, 'Centroid Y': 22, 'Slant Angle': 77.58428955078125}
# Image: 146.jpg
# Features: {'label': '146', 'features': array([0.        , 0.        , 0.10641911, ..., 1.11778657, 0.25727256,
#        0.28175545]), 'Length': 131, 'Height': 67, 'Ratio (Length/Height)': 1.955223880597015, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 63, 'Centroid Y': 31, 'Slant Angle': 89.26143646240234}
# Image: 147.jpg
# Features: {'label': '147', 'features': array([0.1774753 , 0.        , 0.10457833, ..., 0.37705567, 0.19512124,
#        0.29673388]), 'Length': 120, 'Height': 60, 'Ratio (Length/Height)': 2.0, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 60, 'Centroid Y': 27, 'Slant Angle': 95.03276824951172}
# Image: 148.jpg
# Features: {'label': '148', 'features': array([0.30775772, 0.        , 0.        , ..., 0.28248378, 0.29637185,
#        0.2440208 ]), 'Length': 176, 'Height': 53, 'Ratio (Length/Height)': 3.3207547169811322, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 82, 'Centroid Y': 21, 'Slant Angle': 99.52277374267578}
# Image: 149.jpg
# Features: {'label': '149', 'features': array([0.04001669, 0.00854778, 0.00708232, ..., 0.273666  , 0.27388962,
#        0.29323191]), 'Length': 130, 'Height': 63, 'Ratio (Length/Height)': 2.0634920634920637, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 64, 'Centroid Y': 29, 'Slant Angle': 85.67007446289062}
# Image: 150.jpg
# Features: {'label': '150', 'features': array([0.15174944, 0.        , 0.        , ..., 0.15843607, 0.33011643,
#        0.26897182]), 'Length': 165, 'Height': 63, 'Ratio (Length/Height)': 2.619047619047619, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 73, 'Centroid Y': 19, 'Slant Angle': 83.88218688964844}
# Image: 151.jpg
# Features: {'label': '151', 'features': array([5.05076272e-01, 0.00000000e+00, 0.00000000e+00, ...,
#        9.29462984e+02, 2.49104626e-01, 2.47056452e-01]), 'Length': 183, 'Height': 65, 'Ratio (Length/Height)': 2.8153846153846156, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 92, 'Centroid Y': 31, 'Slant Angle': 0.0}
# Image: 154.jpg
# Features: {'label': '154', 'features': array([0.0803642 , 0.        , 0.01894202, ..., 0.30633445, 0.23531108,
#        0.21243228]), 'Length': 162, 'Height': 48, 'Ratio (Length/Height)': 3.375, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 111, 'Centroid Y': 31, 'Slant Angle': 91.95911407470703}
# Image: 155.jpg
# Features: {'label': '155', 'features': array([0.2754416 , 0.        , 0.21640736, ..., 0.        , 0.34627197,
#        0.32658894]), 'Length': 166, 'Height': 63, 'Ratio (Length/Height)': 2.634920634920635, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 83, 'Centroid Y': 30, 'Slant Angle': 87.71559143066406}
# Image: 156.jpg
# Features: {'label': '156', 'features': array([0.30718334, 0.        , 0.37151612, ..., 0.2328727 , 0.18230895,
#        0.27975147]), 'Length': 279, 'Height': 41, 'Ratio (Length/Height)': 6.804878048780488, 'Integer Ratio': 6, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 147, 'Centroid Y': 18, 'Slant Angle': 91.01760864257812}
# Image: 157.jpg
# Features: {'label': '157', 'features': array([0.06346369, 0.        , 0.02761575, ..., 0.25833309, 0.26856109,
#        0.30176102]), 'Length': 223, 'Height': 69, 'Ratio (Length/Height)': 3.2318840579710146, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 70, 'Centroid Y': 22, 'Slant Angle': 89.31143188476562}
# Image: 158.jpg
# Features: {'label': '158', 'features': array([0.06208349, 0.        , 0.04389966, ..., 0.31279801, 0.29730411,
#        0.29008128]), 'Length': 229, 'Height': 89, 'Ratio (Length/Height)': 2.5730337078651684, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 88, 'Centroid Y': 23, 'Slant Angle': 101.22886657714844}
# Image: 159.jpg
# Features: {'label': '159', 'features': array([0.        , 0.        , 0.        , ..., 0.18181707, 0.15671246,
#        0.25219139]), 'Length': 265, 'Height': 75, 'Ratio (Length/Height)': 3.533333333333333, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 138, 'Centroid Y': 35, 'Slant Angle': 89.0843505859375}
# Image: 160.jpg
# Features: {'label': '160', 'features': array([0.08911322, 0.02094611, 0.01487033, ..., 0.31362083, 0.44683688,
#        0.28799893]), 'Length': 173, 'Height': 52, 'Ratio (Length/Height)': 3.326923076923077, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 89, 'Centroid Y': 24, 'Slant Angle': 91.72174835205078}
# Image: 161.jpg
# Features: {'label': '161', 'features': array([0.36265589, 0.01178012, 0.00507304, ..., 0.52617235, 0.29318468,
#        0.269749  ]), 'Length': 151, 'Height': 55, 'Ratio (Length/Height)': 2.7454545454545456, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Poor', 'Centroid X': 75, 'Centroid Y': 26, 'Slant Angle': 178.97386169433594}
# Image: 162.jpg
# Features: {'label': '162', 'features': array([0.30092724, 0.06954254, 0.02199128, ..., 0.65830884, 0.45572453,
#        0.30846348]), 'Length': 163, 'Height': 46, 'Ratio (Length/Height)': 3.5434782608695654, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 81, 'Centroid Y': 22, 'Slant Angle': 177.1260528564453}
# Image: 163.jpg
# Features: {'label': '163', 'features': array([0.33043324, 0.03811871, 0.09643354, ..., 0.47339691, 0.18347831,
#        0.44016074]), 'Length': 144, 'Height': 47, 'Ratio (Length/Height)': 3.0638297872340425, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 71, 'Centroid Y': 23, 'Slant Angle': 0}
# Image: 164.jpg
# Features: {'label': '164', 'features': array([0.25526463, 0.21077037, 0.07225165, ..., 0.2722    , 0.14295072,
#        0.36814408]), 'Length': 131, 'Height': 51, 'Ratio (Length/Height)': 2.5686274509803924, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 65, 'Centroid Y': 25, 'Slant Angle': 0}
# Image: 165.jpg
# Features: {'label': '165', 'features': array([0.38852967, 0.07766954, 0.        , ..., 0.54519281, 0.43966939,
#        0.30532284]), 'Length': 157, 'Height': 60, 'Ratio (Length/Height)': 2.6166666666666667, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 79, 'Centroid Y': 28, 'Slant Angle': 82.8764877319336}
# Image: 166.jpg
# Features: {'label': '166', 'features': array([0.        , 0.        , 0.        , ..., 0.59561268, 0.31867196,
#        0.16179491]), 'Length': 145, 'Height': 59, 'Ratio (Length/Height)': 2.457627118644068, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 72, 'Centroid Y': 29, 'Slant Angle': 0}
# Image: 167.jpg
# Features: {'label': '167', 'features': array([0.35259493, 0.        , 0.06404796, ..., 0.38157296, 0.37292815,
#        0.34825335]), 'Length': 100, 'Height': 36, 'Ratio (Length/Height)': 2.7777777777777777, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 49, 'Centroid Y': 17, 'Slant Angle': 0}
# Image: 168.jpg
# Features: {'label': '168', 'features': array([0.1510509 , 0.04222001, 0.08010683, ..., 0.34041912, 0.39077823,
#        0.36304085]), 'Length': 157, 'Height': 52, 'Ratio (Length/Height)': 3.019230769230769, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 78, 'Centroid Y': 25, 'Slant Angle': 91.49557495117188}
# Image: 169.jpg
# Features: {'label': '169', 'features': array([0.04261882, 0.02555214, 0.03074638, ..., 0.35149351, 0.27467661,
#        0.25321803]), 'Length': 165, 'Height': 56, 'Ratio (Length/Height)': 2.9464285714285716, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 82, 'Centroid Y': 25, 'Slant Angle': 89.52128601074219}
# Image: 170.jpg
# Features: {'label': '170', 'features': array([0.01651022, 0.        , 0.02334897, ..., 0.33951519, 0.14654399,
#        0.33662904]), 'Length': 164, 'Height': 56, 'Ratio (Length/Height)': 2.9285714285714284, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 81, 'Centroid Y': 27, 'Slant Angle': 96.4786148071289}
# Image: 171.jpg
# Features: {'label': '171', 'features': array([0.17379684, 0.10598769, 0.27034253, ..., 0.4911361 , 0.16645113,
#        0.22330483]), 'Length': 101, 'Height': 52, 'Ratio (Length/Height)': 1.9423076923076923, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 50, 'Centroid Y': 25, 'Slant Angle': 90.69964599609375}
# Image: 172.jpg
# Features: {'label': '172', 'features': array([0.08356726, 0.        , 0.11818195, ..., 0.39759987, 0.28022743,
#        0.28039092]), 'Length': 176, 'Height': 53, 'Ratio (Length/Height)': 3.3207547169811322, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 88, 'Centroid Y': 25, 'Slant Angle': 89.62533569335938}
# Image: 173.jpg
# Features: {'label': '173', 'features': array([0.31192866, 0.        , 0.03356346, ..., 0.15007579, 0.12323219,
#        0.14211715]), 'Length': 163, 'Height': 52, 'Ratio (Length/Height)': 3.1346153846153846, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 82, 'Centroid Y': 24, 'Slant Angle': 90.07740020751953}
# Image: 174.jpg
# Features: {'label': '174', 'features': array([0.06552791, 0.0131744 , 0.01484596, ..., 0.25163809, 0.3939317 ,
#        0.21938443]), 'Length': 116, 'Height': 43, 'Ratio (Length/Height)': 2.697674418604651, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 57, 'Centroid Y': 20, 'Slant Angle': 90.8572006225586}
# Image: 175.jpg
# Features: {'label': '175', 'features': array([0.1195759 , 0.00323095, 0.00408687, ..., 0.30165857, 0.41177021,
#        0.22696783]), 'Length': 130, 'Height': 54, 'Ratio (Length/Height)': 2.4074074074074074, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 64, 'Centroid Y': 26, 'Slant Angle': 0}
# Image: 176.jpg
# Features: {'label': '176', 'features': array([0.2245589 , 0.        , 0.2920752 , ..., 0.29036054, 0.17486775,
#        0.18536   ]), 'Length': 108, 'Height': 48, 'Ratio (Length/Height)': 2.25, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 54, 'Centroid Y': 23, 'Slant Angle': 91.31756591796875}
# Image: 177.jpg
# Features: {'label': '177', 'features': array([0.03859304, 0.00766656, 0.00295666, ..., 0.377273  , 0.20287353,
#        0.16315515]), 'Length': 123, 'Height': 51, 'Ratio (Length/Height)': 2.411764705882353, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 66, 'Centroid Y': 21, 'Slant Angle': 90.89444732666016}
# Image: 178.jpg
# Features: {'label': '178', 'features': array([0.04584456, 0.        , 0.        , ..., 0.26896354, 0.40882492,
#        0.36707605]), 'Length': 137, 'Height': 50, 'Ratio (Length/Height)': 2.74, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 68, 'Centroid Y': 24, 'Slant Angle': 0}
# Image: 179.jpg
# Features: {'label': '179', 'features': array([0.35001901, 0.        , 0.19439531, ..., 0.3041213 , 0.26043116,
#        0.34835247]), 'Length': 135, 'Height': 49, 'Ratio (Length/Height)': 2.7551020408163267, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 67, 'Centroid Y': 23, 'Slant Angle': 0.0}
# Image: 180.jpg
# Features: {'label': '180', 'features': array([0.12101227, 0.        , 0.        , ..., 0.57610663, 0.12353415,
#        0.26051394]), 'Length': 201, 'Height': 59, 'Ratio (Length/Height)': 3.406779661016949, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 100, 'Centroid Y': 29, 'Slant Angle': 86.22357177734375}
# Image: 181.jpg
# Features: {'label': '181', 'features': array([0.29015793, 0.        , 0.16343066, ..., 0.294057  , 0.27227731,
#        0.2273658 ]), 'Length': 148, 'Height': 53, 'Ratio (Length/Height)': 2.792452830188679, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 88, 'Centroid Y': 11, 'Slant Angle': 87.61754608154297}
# Image: 182.jpg
# Features: {'label': '182', 'features': array([0.23076287, 0.        , 0.04662114, ..., 0.37706721, 0.30767232,
#        0.2668791 ]), 'Length': 101, 'Height': 51, 'Ratio (Length/Height)': 1.9803921568627452, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 48, 'Centroid Y': 23, 'Slant Angle': 91.36174774169922}
# Image: 183.jpg
# Features: {'label': '183', 'features': array([0.23076287, 0.        , 0.04662114, ..., 0.37706721, 0.30767232,
#        0.2668791 ]), 'Length': 103, 'Height': 52, 'Ratio (Length/Height)': 1.9807692307692308, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 49, 'Centroid Y': 24, 'Slant Angle': 90.98308563232422}
# Image: 184.jpg
# Features: {'label': '184', 'features': array([0.3427059 , 0.29324454, 0.33383543, ..., 0.11552596, 0.19814192,
#        0.19944552]), 'Length': 171, 'Height': 58, 'Ratio (Length/Height)': 2.9482758620689653, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 85, 'Centroid Y': 28, 'Slant Angle': 90.84751892089844}
# Image: 185.jpg
# Features: {'label': '185', 'features': array([0.04584276, 0.02288572, 0.0058398 , ..., 0.26850504, 0.14716186,
#        0.26098978]), 'Length': 141, 'Height': 54, 'Ratio (Length/Height)': 2.611111111111111, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 71, 'Centroid Y': 24, 'Slant Angle': 91.42074584960938}
# Image: 186.jpg
# Features: {'label': '186', 'features': array([2.90301461e-01, 0.00000000e+00, 1.14558574e-01, ...,
#        3.30000000e+02, 2.84010297e-01, 1.71270290e-01]), 'Length': 119, 'Height': 48, 'Ratio (Length/Height)': 2.4791666666666665, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 59, 'Centroid Y': 23, 'Slant Angle': 0}
# Image: 187.jpg
# Features: {'label': '187', 'features': array([0.06466163, 0.        , 0.        , ..., 0.4744013 , 0.20255702,
#        0.47073496]), 'Length': 139, 'Height': 51, 'Ratio (Length/Height)': 2.7254901960784315, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 70, 'Centroid Y': 24, 'Slant Angle': 88.1609878540039}
# Image: 188.jpg
# Features: {'label': '188', 'features': array([0.3096546 , 0.        , 0.09841689, ..., 0.19738182, 0.21964419,
#        0.22929619]), 'Length': 181, 'Height': 53, 'Ratio (Length/Height)': 3.4150943396226414, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 90, 'Centroid Y': 25, 'Slant Angle': 0.0}
# Image: 189.jpg
# Features: {'label': '189', 'features': array([0.27916199, 0.01918609, 0.03640305, ..., 0.1905551 , 0.29619617,
#        0.2194815 ]), 'Length': 143, 'Height': 59, 'Ratio (Length/Height)': 2.4237288135593222, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 70, 'Centroid Y': 27, 'Slant Angle': 94.03063201904297}
# Image: 190.jpg
# Features: {'label': '190', 'features': array([0.12116595, 0.        , 0.        , ..., 0.11835033, 0.19933358,
#        0.21648076]), 'Length': 177, 'Height': 43, 'Ratio (Length/Height)': 4.116279069767442, 'Integer Ratio': 4, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 88, 'Centroid Y': 21, 'Slant Angle': 0}
# Image: 191.jpg
# Features: {'label': '191', 'features': array([0.20633594, 0.02545817, 0.1610116 , ..., 0.4235054 , 0.1513195 ,
#        0.18728212]), 'Length': 173, 'Height': 41, 'Ratio (Length/Height)': 4.219512195121951, 'Integer Ratio': 4, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 94, 'Centroid Y': 18, 'Slant Angle': 90.83541107177734}
# Image: 192.jpg
# Features: {'label': '192', 'features': array([0.10243297, 0.        , 0.        , ..., 0.61418801, 0.2133099 ,
#        0.22656137]), 'Length': 184, 'Height': 49, 'Ratio (Length/Height)': 3.7551020408163267, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 91, 'Centroid Y': 24, 'Slant Angle': 0}
# Image: 193.jpg
# Features: {'label': '193', 'features': array([0.31468349, 0.07456227, 0.1178933 , ..., 0.23269079, 0.18999307,
#        0.20022083]), 'Length': 176, 'Height': 49, 'Ratio (Length/Height)': 3.5918367346938775, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 118, 'Centroid Y': 23, 'Slant Angle': 89.73086547851562}
# Image: 194.jpg
# Features: {'label': '194', 'features': array([0.27120988, 0.        , 0.11314744, ..., 0.29160776, 0.59219332,
#        0.2592705 ]), 'Length': 147, 'Height': 50, 'Ratio (Length/Height)': 2.94, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 75, 'Centroid Y': 23, 'Slant Angle': 90.21102905273438}
# Image: 195.jpg
# Features: {'label': '195', 'features': array([0.35246737, 0.        , 0.        , ..., 0.26429261, 0.43136202,
#        0.28836629]), 'Length': 128, 'Height': 63, 'Ratio (Length/Height)': 2.0317460317460316, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 63, 'Centroid Y': 31, 'Slant Angle': 0}
# Image: 196.jpg
# Features: {'label': '196', 'features': array([0.31127899, 0.        , 0.0652284 , ..., 0.19740631, 0.27036098,
#        0.2629262 ]), 'Length': 169, 'Height': 50, 'Ratio (Length/Height)': 3.38, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 85, 'Centroid Y': 24, 'Slant Angle': 95.977783203125}
# Image: 197.jpg
# Features: {'label': '197', 'features': array([0.07593508, 0.04631147, 0.00398114, ..., 0.33467192, 0.24329763,
#        0.26285117]), 'Length': 112, 'Height': 57, 'Ratio (Length/Height)': 1.9649122807017543, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 58, 'Centroid Y': 25, 'Slant Angle': 90.4747543334961}
# Image: 198.jpg
# Features: {'label': '198', 'features': array([0.02671961, 0.01007406, 0.01285917, ..., 0.2083553 , 0.20448174,
#        0.17342156]), 'Length': 115, 'Height': 44, 'Ratio (Length/Height)': 2.6136363636363638, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 57, 'Centroid Y': 21, 'Slant Angle': 0}
# Image: 199.jpg
# Features: {'label': '199', 'features': array([0.33255718, 0.        , 0.03710135, ..., 0.24352912, 0.27858347,
#        0.19728526]), 'Length': 173, 'Height': 47, 'Ratio (Length/Height)': 3.6808510638297873, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 87, 'Centroid Y': 22, 'Slant Angle': 88.12323760986328}
# Image: 200.jpg
# Features: {'label': '200', 'features': array([0.39769343, 0.26638065, 0.06738957, ..., 0.26076479, 0.19162694,
#        0.26469418]), 'Length': 142, 'Height': 53, 'Ratio (Length/Height)': 2.6792452830188678, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 70, 'Centroid Y': 26, 'Slant Angle': 81.134033203125}
# Image: 201.jpg
# Features: {'label': '201', 'features': array([0.28256285, 0.        , 0.19897339, ..., 0.30104959, 0.26289506,
#        0.21943615]), 'Length': 181, 'Height': 66, 'Ratio (Length/Height)': 2.742424242424242, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 69, 'Centroid Y': 19, 'Slant Angle': 82.48155975341797}
# Image: 202.jpg
# Features: {'label': '202', 'features': array([0.26079089, 0.        , 0.08714138, ..., 0.27123176, 0.30417951,
#        0.18745343]), 'Length': 141, 'Height': 53, 'Ratio (Length/Height)': 2.660377358490566, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 70, 'Centroid Y': 26, 'Slant Angle': 0}
# Image: 203.jpg
# Features: {'label': '203', 'features': array([0.17429073, 0.        , 0.        , ..., 0.31404029, 0.34098894,
#        0.1898479 ]), 'Length': 171, 'Height': 73, 'Ratio (Length/Height)': 2.3424657534246576, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 84, 'Centroid Y': 36, 'Slant Angle': 90.85791778564453}
# Image: 204.jpg
# Features: {'label': '204', 'features': array([0.29237286, 0.07363018, 0.06985172, ..., 0.28787009, 0.19972098,
#        0.28207267]), 'Length': 121, 'Height': 38, 'Ratio (Length/Height)': 3.1842105263157894, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 83, 'Centroid Y': 17, 'Slant Angle': 86.50597381591797}
# Image: 205.jpg
# Features: {'label': '205', 'features': array([0.229119  , 0.        , 0.        , ..., 0.18980383, 0.29581817,
#        0.24566829]), 'Length': 159, 'Height': 63, 'Ratio (Length/Height)': 2.5238095238095237, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 56, 'Centroid Y': 17, 'Slant Angle': 0.0}
# Image: 206.jpg
# Features: {'label': '206', 'features': array([0.10120194, 0.03232777, 0.04089176, ..., 0.24938727, 0.38729376,
#        0.20481322]), 'Length': 136, 'Height': 53, 'Ratio (Length/Height)': 2.5660377358490565, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 67, 'Centroid Y': 25, 'Slant Angle': 91.22093963623047}
# Image: 207.jpg
# Features: {'label': '207', 'features': array([0.08788008, 0.        , 0.20713531, ..., 0.18868474, 0.18671362,
#        0.30261487]), 'Length': 152, 'Height': 46, 'Ratio (Length/Height)': 3.3043478260869565, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 98, 'Centroid Y': 21, 'Slant Angle': 88.25720977783203}
# Image: 208.jpg
# Features: {'label': '208', 'features': array([0.32724732, 0.06192967, 0.04497817, ..., 0.37957737, 0.24674996,
#        0.52886408]), 'Length': 215, 'Height': 77, 'Ratio (Length/Height)': 2.792207792207792, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 110, 'Centroid Y': 36, 'Slant Angle': 0.0}
# Image: 209.jpg
# Features: {'label': '209', 'features': array([0.09968239, 0.02786208, 0.15859372, ..., 0.29827649, 0.36171466,
#        0.32434514]), 'Length': 163, 'Height': 73, 'Ratio (Length/Height)': 2.232876712328767, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 88, 'Centroid Y': 40, 'Slant Angle': 73.18025970458984}
# Image: 210.jpg
# Features: {'label': '210', 'features': array([0.30098192, 0.        , 0.11359448, ..., 0.20785293, 0.0894347 ,
#        0.25617067]), 'Length': 195, 'Height': 66, 'Ratio (Length/Height)': 2.9545454545454546, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 131, 'Centroid Y': 47, 'Slant Angle': 85.01449584960938}
# Image: 211.jpg
# Features: {'label': '211', 'features': array([0.20076475, 0.07347428, 0.02185727, ..., 0.21734944, 0.2267853 ,
#        0.21608389]), 'Length': 81, 'Height': 40, 'Ratio (Length/Height)': 2.025, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 40, 'Centroid Y': 19, 'Slant Angle': 0}
# Image: 212.jpg
# Features: {'label': '212', 'features': array([0.32164591, 0.08082508, 0.20447307, ..., 0.30969144, 0.30786771,
#        0.30088002]), 'Length': 207, 'Height': 67, 'Ratio (Length/Height)': 3.08955223880597, 'Integer Ratio': 3, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 103, 'Centroid Y': 32, 'Slant Angle': 92.05183410644531}
# Number of images processed: 88
# Features saved to D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\dataset.xlsx

# %%
import os
import cv2
import numpy as np
import pandas as pd
from skimage.feature import hog

def extract_stroke_features(image):
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    return features

def extract_shape_features(image):
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    shape_features = []
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        area = cv2.contourArea(contour)
        perimeter = cv2.arcLength(contour, True)
        shape_features = [aspect_ratio, area, perimeter]
    return shape_features

def calculate_slant_angle(image):
    # Convert image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Threshold the image to obtain a binary image
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    
    # Find contours in the binary image
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Find the largest contour (signature)
    largest_contour = max(contours, key=cv2.contourArea)
    
    # Check if the contour contains at least 5 points
    if len(largest_contour) < 5:
        # If the contour has too few points, return a default angle (0 degrees)
        return 0
    
    # Perform principal component analysis (PCA) on the largest contour
    _, _, angle = cv2.fitEllipse(largest_contour)
    
    # The angle returned by fitEllipse is the angle of rotation of the fitted ellipse
    # We use this as an estimate of the slant angle of the signature
    return angle


def extract_angle_features(image):
    # Calculate angle features (e.g., angles between strokes)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    lines = cv2.HoughLinesP(edges, 1, np.pi/180, threshold=100, minLineLength=100, maxLineGap=10)
    angle_features = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            angle = np.arctan2(y2 - y1, x2 - x1) * 180 / np.pi
            angle_features.append(angle)
    return angle_features

def extract_curvature_features(image):
    # Calculate curvature features
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    curvature_features = []
    if contours:
        for contour in contours:
            M = cv2.moments(contour)
            if M["m00"] != 0:
                cx = int(M["m10"] / M["m00"])
                cy = int(M["m01"] / M["m00"])
                cX, cY = cx, cy
                points = contour[:, 0]
                prev_point = points[0]
                total_distance = 0
                total_curvature = 0
                num_points = 0
                for point in points[1:]:
                    distance = np.linalg.norm(point - prev_point)
                    total_distance += distance
                    angle = np.arctan2(point[1] - prev_point[1], point[0] - prev_point[0])
                    curvature = np.abs(angle - prev_angle) / distance if num_points > 0 else 0
                    total_curvature += curvature
                    prev_point = point
                    prev_angle = angle
                    num_points += 1
                if num_points > 0:
                    mean_curvature = total_curvature / total_distance
                    curvature_features.append(mean_curvature)
    return curvature_features

def classify_sign(image):
    # Replace this with your own sign classification method
    # Example: Determine if the sign is angular, circular, or something else
    # You may use machine learning models, rules-based systems, etc.
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    
    # Simple rule-based classification
    if len(features) < 1000:
        return "Circular"
    else:
        return "Angular"

def assess_skill(image):
    # Replace this with your own method for assessing the overall skill of the signature
    # Example: Use machine learning models or rules-based systems to evaluate the signature's quality
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    
    # Simple rule-based assessment
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        if aspect_ratio > 0.5:
            return "Good"
        else:
            return "Poor"
    else:
        return "Poor"


def extract_additional_features(image):
    # Calculate length, height, ratio, integer ratio
    height, length, _ = image.shape
    ratio = length / height
    integer_ratio = int(ratio)
    
    # Classify the sign
    sign_classification = classify_sign(image)
    
    # Assess overall skill
    overall_skill = assess_skill(image)
    
    # Calculate centroid coordinates
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        contour = max(contours, key=cv2.contourArea)
        M = cv2.moments(contour)
        if M["m00"] != 0:
            centroid_x = int(M["m10"] / M["m00"])
            centroid_y = int(M["m01"] / M["m00"])
        else:
            centroid_x, centroid_y = -1, -1
    else:
        centroid_x, centroid_y = -1, -1
    
    # Calculate slant angle
    slant_angle = calculate_slant_angle(image)
    
    return {
        'Length': length,
        'Height': height,
        'Ratio (Length/Height)': ratio,
        'Integer Ratio': integer_ratio,
        'Sign Classification': sign_classification,
        'Overall Skill': overall_skill,
        'Centroid X': centroid_x,
        'Centroid Y': centroid_y,
        'Slant Angle': slant_angle
    }

def extract_features_from_images(sample_images_folder):
    features_list = []
    for filename in os.listdir(sample_images_folder):
        image_path = os.path.join(sample_images_folder, filename)
        
        # Extract label from filename
        label = os.path.splitext(filename)[0]
        
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue  # Skip this image if loading fails
        
        # Extract additional features
        additional_features = extract_additional_features(image)
        
        # Extract stroke features
        stroke_features = extract_stroke_features(image)
        
        # Extract shape features
        shape_features = extract_shape_features(image)
        
        # Extract angle features
        angle_features = extract_angle_features(image)
        
        # Extract curvature features
        curvature_features = extract_curvature_features(image)
        
        # Combine all features into a single feature vector
        all_features = np.concatenate((stroke_features, shape_features, angle_features, curvature_features))
        
        # Add features, label, and additional features to the list
        features_dict = {
            "label": label,
            "features": all_features,
            **additional_features
        }
        features_list.append(features_dict)
        
        # Print feature values
        print(f"Image: {filename}")
        print(f"Features: {features_dict}")
    
    print(f"Number of images processed: {len(features_list)}")
    return features_list

# Example usage:
sample_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample images"

features = extract_features_from_images(sample_images_folder)

# Convert features to DataFrame
df = pd.DataFrame(features)

# Save DataFrame to Excel file
excel_filename = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample.xlsx"
df.to_excel(excel_filename, index=False)

print(f"Features saved to {excel_filename}")
# Out:
# Image: 121.jpg
# Features: {'label': '121', 'features': array([0.40614268, 0.        , 0.        , ..., 0.27333066, 0.28524029,
#        0.22354762]), 'Length': 197, 'Height': 88, 'Ratio (Length/Height)': 2.2386363636363638, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 98, 'Centroid Y': 43, 'Slant Angle': 92.14785766601562}
# Image: 132.jpg
# Features: {'label': '132', 'features': array([0.18077538, 0.        , 0.        , ..., 0.16663398, 0.42196987,
#        0.17294859]), 'Length': 127, 'Height': 60, 'Ratio (Length/Height)': 2.1166666666666667, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 55, 'Centroid Y': 22, 'Slant Angle': 87.39740753173828}
# Image: 153.jpg
# Features: {'label': '153', 'features': array([3.33951183e-01, 6.97702137e-02, 1.87555060e-02, ...,
#        2.73597979e+02, 3.00361669e-01, 3.02547831e-01]), 'Length': 130, 'Height': 53, 'Ratio (Length/Height)': 2.452830188679245, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 53, 'Centroid Y': 18, 'Slant Angle': 84.9600601196289}
# Number of images processed: 3
# Features saved to D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample.xlsx

# %%
import pandas as pd
import numpy as np

# Load features from Excel files
sample_features_file =r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample.xlsx"
dataset_features_file = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\dataset.xlsx"

sample_df = pd.read_excel(sample_features_file)
dataset_df = pd.read_excel(dataset_features_file)

# Convert feature vectors to numpy arrays
sample_df['features'] = sample_df['features'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))
dataset_df['features'] = dataset_df['features'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))

# Define a function to calculate similarity between feature vectors
def calculate_similarity(feature_vector1, feature_vector2):
    # Here you can use any suitable similarity metric, such as Euclidean distance or cosine similarity
    return np.linalg.norm(feature_vector1 - feature_vector2)  # Euclidean distance

# Set a threshold for similarity
threshold = 0.5  # Adjust as needed

# Dictionary to store most similar dataset image for each sample image
most_similar_images = {}

# Iterate over sample images
for index, sample_row in sample_df.iterrows():
    sample_feature_vector = sample_row["features"]
    sample_label = sample_row["label"]
    most_similar_image = None
    min_similarity = float('inf')
    
    # Iterate over dataset images
    for index, dataset_row in dataset_df.iterrows():
        dataset_feature_vector = dataset_row["features"]
        dataset_label = dataset_row["label"]
        
        # Calculate similarity between sample and dataset feature vectors
        similarity = calculate_similarity(sample_feature_vector, dataset_feature_vector)
        
        # If similarity is below threshold and better than previous matches, update most similar image
        if similarity < threshold and similarity < min_similarity:
            most_similar_image = dataset_label
            min_similarity = similarity
    
    # Store the most similar dataset image for the current sample image
    if most_similar_image is not None:
        most_similar_images[sample_label] = most_similar_image

# Print most similar images for each sample image
print("Most similar images from the dataset for each sample image:")
for sample_image, similar_image in most_similar_images.items():
    print(f"Sample Image: {sample_image}, Most Similar Dataset Image: {similar_image}")
# Out:
# Most similar images from the dataset for each sample image:
# Sample Image: 121, Most Similar Dataset Image: 136
# Sample Image: 132, Most Similar Dataset Image: 203
# Sample Image: 153, Most Similar Dataset Image: 208
# C:\Users\FRIENDS INFOTECH\AppData\Local\Temp\ipykernel_5088\400571709.py:12: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   sample_df['features'] = sample_df['features'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))
# C:\Users\FRIENDS INFOTECH\AppData\Local\Temp\ipykernel_5088\400571709.py:13: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   dataset_df['features'] = dataset_df['features'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))

# %%
import os
import numpy as np

def extract_features_from_images(images_folder):
    features_list = []
    for filename in os.listdir(images_folder):
        image_path = os.path.join(images_folder, filename)
        # Read the image and extract features (replace this with your feature extraction method)
        features = np.random.rand(10)  # Dummy features for demonstration
        features_list.append((filename, features))
    return features_list

def compare_with_dataset(sample_features, dataset_features, threshold=0.5):
    matched_images = []
    for sample_filename, sample_feature in sample_features:
        matched_dataset_images = []
        for dataset_filename, dataset_feature in dataset_features:
            # Calculate distance between sample and dataset features (replace this with your distance metric)
            distance = np.linalg.norm(sample_feature - dataset_feature)
            # If the distance is below the threshold, consider it a match
            if distance < threshold:
                matched_dataset_images.append(dataset_filename)
        if matched_dataset_images:
            matched_images.append((sample_filename, matched_dataset_images))
    return matched_images

def test_signature_matching(sample_images_folder, dataset_images_folder, threshold=0.5):
    # Extract features from sample images and dataset images
    sample_features = extract_features_from_images(sample_images_folder)
    dataset_features = extract_features_from_images(dataset_images_folder)

    # Compare sample features with dataset features
    matched_images = compare_with_dataset(sample_features, dataset_features, threshold)

    # Print matched image names or numbers along with the corresponding sample image names
    if matched_images:
        print("Matched images from the dataset:")
        for sample_image, matched_dataset_images in matched_images:
            print(f"Sample Image: {sample_image}, Matched Dataset Images: {matched_dataset_images}")
    else:
        print("No matching images found in the dataset.")

# Paths to sample images and dataset images folders
sample_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample images"
dataset_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain"

# Set a threshold for considering a match (adjust as needed)
threshold = 0.5

# Test the signature matching
test_signature_matching(sample_images_folder, dataset_images_folder, threshold)
# Out:
# No matching images found in the dataset.

# %%
import os
import cv2
import numpy as np
import pandas as pd
from skimage.feature import hog

def extract_stroke_features(image):
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    return features

def extract_shape_features(image):
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    shape_features = []
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        area = cv2.contourArea(contour)
        perimeter = cv2.arcLength(contour, True)
        shape_features = [aspect_ratio, area, perimeter]
    return shape_features

def calculate_slant_angle(image):
    # Convert image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Threshold the image to obtain a binary image
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    
    # Find contours in the binary image
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Find the largest contour (signature)
    largest_contour = max(contours, key=cv2.contourArea)
    
    # Check if the contour contains at least 5 points
    if len(largest_contour) < 5:
        # If the contour has too few points, return a default angle (0 degrees)
        return 0
    
    # Perform principal component analysis (PCA) on the largest contour
    _, _, angle = cv2.fitEllipse(largest_contour)
    
    # The angle returned by fitEllipse is the angle of rotation of the fitted ellipse
    # We use this as an estimate of the slant angle of the signature
    return angle


def extract_angle_features(image):
    # Calculate angle features (e.g., angles between strokes)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    lines = cv2.HoughLinesP(edges, 1, np.pi/180, threshold=100, minLineLength=100, maxLineGap=10)
    angle_features = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            angle = np.arctan2(y2 - y1, x2 - x1) * 180 / np.pi
            angle_features.append(angle)
    return angle_features

def extract_curvature_features(image):
    # Calculate curvature features
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    curvature_features = []
    if contours:
        for contour in contours:
            M = cv2.moments(contour)
            if M["m00"] != 0:
                cx = int(M["m10"] / M["m00"])
                cy = int(M["m01"] / M["m00"])
                cX, cY = cx, cy
                points = contour[:, 0]
                prev_point = points[0]
                total_distance = 0
                total_curvature = 0
                num_points = 0
                for point in points[1:]:
                    distance = np.linalg.norm(point - prev_point)
                    total_distance += distance
                    angle = np.arctan2(point[1] - prev_point[1], point[0] - prev_point[0])
                    curvature = np.abs(angle - prev_angle) / distance if num_points > 0 else 0
                    total_curvature += curvature
                    prev_point = point
                    prev_angle = angle
                    num_points += 1
                if num_points > 0:
                    mean_curvature = total_curvature / total_distance
                    curvature_features.append(mean_curvature)
    return curvature_features

def classify_sign(image):
    # Replace this with your own sign classification method
    # Example: Determine if the sign is angular, circular, or something else
    # You may use machine learning models, rules-based systems, etc.
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    
    # Simple rule-based classification
    if len(features) < 1000:
        return "Circular"
    else:
        return "Angular"

def assess_skill(image):
    # Replace this with your own method for assessing the overall skill of the signature
    # Example: Use machine learning models or rules-based systems to evaluate the signature's quality
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    
    # Simple rule-based assessment
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        if aspect_ratio > 0.5:
            return "Good"
        else:
            return "Poor"
    else:
        return "Poor"


def extract_additional_features(image):
    # Calculate length, height, ratio, integer ratio
    height, length, _ = image.shape
    ratio = length / height
    integer_ratio = int(ratio)
    
    # Classify the sign
    sign_classification = classify_sign(image)
    
    # Assess overall skill
    overall_skill = assess_skill(image)
    
    # Calculate centroid coordinates
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        contour = max(contours, key=cv2.contourArea)
        M = cv2.moments(contour)
        if M["m00"] != 0:
            centroid_x = int(M["m10"] / M["m00"])
            centroid_y = int(M["m01"] / M["m00"])
        else:
            centroid_x, centroid_y = -1, -1
    else:
        centroid_x, centroid_y = -1, -1
    
    # Calculate slant angle
    slant_angle = calculate_slant_angle(image)
    
    return {
        'Length': length,
        'Height': height,
        'Ratio (Length/Height)': ratio,
        'Integer Ratio': integer_ratio,
        'Sign Classification': sign_classification,
        'Overall Skill': overall_skill,
        'Centroid X': centroid_x,
        'Centroid Y': centroid_y,
        'Slant Angle': slant_angle
    }

def extract_features_from_images(sample_images_folder):
    features_list = []
    for filename in os.listdir(sample_images_folder):
        image_path = os.path.join(sample_images_folder, filename)
        
        # Extract label from filename
        label = os.path.splitext(filename)[0]
        
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue  # Skip this image if loading fails
        
        # Extract additional features
        additional_features = extract_additional_features(image)
        
        # Extract stroke features
        stroke_features = extract_stroke_features(image)
        
        # Extract shape features
        shape_features = extract_shape_features(image)
        
        # Extract angle features
        angle_features = extract_angle_features(image)
        
        # Extract curvature features
        curvature_features = extract_curvature_features(image)
        
        # Combine all features into a single feature vector
        all_features = np.concatenate((stroke_features, shape_features, angle_features, curvature_features))
        
        # Add features, label, and additional features to the list
        features_dict = {
            "label": label,
            "features": all_features,
            **additional_features
        }
        features_list.append(features_dict)
        
        # Print feature values
        print(f"Image: {filename}")
        print(f"Features: {features_dict}")
    
    print(f"Number of images processed: {len(features_list)}")
    return features_list

# Example usage:
sample_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\kabeer main\kabeer sample image"

features = extract_features_from_images(sample_images_folder)

# Convert features to DataFrame
df = pd.DataFrame(features)

# Save DataFrame to Excel file
excel_filename = r"D:\AIML Internship\cropped_signatures\cropped_signatures\kabeer main\sample.xlsx"
df.to_excel(excel_filename, index=False)

print(f"Features saved to {excel_filename}")
# Out:
# Image: 1.jpg
# Features: {'label': '1', 'features': array([0.04132208, 0.        , 0.0233753 , ..., 0.32553102, 0.81145465,
#        0.36577128]), 'Length': 117, 'Height': 69, 'Ratio (Length/Height)': 1.6956521739130435, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 58, 'Centroid Y': 34, 'Slant Angle': 0}
# Image: 56.jpg
# Features: {'label': '56', 'features': array([0.02936837, 0.00273624, 0.0034611 , ..., 0.18845876, 0.35122746,
#        0.35669672]), 'Length': 118, 'Height': 62, 'Ratio (Length/Height)': 1.903225806451613, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 79, 'Centroid Y': 15, 'Slant Angle': 89.0597915649414}
# Number of images processed: 2
# Features saved to D:\AIML Internship\cropped_signatures\cropped_signatures\kabeer main\sample.xlsx

# %%
import os
import cv2
import numpy as np
import pandas as pd
from skimage.feature import hog

def extract_stroke_features(image):
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    return features

def extract_shape_features(image):
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    shape_features = []
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        area = cv2.contourArea(contour)
        perimeter = cv2.arcLength(contour, True)
        shape_features = [aspect_ratio, area, perimeter]
    return shape_features

def calculate_slant_angle(image):
    # Convert image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Threshold the image to obtain a binary image
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    
    # Find contours in the binary image
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Find the largest contour (signature)
    largest_contour = max(contours, key=cv2.contourArea)
    
    # Check if the contour contains at least 5 points
    if len(largest_contour) < 5:
        # If the contour has too few points, return a default angle (0 degrees)
        return 0
    
    # Perform principal component analysis (PCA) on the largest contour
    _, _, angle = cv2.fitEllipse(largest_contour)
    
    # The angle returned by fitEllipse is the angle of rotation of the fitted ellipse
    # We use this as an estimate of the slant angle of the signature
    return angle


def extract_angle_features(image):
    # Calculate angle features (e.g., angles between strokes)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    lines = cv2.HoughLinesP(edges, 1, np.pi/180, threshold=100, minLineLength=100, maxLineGap=10)
    angle_features = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            angle = np.arctan2(y2 - y1, x2 - x1) * 180 / np.pi
            angle_features.append(angle)
    return angle_features

def extract_curvature_features(image):
    # Calculate curvature features
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    curvature_features = []
    if contours:
        for contour in contours:
            M = cv2.moments(contour)
            if M["m00"] != 0:
                cx = int(M["m10"] / M["m00"])
                cy = int(M["m01"] / M["m00"])
                cX, cY = cx, cy
                points = contour[:, 0]
                prev_point = points[0]
                total_distance = 0
                total_curvature = 0
                num_points = 0
                for point in points[1:]:
                    distance = np.linalg.norm(point - prev_point)
                    total_distance += distance
                    angle = np.arctan2(point[1] - prev_point[1], point[0] - prev_point[0])
                    curvature = np.abs(angle - prev_angle) / distance if num_points > 0 else 0
                    total_curvature += curvature
                    prev_point = point
                    prev_angle = angle
                    num_points += 1
                if num_points > 0:
                    mean_curvature = total_curvature / total_distance
                    curvature_features.append(mean_curvature)
    return curvature_features

def classify_sign(image):
    # Replace this with your own sign classification method
    # Example: Determine if the sign is angular, circular, or something else
    # You may use machine learning models, rules-based systems, etc.
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    
    # Simple rule-based classification
    if len(features) < 1000:
        return "Circular"
    else:
        return "Angular"

def assess_skill(image):
    # Replace this with your own method for assessing the overall skill of the signature
    # Example: Use machine learning models or rules-based systems to evaluate the signature's quality
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    
    # Simple rule-based assessment
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        if aspect_ratio > 0.5:
            return "Good"
        else:
            return "Poor"
    else:
        return "Poor"


def extract_additional_features(image):
    # Calculate length, height, ratio, integer ratio
    height, length, _ = image.shape
    ratio = length / height
    integer_ratio = int(ratio)
    
    # Classify the sign
    sign_classification = classify_sign(image)
    
    # Assess overall skill
    overall_skill = assess_skill(image)
    
    # Calculate centroid coordinates
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        contour = max(contours, key=cv2.contourArea)
        M = cv2.moments(contour)
        if M["m00"] != 0:
            centroid_x = int(M["m10"] / M["m00"])
            centroid_y = int(M["m01"] / M["m00"])
        else:
            centroid_x, centroid_y = -1, -1
    else:
        centroid_x, centroid_y = -1, -1
    
    # Calculate slant angle
    slant_angle = calculate_slant_angle(image)
    
    return {
        'Length': length,
        'Height': height,
        'Ratio (Length/Height)': ratio,
        'Integer Ratio': integer_ratio,
        'Sign Classification': sign_classification,
        'Overall Skill': overall_skill,
        'Centroid X': centroid_x,
        'Centroid Y': centroid_y,
        'Slant Angle': slant_angle
    }

def extract_features_from_images(sample_images_folder):
    features_list = []
    for filename in os.listdir(sample_images_folder):
        image_path = os.path.join(sample_images_folder, filename)
        
        # Extract label from filename
        label = os.path.splitext(filename)[0]
        
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue  # Skip this image if loading fails
        
        # Extract additional features
        additional_features = extract_additional_features(image)
        
        # Extract stroke features
        stroke_features = extract_stroke_features(image)
        
        # Extract shape features
        shape_features = extract_shape_features(image)
        
        # Extract angle features
        angle_features = extract_angle_features(image)
        
        # Extract curvature features
        curvature_features = extract_curvature_features(image)
        
        # Combine all features into a single feature vector
        all_features = np.concatenate((stroke_features, shape_features, angle_features, curvature_features))
        
        # Add features, label, and additional features to the list
        features_dict = {
            "label": label,
            "features": all_features,
            **additional_features
        }
        features_list.append(features_dict)
        
        # Print feature values
        print(f"Image: {filename}")
        print(f"Features: {features_dict}")
    
    print(f"Number of images processed: {len(features_list)}")
    return features_list

# Example usage:
sample_images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\kabeer main\Kabeer"

features = extract_features_from_images(sample_images_folder)

# Convert features to DataFrame
df = pd.DataFrame(features)

# Save DataFrame to Excel file
excel_filename = r"D:\AIML Internship\cropped_signatures\cropped_signatures\kabeer main\dataset.xlsx"
df.to_excel(excel_filename, index=False)

print(f"Features saved to {excel_filename}")
# Out:
# Image: 10.jpg
# Features: {'label': '10', 'features': array([0.00934109, 0.00094517, 0.00750182, ..., 0.81145465, 0.32008575,
#        0.25548501]), 'Length': 110, 'Height': 64, 'Ratio (Length/Height)': 1.71875, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 64, 'Centroid Y': 46, 'Slant Angle': 81.65257263183594}
# Image: 11.jpg
# Features: {'label': '11', 'features': array([0.15963098, 0.03072642, 0.08532324, ..., 0.30225756, 0.37035011,
#        0.39789038]), 'Length': 120, 'Height': 67, 'Ratio (Length/Height)': 1.791044776119403, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 71, 'Centroid Y': 35, 'Slant Angle': 95.05685424804688}
# Image: 12.jpg
# Features: {'label': '12', 'features': array([0.0278378 , 0.        , 0.00145543, ..., 0.13377541, 0.40885998,
#        0.16950834]), 'Length': 118, 'Height': 64, 'Ratio (Length/Height)': 1.84375, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 72, 'Centroid Y': 49, 'Slant Angle': 81.36953735351562}
# Image: 13.jpg
# Features: {'label': '13', 'features': array([0.01241416, 0.01110998, 0.01496621, ..., 0.17104236, 0.39602093,
#        0.32151381]), 'Length': 122, 'Height': 83, 'Ratio (Length/Height)': 1.4698795180722892, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 74, 'Centroid Y': 45, 'Slant Angle': 77.91389465332031}
# Image: 14.jpg
# Features: {'label': '14', 'features': array([0.01986563, 0.        , 0.00766207, ..., 0.41772241, 0.28286305,
#        0.3400219 ]), 'Length': 123, 'Height': 74, 'Ratio (Length/Height)': 1.662162162162162, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 75, 'Centroid Y': 38, 'Slant Angle': 93.07099914550781}
# Image: 15.jpg
# Features: {'label': '15', 'features': array([0.01771081, 0.        , 0.00556597, ..., 0.71802165, 0.40286849,
#        0.33487919]), 'Length': 126, 'Height': 71, 'Ratio (Length/Height)': 1.7746478873239437, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 84, 'Centroid Y': 36, 'Slant Angle': 95.26610565185547}
# Image: 16.jpg
# Features: {'label': '16', 'features': array([0.02662297, 0.        , 0.00584235, ..., 0.34054363, 0.28445008,
#        0.34567248]), 'Length': 129, 'Height': 59, 'Ratio (Length/Height)': 2.1864406779661016, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 71, 'Centroid Y': 46, 'Slant Angle': 87.63318634033203}
# Image: 17.jpg
# Features: {'label': '17', 'features': array([0.0177466 , 0.00638278, 0.00114997, ..., 0.41635054, 0.26482799,
#        0.26968948]), 'Length': 104, 'Height': 60, 'Ratio (Length/Height)': 1.7333333333333334, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 72, 'Centroid Y': 30, 'Slant Angle': 12.40634536743164}
# Image: 18.jpg
# Features: {'label': '18', 'features': array([0.03765994, 0.11905268, 0.20094594, ..., 0.38067761, 0.293545  ,
#        0.24590571]), 'Length': 115, 'Height': 55, 'Ratio (Length/Height)': 2.090909090909091, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 78, 'Centroid Y': 39, 'Slant Angle': 69.66011810302734}
# Image: 19.jpg
# Features: {'label': '19', 'features': array([0.01653337, 0.00288802, 0.00487078, ..., 0.15291299, 0.35583767,
#        0.25007398]), 'Length': 101, 'Height': 72, 'Ratio (Length/Height)': 1.4027777777777777, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Poor', 'Centroid X': 65, 'Centroid Y': 38, 'Slant Angle': 43.30498504638672}
# Image: 2.jpg
# Features: {'label': '2', 'features': array([0.01679678, 0.00139106, 0.00703829, ..., 0.15632301, 0.40431862,
#        0.34444151]), 'Length': 117, 'Height': 70, 'Ratio (Length/Height)': 1.6714285714285715, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 58, 'Centroid Y': 34, 'Slant Angle': 0}
# Image: 20.jpg
# Features: {'label': '20', 'features': array([0.02120957, 0.03471777, 0.25386896, ..., 0.42442925, 0.50124889,
#        0.30587999]), 'Length': 107, 'Height': 54, 'Ratio (Length/Height)': 1.9814814814814814, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 71, 'Centroid Y': 26, 'Slant Angle': 45.67216491699219}
# Image: 21.jpg
# Features: {'label': '21', 'features': array([0.03500261, 0.00373016, 0.19116136, ..., 0.41474544, 0.34289032,
#        0.17347354]), 'Length': 114, 'Height': 63, 'Ratio (Length/Height)': 1.8095238095238095, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 70, 'Centroid Y': 31, 'Slant Angle': 89.72146606445312}
# Image: 22.jpg
# Features: {'label': '22', 'features': array([0.01119758, 0.0020208 , 0.00635988, ..., 0.27328905, 0.28050581,
#        0.16474809]), 'Length': 104, 'Height': 61, 'Ratio (Length/Height)': 1.7049180327868851, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 67, 'Centroid Y': 31, 'Slant Angle': 62.03077697753906}
# Image: 24.jpg
# Features: {'label': '24', 'features': array([0.02516867, 0.00824648, 0.00635735, ..., 0.48798386, 0.27223499,
#        0.36465226]), 'Length': 122, 'Height': 68, 'Ratio (Length/Height)': 1.7941176470588236, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 72, 'Centroid Y': 15, 'Slant Angle': 86.55854034423828}
# Image: 25.jpg
# Features: {'label': '25', 'features': array([0.00752539, 0.        , 0.        , ..., 0.48779124, 0.32645308,
#        0.30567043]), 'Length': 107, 'Height': 76, 'Ratio (Length/Height)': 1.4078947368421053, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 69, 'Centroid Y': 40, 'Slant Angle': 12.904369354248047}
# Image: 26.jpg
# Features: {'label': '26', 'features': array([0.01026206, 0.00500933, 0.01420312, ..., 0.16889157, 0.34141908,
#        0.33598994]), 'Length': 103, 'Height': 72, 'Ratio (Length/Height)': 1.4305555555555556, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 63, 'Centroid Y': 36, 'Slant Angle': 85.50413513183594}
# Image: 27.jpg
# Features: {'label': '27', 'features': array([0.01540487, 0.        , 0.00272322, ..., 0.17042589, 0.31483504,
#        0.26311778]), 'Length': 108, 'Height': 64, 'Ratio (Length/Height)': 1.6875, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Poor', 'Centroid X': 68, 'Centroid Y': 47, 'Slant Angle': 61.44058609008789}
# Image: 29.jpg
# Features: {'label': '29', 'features': array([0.00757103, 0.00083965, 0.00477939, ..., 0.17162822, 0.47046222,
#        0.29861915]), 'Length': 102, 'Height': 79, 'Ratio (Length/Height)': 1.2911392405063291, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 58, 'Centroid Y': 43, 'Slant Angle': 100.13700866699219}
# Image: 3.jpg
# Features: {'label': '3', 'features': array([0.00279646, 0.00125062, 0.0039548 , ..., 0.83751114, 0.45646807,
#        0.33422201]), 'Length': 134, 'Height': 61, 'Ratio (Length/Height)': 2.19672131147541, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 75, 'Centroid Y': 30, 'Slant Angle': 87.70233917236328}
# Image: 30.jpg
# Features: {'label': '30', 'features': array([0.01501329, 0.        , 0.00468498, ..., 0.55080155, 0.20930443,
#        0.33306112]), 'Length': 114, 'Height': 63, 'Ratio (Length/Height)': 1.8095238095238095, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 70, 'Centroid Y': 32, 'Slant Angle': 95.53056335449219}
# Image: 31.jpg
# Features: {'label': '31', 'features': array([0.02352848, 0.        , 0.00554572, ..., 0.37873452, 0.23644488,
#        0.3385512 ]), 'Length': 124, 'Height': 72, 'Ratio (Length/Height)': 1.7222222222222223, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 70, 'Centroid Y': 37, 'Slant Angle': 96.9637451171875}
# Image: 32.jpg
# Features: {'label': '32', 'features': array([0.02008964, 0.00249566, 0.01894069, ..., 0.3625207 , 0.20454927,
#        0.31822529]), 'Length': 120, 'Height': 70, 'Ratio (Length/Height)': 1.7142857142857142, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 69, 'Centroid Y': 36, 'Slant Angle': 98.85493469238281}
# Image: 33.jpg
# Features: {'label': '33', 'features': array([0.01655083, 0.04699562, 0.00539531, ..., 0.26805858, 0.40661817,
#        0.37376449]), 'Length': 111, 'Height': 69, 'Ratio (Length/Height)': 1.608695652173913, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 72, 'Centroid Y': 34, 'Slant Angle': 93.66327667236328}
# Image: 34.jpg
# Features: {'label': '34', 'features': array([0.07573703, 0.05017624, 0.07382206, ..., 0.19750594, 0.27909058,
#        0.26862469]), 'Length': 122, 'Height': 77, 'Ratio (Length/Height)': 1.5844155844155845, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 74, 'Centroid Y': 40, 'Slant Angle': 90.35432434082031}
# Image: 35.jpg
# Features: {'label': '35', 'features': array([0.04229967, 0.01646219, 0.00238449, ..., 0.33141671, 0.31865356,
#        0.2989281 ]), 'Length': 118, 'Height': 62, 'Ratio (Length/Height)': 1.903225806451613, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 70, 'Centroid Y': 14, 'Slant Angle': 89.31695556640625}
# Image: 36.jpg
# Features: {'label': '36', 'features': array([0.26268039, 0.09966517, 0.06196738, ..., 0.26953363, 0.30395492,
#        0.35405439]), 'Length': 135, 'Height': 56, 'Ratio (Length/Height)': 2.4107142857142856, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 81, 'Centroid Y': 12, 'Slant Angle': 88.55386352539062}
# Image: 37.jpg
# Features: {'label': '37', 'features': array([0.01181324, 0.00080046, 0.00253128, ..., 0.12978624, 0.29166937,
#        0.34242791]), 'Length': 121, 'Height': 75, 'Ratio (Length/Height)': 1.6133333333333333, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Poor', 'Centroid X': 58, 'Centroid Y': 37, 'Slant Angle': 153.7542724609375}
# Image: 38.jpg
# Features: {'label': '38', 'features': array([0.02565318, 0.00404004, 0.07813761, ..., 0.45719513, 0.2832824 ,
#        0.26715463]), 'Length': 130, 'Height': 72, 'Ratio (Length/Height)': 1.8055555555555556, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Poor', 'Centroid X': 79, 'Centroid Y': 37, 'Slant Angle': 92.95098876953125}
# Image: 39.jpg
# Features: {'label': '39', 'features': array([0.03386439, 0.0054262 , 0.00520825, ..., 0.23100923, 0.24701919,
#        0.16342512]), 'Length': 133, 'Height': 68, 'Ratio (Length/Height)': 1.9558823529411764, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 83, 'Centroid Y': 34, 'Slant Angle': 93.89682006835938}
# Image: 4.jpg
# Features: {'label': '4', 'features': array([0.01043631, 0.00676878, 0.0052201 , ..., 0.22280659, 0.41710414,
#        0.40126316]), 'Length': 108, 'Height': 76, 'Ratio (Length/Height)': 1.4210526315789473, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 67, 'Centroid Y': 39, 'Slant Angle': 107.92533874511719}
# Image: 40.jpg
# Features: {'label': '40', 'features': array([0.00846808, 0.        , 0.0021774 , ..., 0.2030731 , 0.33855025,
#        0.28083265]), 'Length': 119, 'Height': 62, 'Ratio (Length/Height)': 1.9193548387096775, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 60, 'Centroid Y': 45, 'Slant Angle': 86.16522979736328}
# Image: 41.jpg
# Features: {'label': '41', 'features': array([0.00770378, 0.00132509, 0.00167612, ..., 0.21173291, 0.4394399 ,
#        0.27037529]), 'Length': 121, 'Height': 75, 'Ratio (Length/Height)': 1.6133333333333333, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 78, 'Centroid Y': 35, 'Slant Angle': 91.17560577392578}
# Image: 42.jpg
# Features: {'label': '42', 'features': array([0.02192241, 0.00097393, 0.00431175, ..., 0.23387104, 0.24303876,
#        0.33755397]), 'Length': 120, 'Height': 69, 'Ratio (Length/Height)': 1.7391304347826086, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Poor', 'Centroid X': 78, 'Centroid Y': 34, 'Slant Angle': 0.0}
# Image: 43.jpg
# Features: {'label': '43', 'features': array([0.01286498, 0.00260311, 0.00439028, ..., 0.26294762, 0.2756313 ,
#        0.20774256]), 'Length': 136, 'Height': 67, 'Ratio (Length/Height)': 2.029850746268657, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 88, 'Centroid Y': 16, 'Slant Angle': 90.60782623291016}
# Image: 44.jpg
# Features: {'label': '44', 'features': array([0.01286498, 0.00260311, 0.00439028, ..., 0.26294762, 0.2756313 ,
#        0.20774256]), 'Length': 136, 'Height': 67, 'Ratio (Length/Height)': 2.029850746268657, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 88, 'Centroid Y': 16, 'Slant Angle': 90.60782623291016}
# Image: 45.jpg
# Features: {'label': '45', 'features': array([0.01742308, 0.05311342, 0.01180824, ..., 0.37490266, 0.27459542,
#        0.37425949]), 'Length': 121, 'Height': 68, 'Ratio (Length/Height)': 1.7794117647058822, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 74, 'Centroid Y': 33, 'Slant Angle': 87.89824676513672}
# Image: 46.jpg
# Features: {'label': '46', 'features': array([0.05190952, 0.00906395, 0.00511933, ..., 0.20257208, 0.35161679,
#        0.41501582]), 'Length': 129, 'Height': 64, 'Ratio (Length/Height)': 2.015625, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 79, 'Centroid Y': 31, 'Slant Angle': 90.955322265625}
# Image: 47.jpg
# Features: {'label': '47', 'features': array([0.01458574, 0.        , 0.00728024, ..., 0.27771424, 0.3038207 ,
#        0.30206783]), 'Length': 127, 'Height': 72, 'Ratio (Length/Height)': 1.7638888888888888, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 78, 'Centroid Y': 36, 'Slant Angle': 93.31135559082031}
# Image: 48.jpg
# Features: {'label': '48', 'features': array([0.02234056, 0.00115513, 0.00924062, ..., 0.14837487, 0.33359092,
#        0.24479818]), 'Length': 132, 'Height': 77, 'Ratio (Length/Height)': 1.7142857142857142, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Poor', 'Centroid X': 76, 'Centroid Y': 60, 'Slant Angle': 88.71941375732422}
# Image: 49.jpg
# Features: {'label': '49', 'features': array([0.02931577, 0.01204866, 0.04448007, ..., 0.26805858, 0.41229995,
#        0.39193334]), 'Length': 111, 'Height': 69, 'Ratio (Length/Height)': 1.608695652173913, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 72, 'Centroid Y': 34, 'Slant Angle': 93.50274658203125}
# Image: 5.jpg
# Features: {'label': '5', 'features': array([0.03366192, 0.00171977, 0.00480856, ..., 0.1932256 , 0.34830365,
#        0.40565681]), 'Length': 109, 'Height': 65, 'Ratio (Length/Height)': 1.676923076923077, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 64, 'Centroid Y': 31, 'Slant Angle': 79.74030303955078}
# Image: 50.jpg
# Features: {'label': '50', 'features': array([0.08629053, 0.10500288, 0.00986931, ..., 0.17339978, 0.30564241,
#        0.25676475]), 'Length': 110, 'Height': 77, 'Ratio (Length/Height)': 1.4285714285714286, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 65, 'Centroid Y': 59, 'Slant Angle': 86.12602996826172}
# Image: 51.jpg
# Features: {'label': '51', 'features': array([0.02430893, 0.00784701, 0.10772278, ..., 0.33733013, 0.24212778,
#        0.30121511]), 'Length': 118, 'Height': 61, 'Ratio (Length/Height)': 1.9344262295081966, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 81, 'Centroid Y': 14, 'Slant Angle': 99.37918090820312}
# Image: 52.jpg
# Features: {'label': '52', 'features': array([0.21035506, 0.09058998, 0.06265659, ..., 0.26953363, 0.30219847,
#        0.39308107]), 'Length': 135, 'Height': 56, 'Ratio (Length/Height)': 2.4107142857142856, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 81, 'Centroid Y': 12, 'Slant Angle': 88.6046371459961}
# Image: 53.jpg
# Features: {'label': '53', 'features': array([0.0084281 , 0.        , 0.00040822, ..., 0.33479082, 0.35582006,
#        0.26723631]), 'Length': 120, 'Height': 74, 'Ratio (Length/Height)': 1.6216216216216217, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 74, 'Centroid Y': 40, 'Slant Angle': 81.31938934326172}
# Image: 54.jpg
# Features: {'label': '54', 'features': array([0.01317344, 0.00249672, 0.08020057, ..., 0.22219531, 0.3569771 ,
#        0.26715463]), 'Length': 130, 'Height': 72, 'Ratio (Length/Height)': 1.8055555555555556, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Poor', 'Centroid X': 79, 'Centroid Y': 37, 'Slant Angle': 92.11920928955078}
# Image: 55.jpg
# Features: {'label': '55', 'features': array([0.01879308, 0.01017619, 0.00812088, ..., 0.26426034, 0.24676235,
#        0.21389875]), 'Length': 131, 'Height': 68, 'Ratio (Length/Height)': 1.9264705882352942, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 82, 'Centroid Y': 35, 'Slant Angle': 93.84085083007812}
# Image: 57.jpg
# Features: {'label': '57', 'features': array([0.00647094, 0.        , 0.0055206 , ..., 0.69011339, 0.27149892,
#        0.27379452]), 'Length': 121, 'Height': 74, 'Ratio (Length/Height)': 1.635135135135135, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 81, 'Centroid Y': 36, 'Slant Angle': 43.51287841796875}
# Image: 58.jpg
# Features: {'label': '58', 'features': array([0.02545302, 0.00254419, 0.0043115 , ..., 0.2351952 , 0.26114627,
#        0.31989873]), 'Length': 120, 'Height': 69, 'Ratio (Length/Height)': 1.7391304347826086, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Poor', 'Centroid X': 78, 'Centroid Y': 34, 'Slant Angle': 0.0}
# Image: 59.jpg
# Features: {'label': '59', 'features': array([0.0112756 , 0.00180093, 0.00740355, ..., 0.26935375, 0.27190207,
#        0.1984512 ]), 'Length': 137, 'Height': 67, 'Ratio (Length/Height)': 2.044776119402985, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 89, 'Centroid Y': 16, 'Slant Angle': 90.6491470336914}
# Image: 6.jpg
# Features: {'label': '6', 'features': array([0.0207897 , 0.0034435 , 0.00108893, ..., 0.85277467, 0.27871364,
#        0.31737836]), 'Length': 125, 'Height': 67, 'Ratio (Length/Height)': 1.8656716417910448, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 82, 'Centroid Y': 32, 'Slant Angle': 89.25570678710938}
# Image: 60.jpg
# Features: {'label': '60', 'features': array([0.01717594, 0.00172037, 0.00979254, ..., 0.29168778, 0.27079311,
#        0.34899281]), 'Length': 128, 'Height': 60, 'Ratio (Length/Height)': 2.1333333333333333, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 82, 'Centroid Y': 29, 'Slant Angle': 89.57630157470703}
# Image: 61.jpg
# Features: {'label': '61', 'features': array([0.0272093 , 0.11608496, 0.36237894, ..., 0.37104819, 0.40042154,
#        0.30566959]), 'Length': 120, 'Height': 67, 'Ratio (Length/Height)': 1.791044776119403, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 78, 'Centroid Y': 33, 'Slant Angle': 2.9328906536102295}
# Image: 62.jpg
# Features: {'label': '62', 'features': array([0.01717509, 0.0094372 , 0.00041599, ..., 0.33181632, 0.34883556,
#        0.37702857]), 'Length': 129, 'Height': 79, 'Ratio (Length/Height)': 1.6329113924050633, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 73, 'Centroid Y': 41, 'Slant Angle': 99.23704528808594}
# Image: 63.jpg
# Features: {'label': '63', 'features': array([0.00516354, 0.        , 0.00121706, ..., 0.26690212, 0.3056742 ,
#        0.28007074]), 'Length': 127, 'Height': 72, 'Ratio (Length/Height)': 1.7638888888888888, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 78, 'Centroid Y': 36, 'Slant Angle': 93.34696960449219}
# Image: 64.jpg
# Features: {'label': '64', 'features': array([0.00690429, 0.        , 0.00627694, ..., 0.26179939, 0.1553668 ,
#        0.29270175]), 'Length': 132, 'Height': 77, 'Ratio (Length/Height)': 1.7142857142857142, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Poor', 'Centroid X': 76, 'Centroid Y': 60, 'Slant Angle': 88.44998931884766}
# Image: 65.jpg
# Features: {'label': '65', 'features': array([0.05925796, 0.00812002, 0.00809551, ..., 0.32456769, 0.28399001,
#        0.24643612]), 'Length': 111, 'Height': 67, 'Ratio (Length/Height)': 1.6567164179104477, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 68, 'Centroid Y': 34, 'Slant Angle': 94.54850769042969}
# Image: 66.jpg
# Features: {'label': '66', 'features': array([0.30465003, 0.14762485, 0.16354117, ..., 0.29888592, 0.85875907,
#        0.26933774]), 'Length': 103, 'Height': 65, 'Ratio (Length/Height)': 1.5846153846153845, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Poor', 'Centroid X': 65, 'Centroid Y': 35, 'Slant Angle': 7.705559253692627}
# Image: 67.jpg
# Features: {'label': '67', 'features': array([0.01818798, 0.        , 0.0060427 , ..., 0.20184611, 0.23687087,
#        0.31944771]), 'Length': 111, 'Height': 54, 'Ratio (Length/Height)': 2.0555555555555554, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 53, 'Centroid Y': 26, 'Slant Angle': 161.62371826171875}
# Image: 68.jpg
# Features: {'label': '68', 'features': array([0.01215316, 0.00157637, 0.00598189, ..., 0.70843674, 0.47127661,
#        0.31954663]), 'Length': 113, 'Height': 61, 'Ratio (Length/Height)': 1.8524590163934427, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 62, 'Centroid Y': 45, 'Slant Angle': 96.19215393066406}
# Image: 69.jpg
# Features: {'label': '69', 'features': array([0.01450402, 0.00183215, 0.00289688, ..., 0.21913862, 0.28991854,
#        0.18386573]), 'Length': 100, 'Height': 66, 'Ratio (Length/Height)': 1.5151515151515151, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 68, 'Centroid Y': 32, 'Slant Angle': 85.69197845458984}
# Image: 7.jpg
# Features: {'label': '7', 'features': array([0.00876533, 0.        , 0.00391454, ..., 0.32904637, 0.34932722,
#        0.45700599]), 'Length': 135, 'Height': 53, 'Ratio (Length/Height)': 2.547169811320755, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 67, 'Centroid Y': 26, 'Slant Angle': 0}
# Image: 70.jpg
# Features: {'label': '70', 'features': array([0.00998795, 0.00670576, 0.00677331, ..., 0.11368757, 0.4684585 ,
#        0.33540301]), 'Length': 113, 'Height': 65, 'Ratio (Length/Height)': 1.7384615384615385, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 54, 'Centroid Y': 31, 'Slant Angle': 10.546398162841797}
# Image: 71.jpg
# Features: {'label': '71', 'features': array([0.02918041, 0.00175885, 0.01288175, ..., 0.09059054, 0.31191716,
#        0.33790879]), 'Length': 118, 'Height': 68, 'Ratio (Length/Height)': 1.7352941176470589, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 67, 'Centroid Y': 33, 'Slant Angle': 95.50740814208984}
# Image: 72.jpg
# Features: {'label': '72', 'features': array([0.00516763, 0.00639764, 0.00702204, ..., 0.34226285, 0.29804392,
#        0.3085077 ]), 'Length': 114, 'Height': 68, 'Ratio (Length/Height)': 1.6764705882352942, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 69, 'Centroid Y': 35, 'Slant Angle': 86.2775650024414}
# Image: 73.jpg
# Features: {'label': '73', 'features': array([0.01413727, 0.        , 0.00456789, ..., 0.41580603, 0.34101167,
#        0.26388528]), 'Length': 120, 'Height': 70, 'Ratio (Length/Height)': 1.7142857142857142, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 83, 'Centroid Y': 35, 'Slant Angle': 89.86731719970703}
# Image: 74.jpg
# Features: {'label': '74', 'features': array([0.01960503, 0.00380255, 0.00400824, ..., 0.20055501, 0.24897285,
#        0.31013553]), 'Length': 127, 'Height': 73, 'Ratio (Length/Height)': 1.7397260273972603, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 79, 'Centroid Y': 36, 'Slant Angle': 86.64997863769531}
# Image: 75.jpg
# Features: {'label': '75', 'features': array([0.01912085, 0.00266352, 0.00551064, ..., 0.1462212 , 0.21618924,
#        0.35269917]), 'Length': 125, 'Height': 57, 'Ratio (Length/Height)': 2.192982456140351, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 75, 'Centroid Y': 28, 'Slant Angle': 90.24298858642578}
# Image: 76.jpg
# Features: {'label': '76', 'features': array([0.13724015, 0.13947136, 0.26176452, ..., 0.19822719, 0.29364357,
#        0.31494473]), 'Length': 113, 'Height': 70, 'Ratio (Length/Height)': 1.6142857142857143, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 71, 'Centroid Y': 35, 'Slant Angle': 89.87471008300781}
# Image: 77.jpg
# Features: {'label': '77', 'features': array([0.17917677, 0.00853701, 0.07633425, ..., 0.53377447, 0.37978401,
#        0.3313271 ]), 'Length': 120, 'Height': 60, 'Ratio (Length/Height)': 2.0, 'Integer Ratio': 2, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 78, 'Centroid Y': 30, 'Slant Angle': 88.63567352294922}
# Image: 78.jpg
# Features: {'label': '78', 'features': array([0.19230002, 0.09512049, 0.00307354, ..., 0.32734002, 0.20954081,
#        0.24536629]), 'Length': 115, 'Height': 66, 'Ratio (Length/Height)': 1.7424242424242424, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 73, 'Centroid Y': 34, 'Slant Angle': 89.07927703857422}
# Image: 79.jpg
# Features: {'label': '79', 'features': array([0.26242127, 0.10049227, 0.01258758, ..., 0.69011339, 0.37748548,
#        0.25445833]), 'Length': 118, 'Height': 62, 'Ratio (Length/Height)': 1.903225806451613, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 75, 'Centroid Y': 32, 'Slant Angle': 42.36320114135742}
# Image: 8.jpg
# Features: {'label': '8', 'features': array([0.08900487, 0.11178093, 0.01326112, ..., 0.31425009, 0.61729582,
#        0.41425486]), 'Length': 108, 'Height': 81, 'Ratio (Length/Height)': 1.3333333333333333, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 63, 'Centroid Y': 44, 'Slant Angle': 93.72412109375}
# Image: 9.jpg
# Features: {'label': '9', 'features': array([0.00686516, 0.00378654, 0.00878099, ..., 0.27764553, 0.19113505,
#        0.35544642]), 'Length': 109, 'Height': 78, 'Ratio (Length/Height)': 1.3974358974358974, 'Integer Ratio': 1, 'Sign Classification': 'Angular', 'Overall Skill': 'Good', 'Centroid X': 65, 'Centroid Y': 40, 'Slant Angle': 82.77023315429688}
# Number of images processed: 75
# Features saved to D:\AIML Internship\cropped_signatures\cropped_signatures\kabeer main\dataset.xlsx

# %%
import pandas as pd
import numpy as np

# Load features from Excel files
sample_features_file =r"D:\AIML Internship\cropped_signatures\cropped_signatures\kabeer main\sample.xlsx"
dataset_features_file = r"D:\AIML Internship\cropped_signatures\cropped_signatures\kabeer main\dataset.xlsx"

sample_df = pd.read_excel(sample_features_file)
dataset_df = pd.read_excel(dataset_features_file)

# Convert feature vectors to numpy arrays
sample_df['features'] = sample_df['features'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))
dataset_df['features'] = dataset_df['features'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))

# Define a function to calculate similarity between feature vectors
def calculate_similarity(feature_vector1, feature_vector2):
    # Here you can use any suitable similarity metric, such as Euclidean distance or cosine similarity
    return np.linalg.norm(feature_vector1 - feature_vector2)  # Euclidean distance

# Set a threshold for similarity
threshold = 0.5  # Adjust as needed

# Dictionary to store most similar dataset image for each sample image
most_similar_images = {}

# Iterate over sample images
for index, sample_row in sample_df.iterrows():
    sample_feature_vector = sample_row["features"]
    sample_label = sample_row["label"]
    most_similar_image = None
    min_similarity = float('inf')
    
    # Iterate over dataset images
    for index, dataset_row in dataset_df.iterrows():
        dataset_feature_vector = dataset_row["features"]
        dataset_label = dataset_row["label"]
        
        # Calculate similarity between sample and dataset feature vectors
        similarity = calculate_similarity(sample_feature_vector, dataset_feature_vector)
        
        # If similarity is below threshold and better than previous matches, update most similar image
        if similarity < threshold and similarity < min_similarity:
            most_similar_image = dataset_label
            min_similarity = similarity
    
    # Store the most similar dataset image for the current sample image
    if most_similar_image is not None:
        most_similar_images[sample_label] = most_similar_image

# Print most similar images for each sample image
print("Most similar images from the dataset for each sample image:")
for sample_image, similar_image in most_similar_images.items():
    print(f"Sample Image: {sample_image}, Most Similar Dataset Image: {similar_image}")
# Out:
# Most similar images from the dataset for each sample image:
# Sample Image: 1, Most Similar Dataset Image: 71
# Sample Image: 56, Most Similar Dataset Image: 12
# C:\Users\FRIENDS INFOTECH\AppData\Local\Temp\ipykernel_5088\2172875807.py:12: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   sample_df['features'] = sample_df['features'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))
# C:\Users\FRIENDS INFOTECH\AppData\Local\Temp\ipykernel_5088\2172875807.py:13: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   dataset_df['features'] = dataset_df['features'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))

# %%
 # Define input and output folders
    signs_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain"
    output_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Parts folder"
    csv_file =r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\dataset.xlsx"

# %%
import os
import cv2
import numpy as np
from skimage.feature import hog  # Import the hog function

# Define the extract_features function with the updated code
def extract_features(images):
    features = []
    for filename, image in images:
        # Calculate image features
        height, length, _ = image.shape
        ratio = length / height
        integer_ratio = int(ratio)
        # Classify the sign
        sign_classification = classify_sign(image)
        # Assess overall skill
        overall_skill = assess_skill(image)
        
        # Calculate centroid coordinates for each partitioned image
        centroid_x_list, centroid_y_list = [], []
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
        contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        if contours:
            for part_index, contour in enumerate(contours):
                M = cv2.moments(contour)
                if M["m00"] != 0:
                    centroid_x = int(M["m10"] / M["m00"])
                    centroid_y = int(M["m01"] / M["m00"])
                    centroid_x_list.append(centroid_x)
                    centroid_y_list.append(centroid_y)
                else:
                    centroid_x_list.append(-1)
                    centroid_y_list.append(-1)
        else:
            centroid_x_list.append(-1)
            centroid_y_list.append(-1)

        # Calculate slant angle
        slant_angle = calculate_slant_angle(image)
        
        # Append features to the list
        features.append({
            'File Name': filename,
            'Length': length,
            'Height': height,
            'Ratio (Length/Height)': ratio,
            'Integer Ratio': integer_ratio,
            'Sign Classification': sign_classification,
            'Overall Skill': overall_skill,
            'Centroid X': centroid_x_list,
            'Centroid Y': centroid_y_list,
            'Slant Angle': slant_angle
        })
    return features


# Function to classify the sign
def classify_sign(image):
    # Replace this with your own sign classification method
    # Example: Determine if the sign is angular, circular, or something else
    # You may use machine learning models, rules-based systems, etc.
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    
    # Simple rule-based classification
    if len(features) < 1000:
        return "Circular"
    else:
        return "Angular"

# Function to assess the overall skill of the signature
def assess_skill(image):
    # Replace this with your own method for assessing the overall skill of the signature
    # Example: Use machine learning models or rules-based systems to evaluate the signature's quality
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    
    # Simple rule-based assessment
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        if aspect_ratio > 0.5:
            return "Good"
        else:
            return "Poor"
    else:
        return "Poor"

# Function to calculate slant angle
def calculate_slant_angle(image):
    # Convert image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Threshold the image to obtain a binary image
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    
    # Find contours in the binary image
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Find the largest contour (signature)
    largest_contour = max(contours, key=cv2.contourArea)
    
    # Check if the contour contains at least 5 points
    if len(largest_contour) < 5:
        # If the contour has too few points, return a default angle (0 degrees)
        return 0
    
    # Perform principal component analysis (PCA) on the largest contour
    _, _, angle = cv2.fitEllipse(largest_contour)
    
    # The angle returned by fitEllipse is the angle of rotation of the fitted ellipse
    # We use this as an estimate of the slant angle of the signature
    return angle

import pandas as pd

# Define a function to save the extracted features to an Excel file
def save_features_to_excel(features, excel_file):
    df = pd.DataFrame(features)
    df.to_excel(excel_file, index=False)

# Call the function to save the features to an Excel file
save_features_to_excel(features, 'extracted_features.xlsx')


# Main function
def main():
    # Define input and output folders
    signs_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain"
    output_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Parts folder"
    csv_file =r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\dataset.xlsx"

    # Load and preprocess images
    images = load_and_preprocess_images(signs_folder)

    # Divide images into parts based on ratio
    divide_images_into_parts(images, output_folder)

    # Extract features from each image
    features = extract_features(images)

    # Save extracted features to a CSV file
    save_features_to_csv(features, csv_file)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 133
#     130     df.to_excel(excel_file, index=False)
#     132 # Call the function to save the features to an Excel file
# --> 133 save_features_to_excel(features, 'extracted_features.xlsx')
#     136 # Main function
#     137 def main():
#     138     # Define input and output folders
#
# NameError: name 'features' is not defined

# %%
import os
import cv2
import numpy as np
import pandas as pd

def partition_and_save(image, num_parts, output_folder):
    height, width, _ = image.shape
    part_width = width // num_parts
    
    for i in range(num_parts):
        part_image = image[:, i*part_width:(i+1)*part_width, :]
        cv2.imwrite(os.path.join(output_folder, f"part_{i+1}.png"), part_image)

def extract_features(image):
    # Calculate length, height, ratio, integer ratio
    height, length, _ = image.shape
    ratio = length / height
    integer_ratio = int(ratio)
    
    # Classify the sign
    sign_classification = classify_sign(image)
    
    # Assess overall skill
    overall_skill = assess_skill(image)
    
    # Calculate centroid coordinates
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        contour = max(contours, key=cv2.contourArea)
        M = cv2.moments(contour)
        if M["m00"] != 0:
            centroid_x = int(M["m10"] / M["m00"])
            centroid_y = int(M["m01"] / M["m00"])
        else:
            centroid_x, centroid_y = -1, -1
    else:
        centroid_x, centroid_y = -1, -1
    
    # Calculate slant angle
    slant_angle = calculate_slant_angle(image)
    
    return {
        'Length': length,
        'Height': height,
        'Ratio (Length/Height)': ratio,
        'Integer Ratio': integer_ratio,
        'Sign Classification': sign_classification,
        'Overall Skill': overall_skill,
        'Centroid X': centroid_x,
        'Centroid Y': centroid_y,
        'Slant Angle': slant_angle
    }

def classify_sign(image):
    # Replace this with your own sign classification method
    # Example: Determine if the sign is angular, circular, or something else
    # You may use machine learning models, rules-based systems, etc.
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    
    # Simple rule-based classification
    if len(features) < 1000:
        return "Circular"
    else:
        return "Angular"

def assess_skill(image):
    # Replace this with your own method for assessing the overall skill of the signature
    # Example: Use machine learning models or rules-based systems to evaluate the signature's quality
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    
    # Simple rule-based assessment
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        if aspect_ratio > 0.5:
            return "Good"
        else:
            return "Poor"
    else:
        return "Poor"

def calculate_slant_angle(image):
    # Replace this with your method for calculating the slant angle
    # For demonstration purposes, let's return a default angle of 0
    return 0

# Define the directory containing the images
images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain"

# Initialize an empty list to store the features of all images
features_list = []

# Iterate over all images in the folder
for filename in os.listdir(images_folder):
    image_path = os.path.join(images_folder, filename)
    
    # Read the image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Unable to read image: {image_path}")
        continue  # Skip this image if loading fails
    
    # Partition the image based on its ratio and save the parts to folders
    ratio = image.shape[1] / image.shape[0]
    if ratio > 4:
        num_parts = 4
    elif ratio > 3:
        num_parts = 3
    elif ratio > 2:
        num_parts = 2
    else:
        num_parts = 1
    
    output_folder = os.path.join(images_folder, f"{num_parts}_parts", filename.split('.')[0])
    os.makedirs(output_folder, exist_ok=True)
    
    partition_and_save(image, num_parts, output_folder)
    
    # Extract features from the image
    image_features = extract_features(image)
    
    # Add the features to the list
    features_list.append(image_features)

# Create a DataFrame from the list of features
df = pd.DataFrame(features_list)

# Save the DataFrame to an Excel file
df.to_excel('extracted_features.xlsx', index=False)

# %%
import os
import cv2
import numpy as np
import pandas as pd
from skimage.feature import hog

def partition_and_save(image, num_parts, output_folder):
    height, width, _ = image.shape
    part_width = width // num_parts
    
    for i in range(num_parts):
        part_image = image[:, i*part_width:(i+1)*part_width, :]
        part_folder = os.path.join(output_folder, f"part_{i+1}")
        os.makedirs(part_folder, exist_ok=True)
        cv2.imwrite(os.path.join(part_folder, f"{i+1}.png"), part_image)

def extract_features(image):
    # Calculate length, height, ratio, integer ratio
    height, length, _ = image.shape
    ratio = length / height
    integer_ratio = int(ratio)
    
    # Classify the sign
    sign_classification = classify_sign(image)
    
    # Assess overall skill
    overall_skill = assess_skill(image)
    
    # Calculate centroid coordinates
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        contour = max(contours, key=cv2.contourArea)
        M = cv2.moments(contour)
        if M["m00"] != 0:
            centroid_x = int(M["m10"] / M["m00"])
            centroid_y = int(M["m01"] / M["m00"])
        else:
            centroid_x, centroid_y = -1, -1
    else:
        centroid_x, centroid_y = -1, -1
    
    # Calculate slant angle
    slant_angle = calculate_slant_angle(image)
    
    return {
        'File Name': filename,
        'Length': length,
        'Height': height,
        'Ratio (Length/Height)': ratio,
        'Integer Ratio': integer_ratio,
        'Sign Classification': sign_classification,
        'Overall Skill': overall_skill,
        'Centroid X': centroid_x,
        'Centroid Y': centroid_y,
        'Slant Angle': slant_angle
    }

def classify_sign(image):
    # Replace this with your own sign classification method
    # Example: Determine if the sign is angular, circular, or something else
    # You may use machine learning models, rules-based systems, etc.
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate stroke features using HOG
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features, _ = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    
    # Simple rule-based classification
    if len(features) < 1000:
        return "Circular"
    elif "eyed" in filename.lower():  # Check if filename contains "eyed"
        return "Eyed"
    else:
        return "Angular"

def assess_skill(image):
    # Replace this with your own method for assessing the overall skill of the signature
    # Example: Use machine learning models or rules-based systems to evaluate the signature's quality
    # For demonstration purposes, let's assume a simple rule-based system
    
    # Calculate shape features (e.g., aspect ratio, area, perimeter)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour = contours[0] if contours else None
    
    # Simple rule-based assessment
    if contour is not None:
        x, y, w, h = cv2.boundingRect(contour)
        aspect_ratio = w / h
        if aspect_ratio > 0.5:
            return "Good"
        else:
            return "Poor"
    else:
        return "Poor"

def calculate_slant_angle(image):
    # Convert image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Threshold the image to obtain a binary image
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    
    # Find contours in the binary image
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Find the largest contour (signature)
    largest_contour = max(contours, key=cv2.contourArea)
    
    # Check if the contour contains at least 5 points
    if len(largest_contour) < 5:
        # If the contour has too few points, return a default angle (0 degrees)
        return 0
    
    # Perform principal component analysis (PCA) on the largest contour
    _, _, angle = cv2.fitEllipse(largest_contour)
    
    # The angle returned by fitEllipse is the angle of rotation of the fitted ellipse
    # We use this as an estimate of the slant angle of the signature
    return angle

# Define the directory containing the images
images_folder = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain"

# Initialize an empty list to store the features of all images
features_list = []

# Iterate over all images in the folder
for filename in os.listdir(images_folder):
    image_path = os.path.join(images_folder, filename)
    
    # Read the image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Unable to read image: {image_path}")
        continue  # Skip this image if loading fails
    
    # Partition the image based on its aspect ratio and save the parts to folders
    ratio = image.shape[1] / image.shape[0]
    if ratio > 4:
        num_parts = 4
    elif ratio > 3:
        num_parts = 3
    elif ratio > 2:
        num_parts = 2
    else:
        num_parts = 1
    
    output_folder = os.path.join(images_folder, f"{num_parts}_parts", filename.split('.')[0])
    os.makedirs(output_folder, exist_ok=True)
    
    partition_and_save(image, num_parts, output_folder)
    
    # Extract features from the image
    image_features = extract_features(image)
    
    # Add the image name to the features dictionary
    image_features['File Name'] = filename
    
    # Append the features to the list
    features_list.append(image_features)
# Out:
# Unable to read image: D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain\1_parts
# Unable to read image: D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain\2_parts
# Unable to read image: D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain\3_parts
# Unable to read image: D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\Hussain\4_parts

# %%
# Convert the features list to a DataFrame
features_df = pd.DataFrame(features_list)

# Define the output Excel file
output_excel = r"D:\AIML Internship\cropped_signatures\cropped_signatures\Hussain\sample.xlsx"

# Save the DataFrame to an Excel file
features_df.to_excel(output_excel, index=False)
